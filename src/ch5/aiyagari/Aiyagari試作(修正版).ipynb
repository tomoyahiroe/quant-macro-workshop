# %%
# !pip install quantecon
# !pip install numba
# !pip install interpolation

# %%
import numpy as np
from quantecon.optimize import brentq
from quantecon.markov import rouwenhorst
from interpolation import interp
from numba import njit
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import scipy

# %% [markdown]
# # Aiyagari に従って...

# %%
# パラメータ
beta = 0.96
gamma = 3.0
rho = 0.6
sigma = 0.4
alpha = 0.36
delta = 0.08
b = 3.0

# %%
r0 = 0.03
K0d = ((r0 + delta) / alpha) ** (1 / (alpha - 1))
w0 = (1 - alpha) * (K0d ** alpha)
print(w0)
# Out:
# 1.246857279797728

# %% [markdown]
# ## 政策関数...

# %%
# 解く問題の設定を行う（パラメータ, グリッド, 効用関数や生産関数）
# モデルを変更する場合にはここを修正
class Setting:

    def __init__(self,
                 R=1.01,                          # 粗実質利子率
                 beta=0.99,                          # 割引因子
                 gamma=1,                          # 相対的リスク回避度(異時点間の代替弾力性の逆数)
                 b=0,                             # 内生的な状態変数の最小値, 借入制約
                 a_max=16,                        # 内生的な状態変数の最大値
                 na=21,                           # 内生的な状態変数のグリッド数
                 mu=0,                            # 外生変数のAR(1)過程の定数項
                 rho=0.6,                        # 外生変数のAR(1)過程の慣性
                 sigma=0.4,                       # 外生変数のAR(1)過程のショック項の標準偏差
                 nz = 11,                         # 外生変数のグリッド数
                 w = 0,                         # 賃金
                 lambdaPF = 1):                 # 政策関数の更新度

        # パラメータを設定する
        self.R = R
        self.beta = beta
        self.b = b
        self.gamma = gamma

        # 外生変数の遷移確率とグリッドを設定する
        mc = rouwenhorst(nz, rho, sigma, mu)
        self.Pz = mc.P
        self.z_grid = np.exp(mc.state_values)

        # 内生的な状態変数のグリッドを設定する
        a_grid = np.linspace(-b, a_max, na)
        self.a_grid = a_grid

        # 賃金を設定
        self.w = w

        # 政策関数の更新度を設定する
        self.lambdaPF = lambdaPF

        # CRRA型効用関数と限界効用を定義する
        gamma = self.gamma
        if gamma == 1:
            self.utility = np.log
            self.mutility = njit(lambda x: 1 / x)
        else:
            self.utility = njit(lambda x: x**(1-gamma) / (1 - gamma))
            self.mutility = njit(lambda x: x**(-gamma))


		    # 政策関数の初期値を定義する
        z_grid = self.z_grid
        hfun_old = np.empty((len(a_grid), len(z_grid)))
        for i_a, a in enumerate(a_grid):
            for i_z, z in enumerate(z_grid):
                c_max = 0.5* (R * a + z + b)
                hfun_old[i_a, i_z] = c_max
        self.hfun_old = hfun_old


# 特定のアルゴリズムを実行して政策関数を更新する関数を出力する
# FOCを変更する場合やアルゴリズムを変更する場合はここを修正

# 今期の状態変数について繰り返し記号はi, 来期の状態変数について繰り返し記号はj

def TimeIteration(hp): # hpはSettingクラスからつくられるインスタンス

    # インスタンスからローカル変数を定義する
    R, beta, b, mutility, w = hp.R, hp.beta, hp.b, hp.mutility, hp.w
    a_grid, z_grid, Pz = hp.a_grid, hp.z_grid, hp.Pz

    @njit
    def FOCs(c, a, z, i_z, hfun):

        # 制約式から次期の内生的な状態変数を計算する
        aprime = R * a + w*z - c

        expectation = 0
        for j_z in range(len(z_grid)):
            # 政策関数の候補を補間して次期の制御変数を計算する
            cprime = interp(a_grid, hfun[:, j_z], aprime)

            # オイラー方程式の右辺を計算する
            expectation += mutility(cprime) * Pz[i_z, j_z]

        rhs = max(R * beta * expectation, mutility(R * a + w*z + b))

        FOC_diff = mutility(c) - rhs

        return FOC_diff


    @njit
    def UpdatePF(h_old):

        h_new = np.empty_like(h_old)
        for i_a in range(len(a_grid)):
            a = a_grid[i_a]
            for i_z in range(len(z_grid)):
                z = z_grid[i_z]
                c_star = brentq(FOCs, 1e-8, R * a + w*z + b, args=(a, z, i_z, h_old)).root
                h_new[i_a, i_z] = c_star

        return h_new

    return UpdatePF





# メイン関数：特定のアルゴリズムでiterationを行い、問題を解く関数
# 基本的には変更する必要がない

def SolveProblem(hp,               # Settingクラスからつくられるインスタンス
                Algorithm,         # アルゴリズムを指定
                tol=1e-4,          # 許容繰り返し誤差
                max_iter=10000,     # iteration回数の最大値
                verbose=True,      # 進捗を表示するかどうか
                print_skip=25):    # 進捗を何回ごとに表示するか


    # インスタンスからローカル変数を定義する
    R, beta, b, mutility = hp.R, hp.beta, hp.b, hp.mutility
    a_grid, z_grid, Pz = hp.a_grid, hp.z_grid, hp.Pz
    lambdaPF = hp.lambdaPF
    hfun_old = hp.hfun_old

    # チェックのために外生変数のグリッドと遷移確率を表示する
    # print(f"About exogenous variables:")
    # print(f"grid is {z_grid}.")
    # print(f"Transition matrix is {Pz}.")



    # 政策関数を更新する関数を取得する
    UpdatePF = Algorithm(hp)

    # iterationを行い、問題を解く
    i = 0
    error = tol + 1

    while i < max_iter and error > tol:

        # 政策関数を更新する
        hfun_new_tilde = UpdatePF(hfun_old)

        # 古い政策関数と加重平均する
        hfun_new = lambdaPF*hfun_new_tilde + (1-lambdaPF)*hfun_old

        error = np.max(np.abs(hfun_new-hfun_old))
        i += 1
        if verbose and i % print_skip == 0:      # 進捗をprint_skip回ごとに表示する
            print(f"Error at iteration {i} is {error}.")
        hfun_old = hfun_new

    if i == max_iter:
        print("Failed to converge!")

    if verbose and i < max_iter:
        print(f"\nConverged in {i} iterations.")

    return hfun_new

# %%
hp = Setting(beta=beta, gamma = gamma, b = b, lambdaPF = 1, na = 100, nz = 10, rho = rho, sigma = sigma, R = 1 + r0, w = w0)
hfun_c = SolveProblem(hp,TimeIteration)
# Out:
# /var/folders/y2/hwl07kg14b31nb5s126cjc8m0000gn/T/ipykernel_53826/2559618858.py:26: UserWarning: The API of rouwenhorst has changed from `rouwenhorst(n, ybar, sigma, rho)` to `rouwenhorst(n, rho, sigma, mu=0.)`. To find more details please visit: https://github.com/QuantEcon/QuantEcon.py/issues/663.
#   mc = rouwenhorst(nz, rho, sigma, mu)
# Error at iteration 25 is 0.03080776090289694.
# Error at iteration 50 is 0.005166747275201278.
# Error at iteration 75 is 0.0013284682856906649.
# Error at iteration 100 is 0.0003814512878370646.
# Error at iteration 125 is 0.00011222428018764496.
#
# Converged in 128 iterations.

# %%
import time

# %%
start = time.time()
Amesh, Zmesh = np.meshgrid(hp.a_grid, hp.z_grid, indexing='ij')
hfun_a = Amesh * hp.R + hp.w * Zmesh - hfun_c
end = time.time()
print(end - start)
# Out:
# 0.0008389949798583984

# %%
# hp.a_grid と hfun_a[0]のデータフレームを作る
df = pd.DataFrame({
    'x_axis': hp.a_grid,
    'y_axis': hfun_a[:, -1]})
# plot
plt.plot('x_axis', 'y_axis', data=df, linestyle='-', marker='o')

# %% [markdown]
# ## 定常分布...

# %%
import numpy as np
from typing import Callable

# TODO: 定常分布が政策関数と同じ要素数であることを前提としてしまっている

# 政策関数によって得られたグリッド外の値が、グリッド上に移動する確率行列を計算する関数
@njit
def split_prob_to_agrid(aprime: float, agrid: np.ndarray) -> np.ndarray:
    """ 政策関数によって得られた a の値が、a_grid のどの点に移動するのかを示す確率ベクトルを計算する関数

    Args:
    aprime: 政策関数によって得られた a の値
    agrid: a のグリッド
    return: aprime が agrid のどの点に移動するのかを示す確率ベクトル
    """
    probs = np.zeros(len(agrid))
    # a の値が a_grid の最小値より小さい場合
    if aprime <= agrid[0]:
        probs[0] = 1.0
        return probs

    # a の値が a_grid の最大値より大きい場合
    if aprime >= agrid[-1]:
        probs[-1] = 1.0
        return probs

    # a の値が a_grid の最小値より大きく最大値より小さい場合
    for i in range(len(agrid)-1):
        if agrid[i] <= aprime <= agrid[i+1]:
            probs[i] = (agrid[i+1] - aprime) / (agrid[i+1] - agrid[i])
            probs[i+1] = (aprime - agrid[i]) / (agrid[i+1] - agrid[i])
            return probs

    # この行までに return されていない場合はエラーを出す
    raise ValueError("Splitting probability failed.")

@njit
def calc_weight_matrix(aprime_grid: np.ndarray, agrid: np.ndarray, split_prob_to_agrid = split_prob_to_agrid) -> np.ndarray:
    """ 前期の定常分布に係る重みづけ確率行列 weight_matrix を計算する関数

    Args:
        aprime_grid: 政策関数の行き先のグリッド
        agrid: 資産のグリッド
        split_prob: 政策関数によって得られた a の値が、a_grid のどの点に移動するのかを示す確率ベクトルを計算する関数

    Returns:
        weight_matrix: 前期の定常分布に係る重みづけ確率のグリッド、shape は aprime_grid と同じ
    """
    weight_matrix = np.empty((len(aprime_grid), len(aprime_grid[0]), len(agrid)))

    # aprime_grid は 二次元配列
    for i in range(len(aprime_grid)):
        for j in range(len(aprime_grid[0])):
            weight_matrix[i, j] = split_prob_to_agrid(float(aprime_grid[i, j]), agrid)
    return weight_matrix

@njit
def gen_pmesh(aprime_grid: np.ndarray, P: np.ndarray, next_y_index: int) -> np.ndarray:
    """ 遷移確率を 政策関数 aprime_grid との要素ごとの計算に使えるように meshgrid を生成する関数

    Args:
        aprime_grid (np.ndarray): 政策関数のグリッド
        P (np.ndarray): 遷移確率行列
        next_y_index (int): 次期の所得状態 y' のインデックス

    Returns:
        np.ndarray: 政策関数と遷移確率行列を使って計算するための meshgrid
    """
    pmesh = np.zeros(aprime_grid.shape)
    for i in range(len(aprime_grid)):
        for j in range(len(aprime_grid[0])):
            pmesh[i, j] = P[j, next_y_index]
    return pmesh

# def calc_sd_point(Pmesh, weight, sd_old) -> float:
#     """ 定常分布の一点を計算する関数

#     Args:
#         Pmesh (np.ndarray): 政策関数と遷移確率行列を使って計算した meshgrid
#         weight (np.ndarray): 前期の定常分布に係る重みづけ確率
#         sd_old (np.ndarray): 一期前の定常分布 f(a, y)

#     Returns:
#         float: 更新された(次期の)定常分布の一点の値
#     """
#     return np.sum(Pmesh * weight * sd_old)

@njit
def update_sd(aprime_grid: np.ndarray, agrid: np.ndarray, sd_old: np.ndarray, P: np.ndarray,
            split_prob_to_agrid = split_prob_to_agrid, calc_weight_matrix = calc_weight_matrix,
            gen_P = gen_pmesh,
            # calc_sd_point = calc_sd_point
            ) -> np.ndarray:
    """ 定常分布を更新する関数

    Args:
        aprime_grid (np.ndarray): 政策関数のグリッド
        agrid (np.ndarray): 資産のグリッド
        sd_old (np.ndarray): 更新前の定常分布
        P (np.ndarray): 遷移確率行列
        split_prob (Callable): 政策関数によって得られた a の値が、a_grid のどの点に移動するのかを示す確率ベクトルを計算する関数
        calc_weight (Callable): 前期の定常分布に係る重みづけ確率 weight を計算する関数
        gen_P (Callable): 遷移確率を 政策関数 aprime_grid との要素ごとの計算に使えるように meshgrid を生成する関数
        calc_sd_point (Callable): 定常分布の一点を計算する関数

    Returns:
        sd_new（np.ndarray）: 更新された定常分布のグリッド
    """
    sd_new = np.zeros(sd_old.shape)
    weight_matrix = calc_weight_matrix(aprime_grid, agrid, split_prob_to_agrid)
    for i in range(len(aprime_grid)):
        for j in range(len(aprime_grid[0])):
            p_mesh = gen_P(aprime_grid, P, j)
            # sd_new[i, j] = calc_sd_point(p_mesh, weight_matrix[:,:,i], sd_old)
            sd_new[i,j] = np.sum(p_mesh * weight_matrix[:,:,i] * sd_old)

    return sd_new

@njit
def sd_iteration(sd0: np.ndarray, aprime_grid: np.ndarray, agrid: np.ndarray, P: np.ndarray,
                        tol: float = 1e-6, max_iter: int = 1000,
                        update_sd = update_sd) -> np.ndarray:
    """ 定常分布を計算する関数

    Args:
        aprime_grid (np.ndarray): 政策関数のグリッド
        agrid (np.ndarray): 資産のグリッド
        guess_sd (np.ndarray): 初期の定常分布のグリッド
        P (np.ndarray): 遷移確率行列
        tol (float, optional): 許容する誤差. Defaults to 1e-6.
        max_iter (int, optional): 最大の反復回数. Defaults to 1000.
        update_sd (_type_, optional): 定常分布を更新する関数. Defaults to update_sd.

    Returns:
        np.ndarray: 収束した定常分布のグリッド
    """
    sd_old = sd0

    diff = tol + 1
    iteration = 0
    while diff > tol and iteration < max_iter:
        sd_new = update_sd(aprime_grid, agrid, sd_old, P)
        diff = np.max(np.abs(sd_new - sd_old))
        sd_old = sd_new
        iteration += 1
        # print(f"Iteration {iteration}: diff = {diff}")

    # 最終イタレーション回数の出力
    print(f"Total iterations until convergence: {iteration}")

    # 定常分布の出力
    # print("Stationary distribution f_{i,j}:")
    # print(sd_new)
    return sd_new

# %%
# hfun_c から 時期のアセット aの政策関数を求める
hfun_aprime = np.empty((len(hp.a_grid), len(hp.z_grid)))
a_mesh, z_mesh = np.meshgrid(hp.a_grid, hp.z_grid, indexing='ij') # ユニバーサル関数を使用するためのグリッドを生成
hfun_aprime = hp.R * a_mesh + hp.w * z_mesh - hfun_c

# 初期の定常分布を定義
sd_grid = np.full(hfun_aprime.shape, 1/hfun_aprime.size)

# %%
sd = sd_iteration(sd_grid, hfun_aprime, hp.a_grid, hp.Pz)
# Out:
# Total iterations until convergence: 150

# %%
Amesh, _ = np.meshgrid(hp.a_grid, hp.z_grid, indexing='ij')
A0 = np.sum(Amesh * sd)

print(A0)
# Out:
# 6.578942669533127

# %%
# aprimeの政策関数を補間
a_grid_sd = np.linspace(-3, 25, 80)
Amesh_sd = np.meshgrid(a_grid_sd, hp.z_grid, indexing='ij')
a_grid = np.linspace(-3, 15, 20)
hfun_aprime_interp = interp(Amesh, hfun_a, Amesh_sd)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       3 Amesh_sd = np.meshgrid(a_grid_sd, hp.z_grid, indexing='ij')
#       4 a_grid = np.linspace(-3, 15, 20)
# ----> 5 hfun_aprime_interp = interp(Amesh, hfun_a, Amesh_sd)
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/dispatcher.py:442, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     440             e.patch_message('\n'.join((str(e).rstrip(), help_msg)))
#     441     # ignore the FULL_TRACEBACKS config, this needs reporting!
# --> 442     raise e
#     443 finally:
#     444     self._types_active_call = []
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/dispatcher.py:375, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     373 return_val = None
#     374 try:
# --> 375     return_val = self.compile(tuple(argtypes))
#     376 except errors.ForceLiteralArg as e:
#     377     # Received request for compiler re-entry with the list of arguments
#     378     # indicated by e.requested_args.
#     379     # First, check if any of these args are already Literal-ized
#     380     already_lit_pos = [i for i in e.requested_args
#     381                        if isinstance(args[i], types.Literal)]
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/dispatcher.py:905, in Dispatcher.compile(self, sig)
#     903 with ev.trigger_event("numba:compile", data=ev_details):
#     904     try:
# --> 905         cres = self._compiler.compile(args, return_type)
#     906     except errors.ForceLiteralArg as e:
#     907         def folded(args, kws):
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/compiler.py:744, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     720 """Compiler entry point
#     721
#     722 Parameter
#    (...)
#     740     compiler pipeline
#     741 """
#     742 pipeline = pipeline_class(typingctx, targetctx, library,
#     743                           args, return_type, flags, locals)
# --> 744 return pipeline.compile_extra(func)
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/compiler.py:438, in CompilerBase.compile_extra(self, func)
#     436 self.state.lifted = ()
#     437 self.state.lifted_from = None
# --> 438 return self._compile_bytecode()
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/compiler.py:506, in CompilerBase._compile_bytecode(self)
#     502 """
#     503 Populate and run pipeline for bytecode input
#     504 """
#     505 assert self.state.func_ir is None
# --> 506 return self._compile_core()
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/compiler.py:481, in CompilerBase._compile_core(self)
#     478 except Exception as e:
#     479     if (utils.use_new_style_errors() and not
#     480             isinstance(e, errors.NumbaError)):
# --> 481         raise e
#     483     self.state.status.fail_reason = e
#     484     if is_final_pipeline:
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/compiler.py:472, in CompilerBase._compile_core(self)
#     470 res = None
#     471 try:
# --> 472     pm.run(self.state)
#     473     if self.state.cr is not None:
#     474         break
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:364, in PassManager.run(self, state)
#     361 except Exception as e:
#     362     if (utils.use_new_style_errors() and not
#     363             isinstance(e, errors.NumbaError)):
# --> 364         raise e
#     365     msg = "Failed in %s mode pipeline (step: %s)" % \
#     366         (self.pipeline_name, pass_desc)
#     367     patched_exception = self._patch_error(msg, e)
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:273, in PassManager._runPass.<locals>.check(func, compiler_state)
#     272 def check(func, compiler_state):
# --> 273     mangled = func(compiler_state)
#     274     if mangled not in (True, False):
#     275         msg = ("CompilerPass implementations should return True/False. "
#     276                "CompilerPass with name '%s' did not.")
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/typed_passes.py:112, in BaseTypeInference.run_pass(self, state)
#     106 """
#     107 Type inference and legalization
#     108 """
#     109 with fallback_context(state, 'Function "%s" failed type inference'
#     110                       % (state.func_id.func_name,)):
#     111     # Type inference
# --> 112     typemap, return_type, calltypes, errs = type_inference_stage(
#     113         state.typingctx,
#     114         state.targetctx,
#     115         state.func_ir,
#     116         state.args,
#     117         state.return_type,
#     118         state.locals,
#     119         raise_errors=self._raise_errors)
#     120     state.typemap = typemap
#     121     # save errors in case of partial typing
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/typed_passes.py:93, in type_inference_stage(typingctx, targetctx, interp, args, return_type, locals, raise_errors)
#      91     infer.build_constraint()
#      92     # return errors in case of partial typing
# ---> 93     errs = infer.propagate(raise_errors=raise_errors)
#      94     typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      96 return _TypingResults(typemap, restype, calltypes, errs)
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/typeinfer.py:1083, in TypeInferer.propagate(self, raise_errors)
#    1080 oldtoken = newtoken
#    1081 # Errors can appear when the type set is incomplete; only
#    1082 # raise them when there is no progress anymore.
# -> 1083 errors = self.constraints.propagate(self)
#    1084 newtoken = self.get_state_token()
#    1085 self.debug.propagate_finished()
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/typeinfer.py:182, in ConstraintNetwork.propagate(self, typeinfer)
#     180     errors.append(utils.chain_exception(new_exc, e))
#     181 elif utils.use_new_style_errors():
# --> 182     raise e
#     183 else:
#     184     msg = ("Unknown CAPTURED_ERRORS style: "
#     185            f"'{config.CAPTURED_ERRORS}'.")
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/typeinfer.py:160, in ConstraintNetwork.propagate(self, typeinfer)
#     157 with typeinfer.warnings.catch_warnings(filename=loc.filename,
#     158                                        lineno=loc.line):
#     159     try:
# --> 160         constraint(typeinfer)
#     161     except ForceLiteralArg as e:
#     162         errors.append(e)
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/typeinfer.py:583, in CallConstraint.__call__(self, typeinfer)
#     581     fnty = typevars[self.func].getone()
#     582 with new_error_context("resolving callee type: {0}", fnty):
# --> 583     self.resolve(typeinfer, typevars, fnty)
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/typeinfer.py:606, in CallConstraint.resolve(self, typeinfer, typevars, fnty)
#     604     fnty = fnty.instance_type
#     605 try:
# --> 606     sig = typeinfer.resolve_call(fnty, pos_args, kw_args)
#     607 except ForceLiteralArg as e:
#     608     # Adjust for bound methods
#     609     folding_args = ((fnty.this,) + tuple(self.args)
#     610                     if isinstance(fnty, types.BoundFunction)
#     611                     else self.args)
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/typeinfer.py:1577, in TypeInferer.resolve_call(self, fnty, pos_args, kw_args)
#    1574     return sig
#    1575 else:
#    1576     # Normal non-recursive call
# -> 1577     return self.context.resolve_function_type(fnty, pos_args, kw_args)
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/typing/context.py:196, in BaseContext.resolve_function_type(self, func, args, kws)
#     194 # Prefer user definition first
#     195 try:
# --> 196     res = self._resolve_user_function_type(func, args, kws)
#     197 except errors.TypingError as e:
#     198     # Capture any typing error
#     199     last_exception = e
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/typing/context.py:248, in BaseContext._resolve_user_function_type(self, func, args, kws, literals)
#     244         return self.resolve_function_type(func_type, args, kws)
#     246 if isinstance(func, types.Callable):
#     247     # XXX fold this into the __call__ attribute logic?
# --> 248     return func.get_call_type(self, args, kws)
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/types/functions.py:312, in BaseFunction.get_call_type(self, context, args, kws)
#     309 except Exception as e:
#     310     if (utils.use_new_style_errors() and not
#     311             isinstance(e, errors.NumbaError)):
# --> 312         raise e
#     313     else:
#     314         sig = None
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/types/functions.py:308, in BaseFunction.get_call_type(self, context, args, kws)
#     305         nolitargs = tuple([_unlit_non_poison(a) for a in args])
#     306         nolitkws = {k: _unlit_non_poison(v)
#     307                     for k, v in kws.items()}
# --> 308         sig = temp.apply(nolitargs, nolitkws)
#     309 except Exception as e:
#     310     if (utils.use_new_style_errors() and not
#     311             isinstance(e, errors.NumbaError)):
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/typing/templates.py:350, in AbstractTemplate.apply(self, args, kws)
#     348 def apply(self, args, kws):
#     349     generic = getattr(self, "generic")
# --> 350     sig = generic(args, kws)
#     351     # Enforce that *generic()* must return None or Signature
#     352     if sig is not None:
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/typing/templates.py:613, in _OverloadFunctionTemplate.generic(self, args, kws)
#     607 """
#     608 Type the overloaded function by compiling the appropriate
#     609 implementation for the given args.
#     610 """
#     611 from numba.core.typed_passes import PreLowerStripPhis
# --> 613 disp, new_args = self._get_impl(args, kws)
#     614 if disp is None:
#     615     return
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/typing/templates.py:712, in _OverloadFunctionTemplate._get_impl(self, args, kws)
#     708 except KeyError:
#     709     # pass and try outside the scope so as to not have KeyError with a
#     710     # nested addition error in the case the _build_impl fails
#     711     pass
# --> 712 impl, args = self._build_impl(cache_key, args, kws)
#     713 return impl, args
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/numba/core/typing/templates.py:785, in _OverloadFunctionTemplate._build_impl(self, cache_key, args, kws)
#     783     raise TypingError(str(e)) from e
#     784 else:
# --> 785     ovf_result = self._overload_func(*args, **kws)
#     787 if ovf_result is None:
#     788     # No implementation => fail typing
#     789     self._impl_cache[cache_key] = None, None
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/interpolation/multilinear/mlinterp.py:237, in ol_interp(*args)
#     234 source = make_mlinterp(it, "__mlinterp")
#     235 import ast
# --> 237 tree = ast.parse(source)
#     238 code = compile(tree, "<string>", "exec")
#     239 eval(code, globals())
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/ast.py:52, in parse(source, filename, mode, type_comments, feature_version)
#      50     feature_version = minor
#      51 # Else it should be an int giving the minor version for 3.x.
# ---> 52 return compile(source, filename, mode, flags,
#      53                _feature_version=feature_version)
#
# TypeError: compile() arg 1 must be a string, bytes or AST object

# %%
a_grid_sd = np.linspace(-3, 25, 80)
a_grid = np.linspace(-3, 15, 20)
hfun_aprime_interp = np.empty((len(a_grid_sd), len(hp.z_grid)))
for i in range(hp.z_grid.size):
   hfun_aprime_interp[:, i] = interp(hp.a_grid, hfun_a[:, i], a_grid_sd)

# %%
hfun_aprime_interp.shape
# Out:
# (80, 10)

# %% [markdown]
# ## 実際に反復

# %%
r0 = 0.03

diff = 1
loop = 0
while abs(diff) > 1e-6:
    loop += 1
    print("loop: ", loop)
    # 1
    K0d = ((r0 + delta) / alpha) ** (1 / (alpha - 1))
    w0 = (1 - alpha) * (K0d ** alpha)

    # 2
    hp = Setting(beta=beta, gamma = gamma, b = b, lambdaPF = 1, na = 20, nz = 3, rho = rho, sigma = sigma, R = 1 + r0, w = w0)
    hfun_c = SolveProblem(hp,TimeIteration)

    # 3
    # hfun_c から 時期のアセット aの政策関数を求める
    hfun_aprime = np.empty((len(hp.a_grid), len(hp.z_grid)))
    a_mesh, z_mesh = np.meshgrid(hp.a_grid, hp.z_grid, indexing='ij') # ユニバーサル関数を使用するためのグリッドを生成
    hfun_aprime = hp.R * a_mesh + hp.w * z_mesh - hfun_c

    # aprimeの政策関数を補間
    a_grid_sd = np.linspace(-hp.b, hp.a_grid[-1] + 30, len(hp.a_grid) + 60)
    hfun_aprime_interp = np.empty((len(a_grid_sd), len(hp.z_grid)))
    for i in range(hp.z_grid.size):
      hfun = scipy.interpolate.interp1d(hp.a_grid, hfun_aprime[:, i], fill_value="extrapolate")
      for j in range(len(a_grid_sd)):
        hfun_aprime_interp[j, i] = hfun(a_grid_sd[j])
      # hfun_aprime_interp[:, i] = interp(hp.a_grid, hfun_aprime[:, i], a_grid_sd)

    # 初期の定常分布を定義
    sd_grid = np.full(hfun_aprime_interp.shape, 1/hfun_aprime_interp.size)

    sd = sd_iteration(sd_grid, hfun_aprime_interp, a_grid_sd, hp.Pz)

    # 4
    Amesh, _ = np.meshgrid(a_grid_sd, hp.z_grid, indexing='ij')
    A0 = np.sum(Amesh * sd)
    print("A0: ", A0)
    diff = (A0 - K0d)
    print("diff: ", diff)

    r0 = r0 - 0.001 * diff

r0 = r0 + 0.001 * diff
# Out:
# loop:  1
# /var/folders/y2/hwl07kg14b31nb5s126cjc8m0000gn/T/ipykernel_53826/2559618858.py:26: UserWarning: The API of rouwenhorst has changed from `rouwenhorst(n, ybar, sigma, rho)` to `rouwenhorst(n, rho, sigma, mu=0.)`. To find more details please visit: https://github.com/QuantEcon/QuantEcon.py/issues/663.
#   mc = rouwenhorst(nz, rho, sigma, mu)
# Error at iteration 25 is 0.028203291259480956.
# Error at iteration 50 is 0.004900033188079078.
# Error at iteration 75 is 0.0013205757618808267.
# Error at iteration 100 is 0.00039904681771862904.
# Error at iteration 125 is 0.00012386476035053384.
#
# Converged in 130 iterations.
# Total iterations until convergence: 1000
# A0:  33.98529216207161
# diff:  27.609317435833226
# loop:  2
# /var/folders/y2/hwl07kg14b31nb5s126cjc8m0000gn/T/ipykernel_53826/2559618858.py:26: UserWarning: The API of rouwenhorst has changed from `rouwenhorst(n, ybar, sigma, rho)` to `rouwenhorst(n, rho, sigma, mu=0.)`. To find more details please visit: https://github.com/QuantEcon/QuantEcon.py/issues/663.
#   mc = rouwenhorst(nz, rho, sigma, mu)
# Error at iteration 25 is 0.019331682492702562.
# Error at iteration 50 is 0.000918570526536655.
#
# Converged in 70 iterations.
# Total iterations until convergence: 150
# A0:  2.149932164984728
# diff:  -7.865348515120695
# loop:  3
# /var/folders/y2/hwl07kg14b31nb5s126cjc8m0000gn/T/ipykernel_53826/2559618858.py:26: UserWarning: The API of rouwenhorst has changed from `rouwenhorst(n, ybar, sigma, rho)` to `rouwenhorst(n, rho, sigma, mu=0.)`. To find more details please visit: https://github.com/QuantEcon/QuantEcon.py/issues/663.
#   mc = rouwenhorst(nz, rho, sigma, mu)
# Error at iteration 25 is 0.02263536852131276.
# Error at iteration 50 is 0.0018049504400687866.
# Error at iteration 75 is 0.00017824042346781255.
#
# Converged in 82 iterations.
# Total iterations until convergence: 191
# A0:  2.8919262095876532
# diff:  -5.79349820284807
# loop:  4
# /var/folders/y2/hwl07kg14b31nb5s126cjc8m0000gn/T/ipykernel_53826/2559618858.py:26: UserWarning: The API of rouwenhorst has changed from `rouwenhorst(n, ybar, sigma, rho)` to `rouwenhorst(n, rho, sigma, mu=0.)`. To find more details please visit: https://github.com/QuantEcon/QuantEcon.py/issues/663.
#   mc = rouwenhorst(nz, rho, sigma, mu)
# Error at iteration 25 is 0.024619931092384473.
# Error at iteration 50 is 0.0026254702962726917.
# Error at iteration 75 is 0.0003579260194084277.
#
# Converged in 92 iterations.
# Total iterations until convergence: 253
# A0:  3.7425963251705787
# diff:  -4.138267869233786
# loop:  5
# /var/folders/y2/hwl07kg14b31nb5s126cjc8m0000gn/T/ipykernel_53826/2559618858.py:26: UserWarning: The API of rouwenhorst has changed from `rouwenhorst(n, ybar, sigma, rho)` to `rouwenhorst(n, rho, sigma, mu=0.)`. To find more details please visit: https://github.com/QuantEcon/QuantEcon.py/issues/663.
#   mc = rouwenhorst(nz, rho, sigma, mu)
# Error at iteration 25 is 0.02584302516192727.
# Error at iteration 50 is 0.00327026486840154.
# Error at iteration 75 is 0.0005538154800897033.
# Error at iteration 100 is 9.546670134907842e-05.
#
# Converged in 100 iterations.
# Total iterations until convergence: 348
# A0:  4.718986831823628
# diff:  -2.6591972937734853
# loop:  6
# /var/folders/y2/hwl07kg14b31nb5s126cjc8m0000gn/T/ipykernel_53826/2559618858.py:26: UserWarning: The API of rouwenhorst has changed from `rouwenhorst(n, ybar, sigma, rho)` to `rouwenhorst(n, rho, sigma, mu=0.)`. To find more details please visit: https://github.com/QuantEcon/QuantEcon.py/issues/663.
#   mc = rouwenhorst(nz, rho, sigma, mu)
# Error at iteration 25 is 0.026552996049105992.
# Error at iteration 50 is 0.003700685765306133.
# Error at iteration 75 is 0.0007177937784650368.
# Error at iteration 100 is 0.00014450481039318674.
#
# Converged in 106 iterations.
# Total iterations until convergence: 477
# A0:  5.8115601439737645
# diff:  -1.2707228331516065
# loop:  7
# /var/folders/y2/hwl07kg14b31nb5s126cjc8m0000gn/T/ipykernel_53826/2559618858.py:26: UserWarning: The API of rouwenhorst has changed from `rouwenhorst(n, ybar, sigma, rho)` to `rouwenhorst(n, rho, sigma, mu=0.)`. To find more details please visit: https://github.com/QuantEcon/QuantEcon.py/issues/663.
#   mc = rouwenhorst(nz, rho, sigma, mu)
# Error at iteration 25 is 0.026872977146510824.
# Error at iteration 50 is 0.003911293478275901.
# Error at iteration 75 is 0.0008084546476032628.
# Error at iteration 100 is 0.0001747104682277012.
#
# Converged in 110 iterations.
# Total iterations until convergence: 576
# A0:  6.705475084394983
# diff:  -0.24221457005350544
# loop:  8
# /var/folders/y2/hwl07kg14b31nb5s126cjc8m0000gn/T/ipykernel_53826/2559618858.py:26: UserWarning: The API of rouwenhorst has changed from `rouwenhorst(n, ybar, sigma, rho)` to `rouwenhorst(n, rho, sigma, mu=0.)`. To find more details please visit: https://github.com/QuantEcon/QuantEcon.py/issues/663.
#   mc = rouwenhorst(nz, rho, sigma, mu)
# Error at iteration 25 is 0.0269326163958703.
# Error at iteration 50 is 0.003952050321567757.
# Error at iteration 75 is 0.0008263451748153905.
# Error at iteration 100 is 0.00018102792110097354.
#
# Converged in 110 iterations.
# Total iterations until convergence: 598
# A0:  6.928209618569689
# diff:  0.005699239729644923
# loop:  9
# /var/folders/y2/hwl07kg14b31nb5s126cjc8m0000gn/T/ipykernel_53826/2559618858.py:26: UserWarning: The API of rouwenhorst has changed from `rouwenhorst(n, ybar, sigma, rho)` to `rouwenhorst(n, rho, sigma, mu=0.)`. To find more details please visit: https://github.com/QuantEcon/QuantEcon.py/issues/663.
#   mc = rouwenhorst(nz, rho, sigma, mu)
# Error at iteration 25 is 0.026931218022500314.
# Error at iteration 50 is 0.0039510781382712246.
# Error at iteration 75 is 0.0008259213532504361.
# Error at iteration 100 is 0.00018087701978553028.
#
# Converged in 110 iterations.
# Total iterations until convergence: 598
# A0:  6.922324838660783
# diff:  -0.0007762812541400876
# loop:  10
# /var/folders/y2/hwl07kg14b31nb5s126cjc8m0000gn/T/ipykernel_53826/2559618858.py:26: UserWarning: The API of rouwenhorst has changed from `rouwenhorst(n, ybar, sigma, rho)` to `rouwenhorst(n, rho, sigma, mu=0.)`. To find more details please visit: https://github.com/QuantEcon/QuantEcon.py/issues/663.
#   mc = rouwenhorst(nz, rho, sigma, mu)
# Error at iteration 25 is 0.0269314085058614.
# Error at iteration 50 is 0.003951208552714469.
# Error at iteration 75 is 0.0008259790828093472.
# Error at iteration 100 is 0.0001808975676058644.
#
# Converged in 110 iterations.
# Total iterations until convergence: 598
# A0:  6.9231254103730535
# diff:  0.00010475889995920085
# loop:  11
# /var/folders/y2/hwl07kg14b31nb5s126cjc8m0000gn/T/ipykernel_53826/2559618858.py:26: UserWarning: The API of rouwenhorst has changed from `rouwenhorst(n, ybar, sigma, rho)` to `rouwenhorst(n, rho, sigma, mu=0.)`. To find more details please visit: https://github.com/QuantEcon/QuantEcon.py/issues/663.
#   mc = rouwenhorst(nz, rho, sigma, mu)
# Error at iteration 25 is 0.026931382800451154.
# Error at iteration 50 is 0.003951190953327188.
# Error at iteration 75 is 0.0008259712920466455.
# Error at iteration 100 is 0.00018089479456762092.
#
# Converged in 110 iterations.
# Total iterations until convergence: 598
# A0:  6.923017355455182
# diff:  -1.4155118143399648e-05
# loop:  12
# /var/folders/y2/hwl07kg14b31nb5s126cjc8m0000gn/T/ipykernel_53826/2559618858.py:26: UserWarning: The API of rouwenhorst has changed from `rouwenhorst(n, ybar, sigma, rho)` to `rouwenhorst(n, rho, sigma, mu=0.)`. To find more details please visit: https://github.com/QuantEcon/QuantEcon.py/issues/663.
#   mc = rouwenhorst(nz, rho, sigma, mu)
# Error at iteration 25 is 0.026931386273793656.
# Error at iteration 50 is 0.00395119333136007.
# Error at iteration 75 is 0.0008259723447348044.
# Error at iteration 100 is 0.00018089516926034221.
#
# Converged in 110 iterations.
# Total iterations until convergence: 598
# A0:  6.923031955605547
# diff:  1.9123253833797094e-06
# loop:  13
# /var/folders/y2/hwl07kg14b31nb5s126cjc8m0000gn/T/ipykernel_53826/2559618858.py:26: UserWarning: The API of rouwenhorst has changed from `rouwenhorst(n, ybar, sigma, rho)` to `rouwenhorst(n, rho, sigma, mu=0.)`. To find more details please visit: https://github.com/QuantEcon/QuantEcon.py/issues/663.
#   mc = rouwenhorst(nz, rho, sigma, mu)
# Error at iteration 25 is 0.026931385804553454.
# Error at iteration 50 is 0.003951193010106824.
# Error at iteration 75 is 0.0008259722025210081.
# Error at iteration 100 is 0.00018089511864038954.
#
# Converged in 110 iterations.
# Total iterations until convergence: 598
# A0:  6.923029983151187
# diff:  -2.583570308800631e-07

# %%
hp

# %%
r0 # 均衡時の金利
# Out:
# np.float64(0.024354916373765217)

# %%
K0d # 均衡時の資本
# Out:
# np.float64(6.923030241508218)

# %%
# 定常分布 sd のプロット
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# メッシュグリッドを作成
X, Y = np.meshgrid(a_grid_sd, hp.z_grid)
Z = sd.T  # データの形状を合わせるため転置（必要なら）

# 3Dプロット
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none')
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=10)

# 軸ラベル
ax.set_xlabel('hp.a_grid (X-axis)')
ax.set_ylabel('hp.z_grid (Y-axis)')
ax.set_zlabel('sd (Z-axis)')
ax.set_title('3D Surface Plot of sd')

plt.show()

# %%
# hp.a_grid と hfun_a[0]のデータフレームを作る
df = pd.DataFrame({
    'x_axis': a_grid_sd,
    'y_axis': hfun_aprime_interp[:, -1]})
# plot
plt.plot('x_axis', 'y_axis', data=df, linestyle='-', marker='o')

# %% [markdown]
# # 12/6の勉強会のコード

# %%
#### 12/06勉強会でのコード

pf = np.zeros((hfun_c.shape[0], hfun_c.shape[1]))
for i in range(hfun_c.shape[0]):
  for j in range(hfun_c.shape[1]):
    pf[i,j] = hp.R * hp.a_grid[i] + hp.z_grid[j] - hfun_c[i,j]


a_grid = hp.a_grid
p = hp.Pz
a_min = -hp.b
a_max = 16


# グリッド設定
m = pf.shape[0]  # 内生的状態変数aのグリッド数 (a1, a2, a3)
n = pf.shape[1]  # 外生的状態変数yのグリッド数 (y_H, y_L)
epsilon = 1e-5  # 収束基準


# 初期分布 f^{(0)}_{i,j}
f = np.full(pf.shape, 1/pf.size)
# f = f.T
# f= f.reshape(6, 1)

f_new = np.zeros((m, n))
#for j in range(n):  #次期のyのindexについて繰り返し
# pf_t = pf.T
# target_a = pf_t.reshape(6, 1)  # 政策関数による次期a



# 定常分布の計算ループ
max_diff = epsilon + 1  # 初期化: epsilon より大きくしてループを開始
iteration = 0

while max_diff >= epsilon:
    f_new = np.zeros((m, n))
    # pf_t = pf.T
    # target_a = pf_t.reshape(6, 1)  # 政策関数による次期a

    for j in range(n):  #今期のyのindexについて繰り返し
        for i in range(m): #今期のaのindexについて繰り返し


          aprime = pf[i,j]

          for k in range(n): #来期のyのindexについて繰り返し

            if aprime <= a_min:
                f_new[0,k] = f_new[0,k] + f[i,j]*p[j,k]
            elif aprime >= a_max:
                f_new[m-1,k] = f_new[m-1,k] + f[i,j]*p[j,k]
            elif (aprime>a_min) and (aprime<a_max):
                l = sum(a_grid<=aprime)
                weight = (aprime-a_grid[l-1]) / (a_grid[l]-a_grid[l-1])
                f_new[l,k] = f_new[l,k] + weight*f[i,j]*p[j,k]
                f_new[l-1,k] =f_new[l-1,k] + (1-weight)*f[i,j]*p[j,k]



    # 収束の確認
    max_diff = np.max(np.abs(f_new - f))
    print(f"Iteration {iteration + 1}: max difference = {max_diff}")

    # 更新
    f = f_new
    iteration += 1

# 最終イタレーション回数の出力
print(f"Total iterations until convergence: {iteration}")

# 定常分布の出力
print("Stationary distribution f_{i,j}:")
print(f)
# Out:
# Iteration 1: max difference = 0.003447920894973263
# Iteration 2: max difference = 0.002601471123817728
# Iteration 3: max difference = 0.0018858240100315723
# Iteration 4: max difference = 0.0011986996381739392
# Iteration 5: max difference = 0.0008224407268961403
# Iteration 6: max difference = 0.0006001964445547002
# Iteration 7: max difference = 0.0004335915398395729
# Iteration 8: max difference = 0.00031013921340649654
# Iteration 9: max difference = 0.00021950349360230163
# Iteration 10: max difference = 0.00024176523163877035
# Iteration 11: max difference = 0.00024918806378158853
# Iteration 12: max difference = 0.00025769894539354535
# Iteration 13: max difference = 0.0002600614089616621
# Iteration 14: max difference = 0.0002563801053594456
# Iteration 15: max difference = 0.0002539643304503899
# Iteration 16: max difference = 0.00024879907132024405
# Iteration 17: max difference = 0.00024247934750921962
# Iteration 18: max difference = 0.00023677324301961053
# Iteration 19: max difference = 0.0002300166150550429
# Iteration 20: max difference = 0.0002233176383736532
# Iteration 21: max difference = 0.00021691516776013373
# Iteration 22: max difference = 0.00021023797862352277
# Iteration 23: max difference = 0.0002038508668376314
# Iteration 24: max difference = 0.00019766081551253999
# Iteration 25: max difference = 0.00019151557650008352
# Iteration 26: max difference = 0.00018565638701762387
# Iteration 27: max difference = 0.00017997269536604212
# Iteration 28: max difference = 0.00017444529063501742
# Iteration 29: max difference = 0.0001691595054259306
# Iteration 30: max difference = 0.00016404382203411005
# Iteration 31: max difference = 0.0001591086619545292
# Iteration 32: max difference = 0.00015437457379772427
# Iteration 33: max difference = 0.00014980290904774343
# Iteration 34: max difference = 0.000145403356231949
# Iteration 35: max difference = 0.00014117371752219235
# Iteration 36: max difference = 0.00013709431361176583
# Iteration 37: max difference = 0.00013316884224013475
# Iteration 38: max difference = 0.0001293893090307599
# Iteration 39: max difference = 0.00012574528592683171
# Iteration 40: max difference = 0.00012223596888202327
# Iteration 41: max difference = 0.00011885334942898697
# Iteration 42: max difference = 0.00011559107404173017
# Iteration 43: max difference = 0.00011244606543457138
# Iteration 44: max difference = 0.00010941171887682028
# Iteration 45: max difference = 0.00010648340888590527
# Iteration 46: max difference = 0.00010365730809217683
# Iteration 47: max difference = 0.00010092820463803928
# Iteration 48: max difference = 9.829227567109081e-05
# Iteration 49: max difference = 9.57457330417414e-05
# Iteration 50: max difference = 9.328442909335103e-05
# Iteration 51: max difference = 9.090502704087004e-05
# Iteration 52: max difference = 8.860409791460432e-05
# Iteration 53: max difference = 8.637825675548647e-05
# Iteration 54: max difference = 8.422455580792913e-05
# Iteration 55: max difference = 8.214000463253098e-05
# Iteration 56: max difference = 8.012177161247774e-05
# Iteration 57: max difference = 7.816726141765366e-05
# Iteration 58: max difference = 7.627389971861815e-05
# Iteration 59: max difference = 7.443927461790126e-05
# Iteration 60: max difference = 7.266111413151317e-05
# Iteration 61: max difference = 7.093720554878901e-05
# Iteration 62: max difference = 6.926547092583847e-05
# Iteration 63: max difference = 6.764392872063516e-05
# Iteration 64: max difference = 6.607067079429348e-05
# Iteration 65: max difference = 6.454389459891428e-05
# Iteration 66: max difference = 6.306187370273223e-05
# Iteration 67: max difference = 6.162295476185844e-05
# Iteration 68: max difference = 6.022556723135749e-05
# Iteration 69: max difference = 5.8868205359805664e-05
# Iteration 70: max difference = 5.754942970808471e-05
# Iteration 71: max difference = 5.626786731855772e-05
# Iteration 72: max difference = 5.5022201834281116e-05
# Iteration 73: max difference = 5.3811174632756135e-05
# Iteration 74: max difference = 5.263358195809441e-05
# Iteration 75: max difference = 5.148826965224035e-05
# Iteration 76: max difference = 5.0374133063815774e-05
# Iteration 77: max difference = 4.929011382416668e-05
# Iteration 78: max difference = 4.823519685148237e-05
# Iteration 79: max difference = 4.720840938666473e-05
# Iteration 80: max difference = 4.6208818252908845e-05
# Iteration 81: max difference = 4.5235527893692975e-05
# Iteration 82: max difference = 4.428767903159013e-05
# Iteration 83: max difference = 4.336444652436192e-05
# Iteration 84: max difference = 4.2465037870795686e-05
# Iteration 85: max difference = 4.158869181790023e-05
# Iteration 86: max difference = 4.073467669768287e-05
# Iteration 87: max difference = 4.052762100116396e-05
# Iteration 88: max difference = 4.0462582668019526e-05
# Iteration 89: max difference = 4.0391976857422074e-05
# Iteration 90: max difference = 4.0315902075684085e-05
# Iteration 91: max difference = 4.0234460053750407e-05
# Iteration 92: max difference = 4.0163970792674725e-05
# Iteration 93: max difference = 4.009437933955376e-05
# Iteration 94: max difference = 4.0019452392969085e-05
# Iteration 95: max difference = 3.99392943676944e-05
# Iteration 96: max difference = 3.985401150004633e-05
# Iteration 97: max difference = 3.976371157923646e-05
# Iteration 98: max difference = 3.966850369522927e-05
# Iteration 99: max difference = 3.956849800244855e-05
# Iteration 100: max difference = 3.946380549849776e-05
# Iteration 101: max difference = 3.9354537817205826e-05
# Iteration 102: max difference = 3.924746944233837e-05
# Iteration 103: max difference = 3.914812062271768e-05
# Iteration 104: max difference = 3.904424246778046e-05
# Iteration 105: max difference = 3.893594360978268e-05
# Iteration 106: max difference = 3.8823332790590553e-05
# Iteration 107: max difference = 3.87065187248143e-05
# Iteration 108: max difference = 3.858560997169018e-05
# Iteration 109: max difference = 3.8460714815479954e-05
# Iteration 110: max difference = 3.8331941153864e-05
# Iteration 111: max difference = 3.819939639397585e-05
# Iteration 112: max difference = 3.806318735578677e-05
# Iteration 113: max difference = 3.792342018229915e-05
# Iteration 114: max difference = 3.778020025637513e-05
# Iteration 115: max difference = 3.763363212379647e-05
# Iteration 116: max difference = 3.7483819422199846e-05
# Iteration 117: max difference = 3.734433630424999e-05
# Iteration 118: max difference = 3.720254924395941e-05
# Iteration 119: max difference = 3.705754851772436e-05
# Iteration 120: max difference = 3.690943314895237e-05
# Iteration 121: max difference = 3.675830119594797e-05
# Iteration 122: max difference = 3.6604249702969216e-05
# Iteration 123: max difference = 3.6447374655241074e-05
# Iteration 124: max difference = 3.6287770937656894e-05
# Iteration 125: max difference = 3.6125532297122745e-05
# Iteration 126: max difference = 3.5960751308244596e-05
# Iteration 127: max difference = 3.579351934223339e-05
# Iteration 128: max difference = 3.562392653891182e-05
# Iteration 129: max difference = 3.545206178159552e-05
# Iteration 130: max difference = 3.5278012674723816e-05
# Iteration 131: max difference = 3.510186552412552e-05
# Iteration 132: max difference = 3.492370531974799e-05
# Iteration 133: max difference = 3.474361572073162e-05
# Iteration 134: max difference = 3.456167904268906e-05
# Iteration 135: max difference = 3.43823900438231e-05
# Iteration 136: max difference = 3.4206959654340535e-05
# Iteration 137: max difference = 3.402969488198494e-05
# Iteration 138: max difference = 3.385067425736715e-05
# Iteration 139: max difference = 3.3669975031430655e-05
# Iteration 140: max difference = 3.34876731679732e-05
# Iteration 141: max difference = 3.33038433377366e-05
# Iteration 142: max difference = 3.311855891411156e-05
# Iteration 143: max difference = 3.293189197018341e-05
# Iteration 144: max difference = 3.274391327722642e-05
# Iteration 145: max difference = 3.261671326053317e-05
# Iteration 146: max difference = 3.249889558845122e-05
# Iteration 147: max difference = 3.237829021916945e-05
# Iteration 148: max difference = 3.22549767939051e-05
# Iteration 149: max difference = 3.2129034307548654e-05
# Iteration 150: max difference = 3.2000541074087355e-05
# Iteration 151: max difference = 3.186957469394382e-05
# Iteration 152: max difference = 3.1736212023245405e-05
# Iteration 153: max difference = 3.1600529144935885e-05
# Iteration 154: max difference = 3.146260134172241e-05
# Iteration 155: max difference = 3.132250307080406e-05
# Iteration 156: max difference = 3.118030794032646e-05
# Iteration 157: max difference = 3.103608868755027e-05
# Iteration 158: max difference = 3.088991715864339e-05
# Iteration 159: max difference = 3.074186429009515e-05
# Iteration 160: max difference = 3.0592000091651805e-05
# Iteration 161: max difference = 3.044039363078732e-05
# Iteration 162: max difference = 3.028711301860526e-05
# Iteration 163: max difference = 3.0132225397149284e-05
# Iteration 164: max difference = 2.9975796928082346e-05
# Iteration 165: max difference = 2.981789278265999e-05
# Iteration 166: max difference = 2.9658577132964797e-05
# Iteration 167: max difference = 2.949791314436727e-05
# Iteration 168: max difference = 2.9335962969140317e-05
# Iteration 169: max difference = 2.9172787741183967e-05
# Iteration 170: max difference = 2.9008447571836002e-05
# Iteration 171: max difference = 2.8843001546718233e-05
# Iteration 172: max difference = 2.8676507723542077e-05
# Iteration 173: max difference = 2.8509023130866493e-05
# Iteration 174: max difference = 2.8340603767761444e-05
# Iteration 175: max difference = 2.8171304604305766e-05
# Iteration 176: max difference = 2.8001179582933314e-05
# Iteration 177: max difference = 2.7830281620511155e-05
# Iteration 178: max difference = 2.765866261119493e-05
# Iteration 179: max difference = 2.7486373429950334e-05
# Iteration 180: max difference = 2.7313463936778914e-05
# Iteration 181: max difference = 2.713998298151457e-05
# Iteration 182: max difference = 2.696597840927059e-05
# Iteration 183: max difference = 2.679149706640016e-05
# Iteration 184: max difference = 2.6616584807018923e-05
# Iteration 185: max difference = 2.644128649999765e-05
# Iteration 186: max difference = 2.6265646036430224e-05
# Iteration 187: max difference = 2.6089706337549187e-05
# Iteration 188: max difference = 2.5913509363026388e-05
# Iteration 189: max difference = 2.573709611967262e-05
# Iteration 190: max difference = 2.5560506670484207e-05
# Iteration 191: max difference = 2.538378014402265e-05
# Iteration 192: max difference = 2.5206954744089183e-05
# Iteration 193: max difference = 2.5030067759697697e-05
# Iteration 194: max difference = 2.485315557529226e-05
# Iteration 195: max difference = 2.4676253681210972e-05
# Iteration 196: max difference = 2.449939668435104e-05
# Iteration 197: max difference = 2.432261831905591e-05
# Iteration 198: max difference = 2.4145951458153306e-05
# Iteration 199: max difference = 2.396942812417542e-05
# Iteration 200: max difference = 2.379307950069881e-05
# Iteration 201: max difference = 2.3616935943828257e-05
# Iteration 202: max difference = 2.344102699378646e-05
# Iteration 203: max difference = 2.3265381386580047e-05
# Iteration 204: max difference = 2.309002706576274e-05
# Iteration 205: max difference = 2.2914991194266168e-05
# Iteration 206: max difference = 2.2740300166268837e-05
# Iteration 207: max difference = 2.2565979619108487e-05
# Iteration 208: max difference = 2.23920544452378e-05
# Iteration 209: max difference = 2.2218548804166238e-05
# Iteration 210: max difference = 2.2045486134440045e-05
# Iteration 211: max difference = 2.187288916559449e-05
# Iteration 212: max difference = 2.1700779930095698e-05
# Iteration 213: max difference = 2.1529179775273827e-05
# Iteration 214: max difference = 2.135810937519897e-05
# Iteration 215: max difference = 2.1187588742548405e-05
# Iteration 216: max difference = 2.1017637240383635e-05
# Iteration 217: max difference = 2.0848273593918748e-05
# Iteration 218: max difference = 2.06795159021899e-05
# Iteration 219: max difference = 2.0511381649674504e-05
# Iteration 220: max difference = 2.034388771783059e-05
# Iteration 221: max difference = 2.0177050396556415e-05
# Iteration 222: max difference = 2.0010885395559813e-05
# Iteration 223: max difference = 1.9845407855654737e-05
# Iteration 224: max difference = 1.96806323599346e-05
# Iteration 225: max difference = 1.9516572944872773e-05
# Iteration 226: max difference = 1.9353243111294716e-05
# Iteration 227: max difference = 1.9190655835273768e-05
# Iteration 228: max difference = 1.902882357888644e-05
# Iteration 229: max difference = 1.886775830087402e-05
# Iteration 230: max difference = 1.870747146717408e-05
# Iteration 231: max difference = 1.8547974061358316e-05
# Iteration 232: max difference = 1.838927659490383e-05
# Iteration 233: max difference = 1.8231389117393318e-05
# Iteration 234: max difference = 1.8074321226560844e-05
# Iteration 235: max difference = 1.7918082078200587e-05
# Iteration 236: max difference = 1.7762680395981903e-05
# Iteration 237: max difference = 1.7608124481103063e-05
# Iteration 238: max difference = 1.7454422221833965e-05
# Iteration 239: max difference = 1.7301581102911398e-05
# Iteration 240: max difference = 1.7149608214821546e-05
# Iteration 241: max difference = 1.699851026292984e-05
# Iteration 242: max difference = 1.68482935764859e-05
# Iteration 243: max difference = 1.6698964117501866e-05
# Iteration 244: max difference = 1.6550527489472833e-05
# Iteration 245: max difference = 1.640298894600191e-05
# Iteration 246: max difference = 1.625635339925352e-05
# Iteration 247: max difference = 1.6110625428285286e-05
# Iteration 248: max difference = 1.5965809287258464e-05
# Iteration 249: max difference = 1.582190891349748e-05
# Iteration 250: max difference = 1.567892793543149e-05
# Iteration 251: max difference = 1.553686968038155e-05
# Iteration 252: max difference = 1.5395737182241978e-05
# Iteration 253: max difference = 1.525553318901772e-05
# Iteration 254: max difference = 1.5116260170226423e-05
# Iteration 255: max difference = 1.497792032417386e-05
# Iteration 256: max difference = 1.4840515585118341e-05
# Iteration 257: max difference = 1.470404763026685e-05
# Iteration 258: max difference = 1.456851788669139e-05
# Iteration 259: max difference = 1.4433927538078789e-05
# Iteration 260: max difference = 1.4300277531392042e-05
# Iteration 261: max difference = 1.416756858337899e-05
# Iteration 262: max difference = 1.4035801186964778e-05
# Iteration 263: max difference = 1.3904975617540227e-05
# Iteration 264: max difference = 1.3775091939101022e-05
# Iteration 265: max difference = 1.3646150010307098e-05
# Iteration 266: max difference = 1.3518149490378967e-05
# Iteration 267: max difference = 1.3391089844914245e-05
# Iteration 268: max difference = 1.3264970351574076e-05
# Iteration 269: max difference = 1.3139790105651597e-05
# Iteration 270: max difference = 1.3015548025548454e-05
# Iteration 271: max difference = 1.2892242858110817e-05
# Iteration 272: max difference = 1.2769873183882119e-05
# Iteration 273: max difference = 1.264843742223784e-05
# Iteration 274: max difference = 1.2527933836412736e-05
# Iteration 275: max difference = 1.240836053842398e-05
# Iteration 276: max difference = 1.2289715493893696e-05
# Iteration 277: max difference = 1.2171996526767412e-05
# Iteration 278: max difference = 1.2055201323930148e-05
# Iteration 279: max difference = 1.1939327439730585e-05
# Iteration 280: max difference = 1.182437230039593e-05
# Iteration 281: max difference = 1.1710333208363524e-05
# Iteration 282: max difference = 1.1597207346508362e-05
# Iteration 283: max difference = 1.1484991782282142e-05
# Iteration 284: max difference = 1.1373683471758642e-05
# Iteration 285: max difference = 1.1263279263590623e-05
# Iteration 286: max difference = 1.1153775902879998e-05
# Iteration 287: max difference = 1.104517003494565e-05
# Iteration 288: max difference = 1.0937458209037479e-05
# Iteration 289: max difference = 1.0830636881923802e-05
# Iteration 290: max difference = 1.0724702421435403e-05
# Iteration 291: max difference = 1.0619651109903747e-05
# Iteration 292: max difference = 1.0515479147522877e-05
# Iteration 293: max difference = 1.0412182655640187e-05
# Iteration 294: max difference = 1.0309757679958717e-05
# Iteration 295: max difference = 1.0208200193677006e-05
# Iteration 296: max difference = 1.0107506100545671e-05
# Iteration 297: max difference = 1.0007671237842464e-05
# Iteration 298: max difference = 9.908691379297008e-06
# Total iterations until convergence: 298
# Stationary distribution f_{i,j}:
# [[1.18734020e-02 3.64738492e-03]
#  [8.83842710e-03 2.87114534e-03]
#  [9.94005937e-03 5.70081445e-03]
#  [1.04335767e-02 5.71656610e-03]
#  [1.14502384e-02 7.67474896e-03]
#  [1.13401703e-02 8.02703431e-03]
#  [1.19168499e-02 9.26432129e-03]
#  [1.23673746e-02 9.86869807e-03]
#  [1.28187318e-02 1.07186137e-02]
#  [1.31500178e-02 1.13162015e-02]
#  [1.34272628e-02 1.19219092e-02]
#  [1.36179658e-02 1.23998002e-02]
#  [1.37420553e-02 1.28157908e-02]
#  [1.37948640e-02 1.31398817e-02]
#  [1.37843182e-02 1.33883441e-02]
#  [1.37133065e-02 1.35580188e-02]
#  [1.35874060e-02 1.36552638e-02]
#  [1.34113564e-02 1.36833320e-02]
#  [1.31903856e-02 1.36473995e-02]
#  [1.29295462e-02 1.35523660e-02]
#  [1.26338690e-02 1.34035429e-02]
#  [1.23082165e-02 1.32062477e-02]
#  [1.19572658e-02 1.29658248e-02]
#  [1.15854593e-02 1.26875296e-02]
#  [1.11969789e-02 1.23764776e-02]
#  [1.07957251e-02 1.20375878e-02]
#  [1.03853033e-02 1.16755420e-02]
#  [9.96901764e-03 1.12947533e-02]
#  [9.54986960e-03 1.08993433e-02]
#  [9.13056116e-03 1.04931273e-02]
#  [8.71350214e-03 1.00796065e-02]
#  [8.30082044e-03 9.66196603e-03]
#  [7.89437461e-03 9.24307763e-03]
#  [7.49576838e-03 8.82550710e-03]
#  [7.10636635e-03 8.41152452e-03]
#  [6.72731057e-03 8.00311725e-03]
#  [6.35953757e-03 7.60200493e-03]
#  [6.00379548e-03 7.20965578e-03]
#  [5.66066100e-03 6.82730393e-03]
#  [5.33055599e-03 6.45596717e-03]
#  [5.01376351e-03 6.09646484e-03]
#  [4.71044314e-03 5.74943565e-03]
#  [4.42064550e-03 5.41535498e-03]
#  [4.14432597e-03 5.09455175e-03]
#  [3.88135734e-03 4.78722447e-03]
#  [3.63154173e-03 4.49345644e-03]
#  [3.39462133e-03 4.21323014e-03]
#  [3.17028845e-03 3.94644056e-03]
#  [2.95819441e-03 3.69290761e-03]
#  [2.75795778e-03 3.45238748e-03]
#  [2.56917159e-03 3.22458309e-03]
#  [2.39140990e-03 3.00915355e-03]
#  [2.22423346e-03 2.80572264e-03]
#  [2.06719486e-03 2.61388655e-03]
#  [1.91984278e-03 2.43322063e-03]
#  [1.78172601e-03 2.26328547e-03]
#  [1.65239640e-03 2.10363215e-03]
#  [1.53141209e-03 1.95380696e-03]
#  [1.41833912e-03 1.81335526e-03]
#  [1.31275434e-03 1.68182510e-03]
#  [1.21424552e-03 1.55876986e-03]
#  [1.12241466e-03 1.44375110e-03]
#  [1.03687592e-03 1.33633998e-03]
#  [9.57260645e-04 1.23611978e-03]
#  [8.83211624e-04 1.14268590e-03]
#  [8.14392249e-04 1.05564878e-03]
#  [7.50474019e-04 9.74631882e-04]
#  [6.91154421e-04 8.99276174e-04]
#  [6.36131480e-04 8.29234815e-04]
#  [5.85139239e-04 7.64181253e-04]
#  [5.37897242e-04 7.03798083e-04]
#  [4.94180533e-04 6.47792519e-04]
#  [4.53720876e-04 5.95874443e-04]
#  [4.16343347e-04 5.47786318e-04]
#  [3.81775394e-04 5.03260922e-04]
#  [3.49910203e-04 4.62078852e-04]
#  [3.20441529e-04 4.23988175e-04]
#  [2.93365684e-04 3.88813796e-04]
#  [2.68290265e-04 3.56306216e-04]
#  [2.45380653e-04 3.26347265e-04]
#  [2.24064256e-04 2.98667956e-04]
#  [2.04797250e-04 2.73231537e-04]
#  [1.86658276e-04 2.49711563e-04]
#  [1.70615907e-04 2.28198636e-04]
#  [1.55098214e-04 2.08242290e-04]
#  [1.41985981e-04 1.90144818e-04]
#  [1.28517152e-04 1.73213953e-04]
#  [1.18202649e-04 1.58117004e-04]
#  [1.06125232e-04 1.43709680e-04]
#  [9.87149784e-05 1.31302713e-04]
#  [8.71662691e-05 1.18920380e-04]
#  [8.31556037e-05 1.09026316e-04]
#  [7.08454886e-05 9.81169344e-05]
#  [7.14156306e-05 9.07578491e-05]
#  [5.61916223e-05 8.06059655e-05]
#  [6.38226454e-05 7.61499347e-05]
#  [4.17605472e-05 6.56425803e-05]
#  [6.15742298e-05 6.51453258e-05]
#  [2.49265312e-05 5.22260968e-05]
#  [6.78628227e-05 2.20915146e-04]]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# 消費の政策関数をプロット
df = pd.DataFrame({
    'x_axis': hp.a_grid,
    'y_axis': np.sum(f,axis=1)})
# plot
plt.plot('x_axis', 'y_axis', data=df, linestyle='-', marker='o')
plt.xlabel('Current asset: a_t')
plt.ylabel('Propotion')
# plt.legend([""])
plt.show()

# %%
for l in range(2):     # iteration over employment types in period t
    # prepare interpolation of optimal next-period asset policy
    aopt_polate = interpolate.interp1d(a_grid_pf,pf[:,l])
    for i in range(nk):  # iteration over assets in period t
        if k1 <= amin:
            gk[0,0] = gk[0,0] + gk0[i,l]*prob[l,0]
            gk[0,1]= gk[0,1] + gk0[i,l]*prob[l,1]
        elif k1 >= amax:
            gk[nk-1,0] = gk[nk-1,0] + gk0[i,l]*prob[l,0]
            gk[nk-1,1] = gk[nk-1,1] + gk0[i,l]*prob[l,1]
        elif (k1>amin) and (k1<amax):
            j = sum(a_grid<=k1) # k1 lies between ag[j-1] and ag[j]
            n0 = (k1-a_grid[j-1]) / (a_grid[j]-a_grid[j-1])
            gk[j,0] = gk[j,0] + n0*gk0[i,l]*prob[l,0]
            gk[j,1] = gk[j,1] + n0*gk0[i,l]*prob[l,1]
            gk[j-1,0] =gk[j-1,0] + (1-n0)*gk0[i,l]*prob[l,0]
            gk[j-1,1] =gk[j-1,1] + (1-n0)*gk0[i,l]*prob[l,1]

# %%
import numpy as np

pf_grid = np.array([[20, -48], [32, 15], [144, 27]])
a_grid = np.array([12, 24, 36])
sd_grid = np.full((3, 2), 1/6)
Pmatrix = np.array([[0.9, 0.1], [0.1, 0.9]])

solve_stationary_dist(pf_grid, a_grid, sd_grid, Pmatrix)
# Out:
# Iteration 1: diff = <object type:float64>
# Iteration 2: diff = <object type:float64>
# Iteration 3: diff = <object type:float64>
# Iteration 4: diff = <object type:float64>
# Iteration 5: diff = <object type:float64>
# Iteration 6: diff = <object type:float64>
# Iteration 7: diff = <object type:float64>
# Iteration 8: diff = <object type:float64>
# Iteration 9: diff = <object type:float64>
# Iteration 10: diff = <object type:float64>
# Iteration 11: diff = <object type:float64>
# Iteration 12: diff = <object type:float64>
# Iteration 13: diff = <object type:float64>
# Iteration 14: diff = <object type:float64>
# Iteration 15: diff = <object type:float64>
# Iteration 16: diff = <object type:float64>
# Iteration 17: diff = <object type:float64>
# Iteration 18: diff = <object type:float64>
# Iteration 19: diff = <object type:float64>
# Iteration 20: diff = <object type:float64>
# Iteration 21: diff = <object type:float64>
# Iteration 22: diff = <object type:float64>
# Iteration 23: diff = <object type:float64>
# Iteration 24: diff = <object type:float64>
# Iteration 25: diff = <object type:float64>
# Iteration 26: diff = <object type:float64>
# Iteration 27: diff = <object type:float64>
# Iteration 28: diff = <object type:float64>
# Iteration 29: diff = <object type:float64>
# Iteration 30: diff = <object type:float64>
# Iteration 31: diff = <object type:float64>
# Iteration 32: diff = <object type:float64>
# Iteration 33: diff = <object type:float64>
# Iteration 34: diff = <object type:float64>
# Iteration 35: diff = <object type:float64>
# Iteration 36: diff = <object type:float64>
# Iteration 37: diff = <object type:float64>
# Iteration 38: diff = <object type:float64>
# Iteration 39: diff = <object type:float64>
# Iteration 40: diff = <object type:float64>
# Iteration 41: diff = <object type:float64>
# Iteration 42: diff = <object type:float64>
# Iteration 43: diff = <object type:float64>
# Iteration 44: diff = <object type:float64>
# Iteration 45: diff = <object type:float64>
# Iteration 46: diff = <object type:float64>
# Iteration 47: diff = <object type:float64>
# Iteration 48: diff = <object type:float64>
# Iteration 49: diff = <object type:float64>
# Iteration 50: diff = <object type:float64>
# Iteration 51: diff = <object type:float64>
# Iteration 52: diff = <object type:float64>
# Iteration 53: diff = <object type:float64>
# Iteration 54: diff = <object type:float64>
# Iteration 55: diff = <object type:float64>
# Iteration 56: diff = <object type:float64>
# Iteration 57: diff = <object type:float64>
# Iteration 58: diff = <object type:float64>
# Iteration 59: diff = <object type:float64>
# Iteration 60: diff = <object type:float64>
# Iteration 61: diff = <object type:float64>
# Iteration 62: diff = <object type:float64>
# Iteration 63: diff = <object type:float64>
# Iteration 64: diff = <object type:float64>
# Iteration 65: diff = <object type:float64>
# Iteration 66: diff = <object type:float64>
# Iteration 67: diff = <object type:float64>
# Iteration 68: diff = <object type:float64>
# Iteration 69: diff = <object type:float64>
# Iteration 70: diff = <object type:float64>
# Iteration 71: diff = <object type:float64>
# Iteration 72: diff = <object type:float64>
# Iteration 73: diff = <object type:float64>
# Iteration 74: diff = <object type:float64>
# Iteration 75: diff = <object type:float64>
# Iteration 76: diff = <object type:float64>
# Iteration 77: diff = <object type:float64>
# Iteration 78: diff = <object type:float64>
# Iteration 79: diff = <object type:float64>
# Iteration 80: diff = <object type:float64>
# Iteration 81: diff = <object type:float64>
# Iteration 82: diff = <object type:float64>
# Iteration 83: diff = <object type:float64>
# Iteration 84: diff = <object type:float64>
# Iteration 85: diff = <object type:float64>
# Iteration 86: diff = <object type:float64>
# Iteration 87: diff = <object type:float64>
# Iteration 88: diff = <object type:float64>
# Iteration 89: diff = <object type:float64>
# Iteration 90: diff = <object type:float64>
# Iteration 91: diff = <object type:float64>
# Iteration 92: diff = <object type:float64>
# Iteration 93: diff = <object type:float64>
# Iteration 94: diff = <object type:float64>
# Iteration 95: diff = <object type:float64>
# Iteration 96: diff = <object type:float64>
# Iteration 97: diff = <object type:float64>
# Iteration 98: diff = <object type:float64>
# Iteration 99: diff = <object type:float64>
# Iteration 100: diff = <object type:float64>
# Iteration 101: diff = <object type:float64>
# Iteration 102: diff = <object type:float64>
# Iteration 103: diff = <object type:float64>
# Iteration 104: diff = <object type:float64>
# Iteration 105: diff = <object type:float64>
# Iteration 106: diff = <object type:float64>
# Iteration 107: diff = <object type:float64>
# Iteration 108: diff = <object type:float64>
# Iteration 109: diff = <object type:float64>
# Iteration 110: diff = <object type:float64>
# Iteration 111: diff = <object type:float64>
# Iteration 112: diff = <object type:float64>
# Iteration 113: diff = <object type:float64>
# Iteration 114: diff = <object type:float64>
# Iteration 115: diff = <object type:float64>
# Iteration 116: diff = <object type:float64>
# Iteration 117: diff = <object type:float64>
# Iteration 118: diff = <object type:float64>
# Iteration 119: diff = <object type:float64>
# Iteration 120: diff = <object type:float64>
# Iteration 121: diff = <object type:float64>
# Iteration 122: diff = <object type:float64>
# Iteration 123: diff = <object type:float64>
# Iteration 124: diff = <object type:float64>
# Iteration 125: diff = <object type:float64>
# Iteration 126: diff = <object type:float64>
# Iteration 127: diff = <object type:float64>
# Iteration 128: diff = <object type:float64>
# Iteration 129: diff = <object type:float64>
# Iteration 130: diff = <object type:float64>
# Iteration 131: diff = <object type:float64>
# Iteration 132: diff = <object type:float64>
# Iteration 133: diff = <object type:float64>
# Iteration 134: diff = <object type:float64>
# Iteration 135: diff = <object type:float64>
# Iteration 136: diff = <object type:float64>
# Iteration 137: diff = <object type:float64>
# Iteration 138: diff = <object type:float64>
# Iteration 139: diff = <object type:float64>
# Iteration 140: diff = <object type:float64>
# Iteration 141: diff = <object type:float64>
# Iteration 142: diff = <object type:float64>
# Iteration 143: diff = <object type:float64>
# Iteration 144: diff = <object type:float64>
# Iteration 145: diff = <object type:float64>
# Iteration 146: diff = <object type:float64>
# Iteration 147: diff = <object type:float64>
# Iteration 148: diff = <object type:float64>
# Iteration 149: diff = <object type:float64>
# Iteration 150: diff = <object type:float64>
# Iteration 151: diff = <object type:float64>
# Iteration 152: diff = <object type:float64>
# Iteration 153: diff = <object type:float64>
# Iteration 154: diff = <object type:float64>
# Iteration 155: diff = <object type:float64>
# Iteration 156: diff = <object type:float64>
# Iteration 157: diff = <object type:float64>
# Iteration 158: diff = <object type:float64>
# Iteration 159: diff = <object type:float64>
# Iteration 160: diff = <object type:float64>
# Iteration 161: diff = <object type:float64>
# Iteration 162: diff = <object type:float64>
# Iteration 163: diff = <object type:float64>
# Iteration 164: diff = <object type:float64>
# Iteration 165: diff = <object type:float64>
# Iteration 166: diff = <object type:float64>
# Iteration 167: diff = <object type:float64>
# Iteration 168: diff = <object type:float64>
# Iteration 169: diff = <object type:float64>
# Iteration 170: diff = <object type:float64>
# Iteration 171: diff = <object type:float64>
# Iteration 172: diff = <object type:float64>
# Iteration 173: diff = <object type:float64>
# Iteration 174: diff = <object type:float64>
# Iteration 175: diff = <object type:float64>
# Iteration 176: diff = <object type:float64>
# Iteration 177: diff = <object type:float64>
# Iteration 178: diff = <object type:float64>
# Iteration 179: diff = <object type:float64>
# Iteration 180: diff = <object type:float64>
# Iteration 181: diff = <object type:float64>
# Iteration 182: diff = <object type:float64>
# Iteration 183: diff = <object type:float64>
# Iteration 184: diff = <object type:float64>
# Iteration 185: diff = <object type:float64>
# Iteration 186: diff = <object type:float64>
# Iteration 187: diff = <object type:float64>
# Iteration 188: diff = <object type:float64>
# Iteration 189: diff = <object type:float64>
# Iteration 190: diff = <object type:float64>
# Iteration 191: diff = <object type:float64>
# Iteration 192: diff = <object type:float64>
# Iteration 193: diff = <object type:float64>
# Iteration 194: diff = <object type:float64>
# Iteration 195: diff = <object type:float64>
# Iteration 196: diff = <object type:float64>
# Iteration 197: diff = <object type:float64>
# Iteration 198: diff = <object type:float64>
# Iteration 199: diff = <object type:float64>
# Iteration 200: diff = <object type:float64>
# Iteration 201: diff = <object type:float64>
# Iteration 202: diff = <object type:float64>
# Iteration 203: diff = <object type:float64>
# Iteration 204: diff = <object type:float64>
# Iteration 205: diff = <object type:float64>
# Iteration 206: diff = <object type:float64>
# Iteration 207: diff = <object type:float64>
# Iteration 208: diff = <object type:float64>
# Iteration 209: diff = <object type:float64>
# Iteration 210: diff = <object type:float64>
# Iteration 211: diff = <object type:float64>
# Iteration 212: diff = <object type:float64>
# Iteration 213: diff = <object type:float64>
# Iteration 214: diff = <object type:float64>
# Iteration 215: diff = <object type:float64>
# Iteration 216: diff = <object type:float64>
# Iteration 217: diff = <object type:float64>
# Iteration 218: diff = <object type:float64>
# Iteration 219: diff = <object type:float64>
# Iteration 220: diff = <object type:float64>
# Iteration 221: diff = <object type:float64>
# Iteration 222: diff = <object type:float64>
# Iteration 223: diff = <object type:float64>
# Iteration 224: diff = <object type:float64>
# Iteration 225: diff = <object type:float64>
# Iteration 226: diff = <object type:float64>
# Iteration 227: diff = <object type:float64>
# Iteration 228: diff = <object type:float64>
# Iteration 229: diff = <object type:float64>
# Iteration 230: diff = <object type:float64>
# Iteration 231: diff = <object type:float64>
# Iteration 232: diff = <object type:float64>
# Iteration 233: diff = <object type:float64>
# Iteration 234: diff = <object type:float64>
# Iteration 235: diff = <object type:float64>
# Iteration 236: diff = <object type:float64>
# Iteration 237: diff = <object type:float64>
# Iteration 238: diff = <object type:float64>
# Iteration 239: diff = <object type:float64>
# Iteration 240: diff = <object type:float64>
# Iteration 241: diff = <object type:float64>
# Iteration 242: diff = <object type:float64>
# Iteration 243: diff = <object type:float64>
# Iteration 244: diff = <object type:float64>
# Iteration 245: diff = <object type:float64>
# Iteration 246: diff = <object type:float64>
# Iteration 247: diff = <object type:float64>
# Iteration 248: diff = <object type:float64>
# Iteration 249: diff = <object type:float64>
# Iteration 250: diff = <object type:float64>
# Iteration 251: diff = <object type:float64>
# Iteration 252: diff = <object type:float64>
# Iteration 253: diff = <object type:float64>
# Iteration 254: diff = <object type:float64>
# Iteration 255: diff = <object type:float64>
# Iteration 256: diff = <object type:float64>
# Iteration 257: diff = <object type:float64>
# Iteration 258: diff = <object type:float64>
# Iteration 259: diff = <object type:float64>
# Iteration 260: diff = <object type:float64>
# Iteration 261: diff = <object type:float64>
# Iteration 262: diff = <object type:float64>
# Iteration 263: diff = <object type:float64>
# Iteration 264: diff = <object type:float64>
# Iteration 265: diff = <object type:float64>
# Iteration 266: diff = <object type:float64>
# Iteration 267: diff = <object type:float64>
# Iteration 268: diff = <object type:float64>
# Iteration 269: diff = <object type:float64>
# Iteration 270: diff = <object type:float64>
# Iteration 271: diff = <object type:float64>
# Iteration 272: diff = <object type:float64>
# Iteration 273: diff = <object type:float64>
# Iteration 274: diff = <object type:float64>
# Iteration 275: diff = <object type:float64>
# Iteration 276: diff = <object type:float64>
# Iteration 277: diff = <object type:float64>
# Iteration 278: diff = <object type:float64>
# Iteration 279: diff = <object type:float64>
# Iteration 280: diff = <object type:float64>
# Iteration 281: diff = <object type:float64>
# Iteration 282: diff = <object type:float64>
# Iteration 283: diff = <object type:float64>
# Iteration 284: diff = <object type:float64>
# Iteration 285: diff = <object type:float64>
# Iteration 286: diff = <object type:float64>
# Iteration 287: diff = <object type:float64>
# Iteration 288: diff = <object type:float64>
# Iteration 289: diff = <object type:float64>
# Iteration 290: diff = <object type:float64>
# Iteration 291: diff = <object type:float64>
# Iteration 292: diff = <object type:float64>
# Iteration 293: diff = <object type:float64>
# Iteration 294: diff = <object type:float64>
# Iteration 295: diff = <object type:float64>
# Iteration 296: diff = <object type:float64>
# Iteration 297: diff = <object type:float64>
# Iteration 298: diff = <object type:float64>
# Iteration 299: diff = <object type:float64>
# Iteration 300: diff = <object type:float64>
# Iteration 301: diff = <object type:float64>
# Iteration 302: diff = <object type:float64>
# Iteration 303: diff = <object type:float64>
# Iteration 304: diff = <object type:float64>
# Iteration 305: diff = <object type:float64>
# Iteration 306: diff = <object type:float64>
# Iteration 307: diff = <object type:float64>
# Iteration 308: diff = <object type:float64>
# Iteration 309: diff = <object type:float64>
# Iteration 310: diff = <object type:float64>
# Iteration 311: diff = <object type:float64>
# Iteration 312: diff = <object type:float64>
# Iteration 313: diff = <object type:float64>
# Iteration 314: diff = <object type:float64>
# Iteration 315: diff = <object type:float64>
# Iteration 316: diff = <object type:float64>
# Iteration 317: diff = <object type:float64>
# Iteration 318: diff = <object type:float64>
# Iteration 319: diff = <object type:float64>
# Iteration 320: diff = <object type:float64>
# Iteration 321: diff = <object type:float64>
# Iteration 322: diff = <object type:float64>
# Iteration 323: diff = <object type:float64>
# Iteration 324: diff = <object type:float64>
# Iteration 325: diff = <object type:float64>
# Iteration 326: diff = <object type:float64>
# Iteration 327: diff = <object type:float64>
# Iteration 328: diff = <object type:float64>
# Iteration 329: diff = <object type:float64>
# Iteration 330: diff = <object type:float64>
# Iteration 331: diff = <object type:float64>
# Iteration 332: diff = <object type:float64>
# Iteration 333: diff = <object type:float64>
# Iteration 334: diff = <object type:float64>
# Iteration 335: diff = <object type:float64>
# Iteration 336: diff = <object type:float64>
# Iteration 337: diff = <object type:float64>
# Iteration 338: diff = <object type:float64>
# Iteration 339: diff = <object type:float64>
# Iteration 340: diff = <object type:float64>
# Iteration 341: diff = <object type:float64>
# Iteration 342: diff = <object type:float64>
# Iteration 343: diff = <object type:float64>
# Iteration 344: diff = <object type:float64>
# Iteration 345: diff = <object type:float64>
# Iteration 346: diff = <object type:float64>
# Iteration 347: diff = <object type:float64>
# Iteration 348: diff = <object type:float64>
# Iteration 349: diff = <object type:float64>
# Iteration 350: diff = <object type:float64>
# Iteration 351: diff = <object type:float64>
# Iteration 352: diff = <object type:float64>
# Iteration 353: diff = <object type:float64>
# Iteration 354: diff = <object type:float64>
# Iteration 355: diff = <object type:float64>
# Iteration 356: diff = <object type:float64>
# Iteration 357: diff = <object type:float64>
# Iteration 358: diff = <object type:float64>
# Iteration 359: diff = <object type:float64>
# Iteration 360: diff = <object type:float64>
# Iteration 361: diff = <object type:float64>
# Iteration 362: diff = <object type:float64>
# Iteration 363: diff = <object type:float64>
# Iteration 364: diff = <object type:float64>
# Iteration 365: diff = <object type:float64>
# Iteration 366: diff = <object type:float64>
# Iteration 367: diff = <object type:float64>
# Iteration 368: diff = <object type:float64>
# Iteration 369: diff = <object type:float64>
# Iteration 370: diff = <object type:float64>
# Iteration 371: diff = <object type:float64>
# Iteration 372: diff = <object type:float64>
# Iteration 373: diff = <object type:float64>
# Iteration 374: diff = <object type:float64>
# Iteration 375: diff = <object type:float64>
# Iteration 376: diff = <object type:float64>
# Iteration 377: diff = <object type:float64>
# Iteration 378: diff = <object type:float64>
# Iteration 379: diff = <object type:float64>
# Iteration 380: diff = <object type:float64>
# Iteration 381: diff = <object type:float64>
# Iteration 382: diff = <object type:float64>
# Iteration 383: diff = <object type:float64>
# Iteration 384: diff = <object type:float64>
# Iteration 385: diff = <object type:float64>
# Iteration 386: diff = <object type:float64>
# Iteration 387: diff = <object type:float64>
# Iteration 388: diff = <object type:float64>
# Iteration 389: diff = <object type:float64>
# Iteration 390: diff = <object type:float64>
# Iteration 391: diff = <object type:float64>
# Iteration 392: diff = <object type:float64>
# Iteration 393: diff = <object type:float64>
# Iteration 394: diff = <object type:float64>
# Iteration 395: diff = <object type:float64>
# Iteration 396: diff = <object type:float64>
# Iteration 397: diff = <object type:float64>
# Iteration 398: diff = <object type:float64>
# Iteration 399: diff = <object type:float64>
# Iteration 400: diff = <object type:float64>
# Iteration 401: diff = <object type:float64>
# Iteration 402: diff = <object type:float64>
# Iteration 403: diff = <object type:float64>
# Iteration 404: diff = <object type:float64>
# Iteration 405: diff = <object type:float64>
# Iteration 406: diff = <object type:float64>
# Iteration 407: diff = <object type:float64>
# Iteration 408: diff = <object type:float64>
# Iteration 409: diff = <object type:float64>
# Iteration 410: diff = <object type:float64>
# Iteration 411: diff = <object type:float64>
# Iteration 412: diff = <object type:float64>
# Iteration 413: diff = <object type:float64>
# Iteration 414: diff = <object type:float64>
# Iteration 415: diff = <object type:float64>
# Iteration 416: diff = <object type:float64>
# Iteration 417: diff = <object type:float64>
# Iteration 418: diff = <object type:float64>
# Iteration 419: diff = <object type:float64>
# Iteration 420: diff = <object type:float64>
# Iteration 421: diff = <object type:float64>
# Iteration 422: diff = <object type:float64>
# Iteration 423: diff = <object type:float64>
# Iteration 424: diff = <object type:float64>
# Iteration 425: diff = <object type:float64>
# Iteration 426: diff = <object type:float64>
# Iteration 427: diff = <object type:float64>
# Iteration 428: diff = <object type:float64>
# Iteration 429: diff = <object type:float64>
# Iteration 430: diff = <object type:float64>
# Iteration 431: diff = <object type:float64>
# Iteration 432: diff = <object type:float64>
# Iteration 433: diff = <object type:float64>
# Iteration 434: diff = <object type:float64>
# Iteration 435: diff = <object type:float64>
# Iteration 436: diff = <object type:float64>
# Iteration 437: diff = <object type:float64>
# Iteration 438: diff = <object type:float64>
# Iteration 439: diff = <object type:float64>
# Iteration 440: diff = <object type:float64>
# Iteration 441: diff = <object type:float64>
# Iteration 442: diff = <object type:float64>
# Iteration 443: diff = <object type:float64>
# Iteration 444: diff = <object type:float64>
# Iteration 445: diff = <object type:float64>
# Iteration 446: diff = <object type:float64>
# Iteration 447: diff = <object type:float64>
# Iteration 448: diff = <object type:float64>
# Iteration 449: diff = <object type:float64>
# Iteration 450: diff = <object type:float64>
# Iteration 451: diff = <object type:float64>
# Iteration 452: diff = <object type:float64>
# Iteration 453: diff = <object type:float64>
# Iteration 454: diff = <object type:float64>
# Iteration 455: diff = <object type:float64>
# Iteration 456: diff = <object type:float64>
# Iteration 457: diff = <object type:float64>
# Iteration 458: diff = <object type:float64>
# Iteration 459: diff = <object type:float64>
# Iteration 460: diff = <object type:float64>
# Iteration 461: diff = <object type:float64>
# Iteration 462: diff = <object type:float64>
# Iteration 463: diff = <object type:float64>
# Iteration 464: diff = <object type:float64>
# Iteration 465: diff = <object type:float64>
# Iteration 466: diff = <object type:float64>
# Iteration 467: diff = <object type:float64>
# Iteration 468: diff = <object type:float64>
# Iteration 469: diff = <object type:float64>
# Iteration 470: diff = <object type:float64>
# Iteration 471: diff = <object type:float64>
# Iteration 472: diff = <object type:float64>
# Iteration 473: diff = <object type:float64>
# Iteration 474: diff = <object type:float64>
# Iteration 475: diff = <object type:float64>
# Iteration 476: diff = <object type:float64>
# Iteration 477: diff = <object type:float64>
# Iteration 478: diff = <object type:float64>
# Iteration 479: diff = <object type:float64>
# Iteration 480: diff = <object type:float64>
# Iteration 481: diff = <object type:float64>
# Iteration 482: diff = <object type:float64>
# Iteration 483: diff = <object type:float64>
# Iteration 484: diff = <object type:float64>
# Iteration 485: diff = <object type:float64>
# Iteration 486: diff = <object type:float64>
# Iteration 487: diff = <object type:float64>
# Iteration 488: diff = <object type:float64>
# Iteration 489: diff = <object type:float64>
# Iteration 490: diff = <object type:float64>
# Iteration 491: diff = <object type:float64>
# Iteration 492: diff = <object type:float64>
# Iteration 493: diff = <object type:float64>
# Iteration 494: diff = <object type:float64>
# Iteration 495: diff = <object type:float64>
# Iteration 496: diff = <object type:float64>
# Iteration 497: diff = <object type:float64>
# Iteration 498: diff = <object type:float64>
# Iteration 499: diff = <object type:float64>
# Iteration 500: diff = <object type:float64>
# Iteration 501: diff = <object type:float64>
# Iteration 502: diff = <object type:float64>
# Iteration 503: diff = <object type:float64>
# Iteration 504: diff = <object type:float64>
# Iteration 505: diff = <object type:float64>
# Iteration 506: diff = <object type:float64>
# Iteration 507: diff = <object type:float64>
# Iteration 508: diff = <object type:float64>
# Iteration 509: diff = <object type:float64>
# Iteration 510: diff = <object type:float64>
# Iteration 511: diff = <object type:float64>
# Iteration 512: diff = <object type:float64>
# Iteration 513: diff = <object type:float64>
# Iteration 514: diff = <object type:float64>
# Iteration 515: diff = <object type:float64>
# Iteration 516: diff = <object type:float64>
# Iteration 517: diff = <object type:float64>
# Iteration 518: diff = <object type:float64>
# Iteration 519: diff = <object type:float64>
# Iteration 520: diff = <object type:float64>
# Iteration 521: diff = <object type:float64>
# Iteration 522: diff = <object type:float64>
# Iteration 523: diff = <object type:float64>
# Iteration 524: diff = <object type:float64>
# Iteration 525: diff = <object type:float64>
# Iteration 526: diff = <object type:float64>
# Iteration 527: diff = <object type:float64>
# Iteration 528: diff = <object type:float64>
# Iteration 529: diff = <object type:float64>
# Iteration 530: diff = <object type:float64>
# Iteration 531: diff = <object type:float64>
# Iteration 532: diff = <object type:float64>
# Iteration 533: diff = <object type:float64>
# Iteration 534: diff = <object type:float64>
# Iteration 535: diff = <object type:float64>
# Iteration 536: diff = <object type:float64>
# Iteration 537: diff = <object type:float64>
# Iteration 538: diff = <object type:float64>
# Iteration 539: diff = <object type:float64>
# Iteration 540: diff = <object type:float64>
# Iteration 541: diff = <object type:float64>
# Iteration 542: diff = <object type:float64>
# Iteration 543: diff = <object type:float64>
# Iteration 544: diff = <object type:float64>
# Iteration 545: diff = <object type:float64>
# Iteration 546: diff = <object type:float64>
# Iteration 547: diff = <object type:float64>
# Iteration 548: diff = <object type:float64>
# Iteration 549: diff = <object type:float64>
# Iteration 550: diff = <object type:float64>
# Iteration 551: diff = <object type:float64>
# Iteration 552: diff = <object type:float64>
# Iteration 553: diff = <object type:float64>
# Iteration 554: diff = <object type:float64>
# Iteration 555: diff = <object type:float64>
# Iteration 556: diff = <object type:float64>
# Iteration 557: diff = <object type:float64>
# Iteration 558: diff = <object type:float64>
# Iteration 559: diff = <object type:float64>
# Iteration 560: diff = <object type:float64>
# Iteration 561: diff = <object type:float64>
# Iteration 562: diff = <object type:float64>
# Iteration 563: diff = <object type:float64>
# Iteration 564: diff = <object type:float64>
# Iteration 565: diff = <object type:float64>
# Iteration 566: diff = <object type:float64>
# Iteration 567: diff = <object type:float64>
# Iteration 568: diff = <object type:float64>
# Iteration 569: diff = <object type:float64>
# Iteration 570: diff = <object type:float64>
# Iteration 571: diff = <object type:float64>
# Iteration 572: diff = <object type:float64>
# Iteration 573: diff = <object type:float64>
# Iteration 574: diff = <object type:float64>
# Iteration 575: diff = <object type:float64>
# Iteration 576: diff = <object type:float64>
# Iteration 577: diff = <object type:float64>
# Iteration 578: diff = <object type:float64>
# Iteration 579: diff = <object type:float64>
# Iteration 580: diff = <object type:float64>
# Iteration 581: diff = <object type:float64>
# Iteration 582: diff = <object type:float64>
# Iteration 583: diff = <object type:float64>
# Iteration 584: diff = <object type:float64>
# Iteration 585: diff = <object type:float64>
# Iteration 586: diff = <object type:float64>
# Iteration 587: diff = <object type:float64>
# Iteration 588: diff = <object type:float64>
# Iteration 589: diff = <object type:float64>
# Iteration 590: diff = <object type:float64>
# Iteration 591: diff = <object type:float64>
# Iteration 592: diff = <object type:float64>
# Iteration 593: diff = <object type:float64>
# Iteration 594: diff = <object type:float64>
# Iteration 595: diff = <object type:float64>
# Iteration 596: diff = <object type:float64>
# Iteration 597: diff = <object type:float64>
# Iteration 598: diff = <object type:float64>
# Iteration 599: diff = <object type:float64>
# Iteration 600: diff = <object type:float64>
# Iteration 601: diff = <object type:float64>
# Iteration 602: diff = <object type:float64>
# Iteration 603: diff = <object type:float64>
# Iteration 604: diff = <object type:float64>
# Iteration 605: diff = <object type:float64>
# Iteration 606: diff = <object type:float64>
# Iteration 607: diff = <object type:float64>
# Iteration 608: diff = <object type:float64>
# Iteration 609: diff = <object type:float64>
# Iteration 610: diff = <object type:float64>
# Iteration 611: diff = <object type:float64>
# Iteration 612: diff = <object type:float64>
# Iteration 613: diff = <object type:float64>
# Iteration 614: diff = <object type:float64>
# Iteration 615: diff = <object type:float64>
# Iteration 616: diff = <object type:float64>
# Iteration 617: diff = <object type:float64>
# Iteration 618: diff = <object type:float64>
# Iteration 619: diff = <object type:float64>
# Iteration 620: diff = <object type:float64>
# Iteration 621: diff = <object type:float64>
# Iteration 622: diff = <object type:float64>
# Iteration 623: diff = <object type:float64>
# Iteration 624: diff = <object type:float64>
# Iteration 625: diff = <object type:float64>
# Iteration 626: diff = <object type:float64>
# Iteration 627: diff = <object type:float64>
# Iteration 628: diff = <object type:float64>
# Iteration 629: diff = <object type:float64>
# Iteration 630: diff = <object type:float64>
# Iteration 631: diff = <object type:float64>
# Iteration 632: diff = <object type:float64>
# Iteration 633: diff = <object type:float64>
# Iteration 634: diff = <object type:float64>
# Iteration 635: diff = <object type:float64>
# Iteration 636: diff = <object type:float64>
# Iteration 637: diff = <object type:float64>
# Iteration 638: diff = <object type:float64>
# Iteration 639: diff = <object type:float64>
# Iteration 640: diff = <object type:float64>
# Iteration 641: diff = <object type:float64>
# Iteration 642: diff = <object type:float64>
# Iteration 643: diff = <object type:float64>
# Iteration 644: diff = <object type:float64>
# Iteration 645: diff = <object type:float64>
# Iteration 646: diff = <object type:float64>
# Iteration 647: diff = <object type:float64>
# Iteration 648: diff = <object type:float64>
# Iteration 649: diff = <object type:float64>
# Iteration 650: diff = <object type:float64>
# Iteration 651: diff = <object type:float64>
# Iteration 652: diff = <object type:float64>
# Iteration 653: diff = <object type:float64>
# Iteration 654: diff = <object type:float64>
# Iteration 655: diff = <object type:float64>
# Iteration 656: diff = <object type:float64>
# Iteration 657: diff = <object type:float64>
# Iteration 658: diff = <object type:float64>
# Iteration 659: diff = <object type:float64>
# Iteration 660: diff = <object type:float64>
# Iteration 661: diff = <object type:float64>
# Iteration 662: diff = <object type:float64>
# Iteration 663: diff = <object type:float64>
# Iteration 664: diff = <object type:float64>
# Iteration 665: diff = <object type:float64>
# Iteration 666: diff = <object type:float64>
# Iteration 667: diff = <object type:float64>
# Iteration 668: diff = <object type:float64>
# Iteration 669: diff = <object type:float64>
# Iteration 670: diff = <object type:float64>
# Iteration 671: diff = <object type:float64>
# Iteration 672: diff = <object type:float64>
# Iteration 673: diff = <object type:float64>
# Iteration 674: diff = <object type:float64>
# Iteration 675: diff = <object type:float64>
# Iteration 676: diff = <object type:float64>
# Iteration 677: diff = <object type:float64>
# Iteration 678: diff = <object type:float64>
# Iteration 679: diff = <object type:float64>
# Iteration 680: diff = <object type:float64>
# Iteration 681: diff = <object type:float64>
# Iteration 682: diff = <object type:float64>
# Iteration 683: diff = <object type:float64>
# Iteration 684: diff = <object type:float64>
# Iteration 685: diff = <object type:float64>
# Iteration 686: diff = <object type:float64>
# Iteration 687: diff = <object type:float64>
# Iteration 688: diff = <object type:float64>
# Iteration 689: diff = <object type:float64>
# Iteration 690: diff = <object type:float64>
# Iteration 691: diff = <object type:float64>
# Iteration 692: diff = <object type:float64>
# Iteration 693: diff = <object type:float64>
# Iteration 694: diff = <object type:float64>
# Iteration 695: diff = <object type:float64>
# Iteration 696: diff = <object type:float64>
# Iteration 697: diff = <object type:float64>
# Iteration 698: diff = <object type:float64>
# Iteration 699: diff = <object type:float64>
# Iteration 700: diff = <object type:float64>
# Iteration 701: diff = <object type:float64>
# Iteration 702: diff = <object type:float64>
# Iteration 703: diff = <object type:float64>
# Iteration 704: diff = <object type:float64>
# Iteration 705: diff = <object type:float64>
# Iteration 706: diff = <object type:float64>
# Iteration 707: diff = <object type:float64>
# Iteration 708: diff = <object type:float64>
# Iteration 709: diff = <object type:float64>
# Iteration 710: diff = <object type:float64>
# Iteration 711: diff = <object type:float64>
# Iteration 712: diff = <object type:float64>
# Iteration 713: diff = <object type:float64>
# Iteration 714: diff = <object type:float64>
# Iteration 715: diff = <object type:float64>
# Iteration 716: diff = <object type:float64>
# Iteration 717: diff = <object type:float64>
# Iteration 718: diff = <object type:float64>
# Iteration 719: diff = <object type:float64>
# Iteration 720: diff = <object type:float64>
# Iteration 721: diff = <object type:float64>
# Iteration 722: diff = <object type:float64>
# Iteration 723: diff = <object type:float64>
# Iteration 724: diff = <object type:float64>
# Iteration 725: diff = <object type:float64>
# Iteration 726: diff = <object type:float64>
# Iteration 727: diff = <object type:float64>
# Iteration 728: diff = <object type:float64>
# Iteration 729: diff = <object type:float64>
# Iteration 730: diff = <object type:float64>
# Iteration 731: diff = <object type:float64>
# Iteration 732: diff = <object type:float64>
# Iteration 733: diff = <object type:float64>
# Iteration 734: diff = <object type:float64>
# Iteration 735: diff = <object type:float64>
# Iteration 736: diff = <object type:float64>
# Iteration 737: diff = <object type:float64>
# Iteration 738: diff = <object type:float64>
# Iteration 739: diff = <object type:float64>
# Iteration 740: diff = <object type:float64>
# Iteration 741: diff = <object type:float64>
# Iteration 742: diff = <object type:float64>
# Iteration 743: diff = <object type:float64>
# Iteration 744: diff = <object type:float64>
# Iteration 745: diff = <object type:float64>
# Iteration 746: diff = <object type:float64>
# Iteration 747: diff = <object type:float64>
# Iteration 748: diff = <object type:float64>
# Iteration 749: diff = <object type:float64>
# Iteration 750: diff = <object type:float64>
# Iteration 751: diff = <object type:float64>
# Iteration 752: diff = <object type:float64>
# Iteration 753: diff = <object type:float64>
# Iteration 754: diff = <object type:float64>
# Iteration 755: diff = <object type:float64>
# Iteration 756: diff = <object type:float64>
# Iteration 757: diff = <object type:float64>
# Iteration 758: diff = <object type:float64>
# Iteration 759: diff = <object type:float64>
# Iteration 760: diff = <object type:float64>
# Iteration 761: diff = <object type:float64>
# Iteration 762: diff = <object type:float64>
# Iteration 763: diff = <object type:float64>
# Iteration 764: diff = <object type:float64>
# Iteration 765: diff = <object type:float64>
# Iteration 766: diff = <object type:float64>
# Iteration 767: diff = <object type:float64>
# Iteration 768: diff = <object type:float64>
# Iteration 769: diff = <object type:float64>
# Iteration 770: diff = <object type:float64>
# Iteration 771: diff = <object type:float64>
# Iteration 772: diff = <object type:float64>
# Iteration 773: diff = <object type:float64>
# Iteration 774: diff = <object type:float64>
# Iteration 775: diff = <object type:float64>
# Iteration 776: diff = <object type:float64>
# Iteration 777: diff = <object type:float64>
# Iteration 778: diff = <object type:float64>
# Iteration 779: diff = <object type:float64>
# Iteration 780: diff = <object type:float64>
# Iteration 781: diff = <object type:float64>
# Iteration 782: diff = <object type:float64>
# Iteration 783: diff = <object type:float64>
# Iteration 784: diff = <object type:float64>
# Iteration 785: diff = <object type:float64>
# Iteration 786: diff = <object type:float64>
# Iteration 787: diff = <object type:float64>
# Iteration 788: diff = <object type:float64>
# Iteration 789: diff = <object type:float64>
# Iteration 790: diff = <object type:float64>
# Iteration 791: diff = <object type:float64>
# Iteration 792: diff = <object type:float64>
# Iteration 793: diff = <object type:float64>
# Iteration 794: diff = <object type:float64>
# Iteration 795: diff = <object type:float64>
# Iteration 796: diff = <object type:float64>
# Iteration 797: diff = <object type:float64>
# Iteration 798: diff = <object type:float64>
# Iteration 799: diff = <object type:float64>
# Iteration 800: diff = <object type:float64>
# Iteration 801: diff = <object type:float64>
# Iteration 802: diff = <object type:float64>
# Iteration 803: diff = <object type:float64>
# Iteration 804: diff = <object type:float64>
# Iteration 805: diff = <object type:float64>
# Iteration 806: diff = <object type:float64>
# Iteration 807: diff = <object type:float64>
# Iteration 808: diff = <object type:float64>
# Iteration 809: diff = <object type:float64>
# Iteration 810: diff = <object type:float64>
# Iteration 811: diff = <object type:float64>
# Iteration 812: diff = <object type:float64>
# Iteration 813: diff = <object type:float64>
# Iteration 814: diff = <object type:float64>
# Iteration 815: diff = <object type:float64>
# Iteration 816: diff = <object type:float64>
# Iteration 817: diff = <object type:float64>
# Iteration 818: diff = <object type:float64>
# Iteration 819: diff = <object type:float64>
# Iteration 820: diff = <object type:float64>
# Iteration 821: diff = <object type:float64>
# Iteration 822: diff = <object type:float64>
# Iteration 823: diff = <object type:float64>
# Iteration 824: diff = <object type:float64>
# Iteration 825: diff = <object type:float64>
# Iteration 826: diff = <object type:float64>
# Iteration 827: diff = <object type:float64>
# Iteration 828: diff = <object type:float64>
# Iteration 829: diff = <object type:float64>
# Iteration 830: diff = <object type:float64>
# Iteration 831: diff = <object type:float64>
# Iteration 832: diff = <object type:float64>
# Iteration 833: diff = <object type:float64>
# Iteration 834: diff = <object type:float64>
# Iteration 835: diff = <object type:float64>
# Iteration 836: diff = <object type:float64>
# Iteration 837: diff = <object type:float64>
# Iteration 838: diff = <object type:float64>
# Iteration 839: diff = <object type:float64>
# Iteration 840: diff = <object type:float64>
# Iteration 841: diff = <object type:float64>
# Iteration 842: diff = <object type:float64>
# Iteration 843: diff = <object type:float64>
# Iteration 844: diff = <object type:float64>
# Iteration 845: diff = <object type:float64>
# Iteration 846: diff = <object type:float64>
# Iteration 847: diff = <object type:float64>
# Iteration 848: diff = <object type:float64>
# Iteration 849: diff = <object type:float64>
# Iteration 850: diff = <object type:float64>
# Iteration 851: diff = <object type:float64>
# Iteration 852: diff = <object type:float64>
# Iteration 853: diff = <object type:float64>
# Iteration 854: diff = <object type:float64>
# Iteration 855: diff = <object type:float64>
# Iteration 856: diff = <object type:float64>
# Iteration 857: diff = <object type:float64>
# Iteration 858: diff = <object type:float64>
# Iteration 859: diff = <object type:float64>
# Iteration 860: diff = <object type:float64>
# Iteration 861: diff = <object type:float64>
# Iteration 862: diff = <object type:float64>
# Iteration 863: diff = <object type:float64>
# Iteration 864: diff = <object type:float64>
# Iteration 865: diff = <object type:float64>
# Iteration 866: diff = <object type:float64>
# Iteration 867: diff = <object type:float64>
# Iteration 868: diff = <object type:float64>
# Iteration 869: diff = <object type:float64>
# Iteration 870: diff = <object type:float64>
# Iteration 871: diff = <object type:float64>
# Iteration 872: diff = <object type:float64>
# Iteration 873: diff = <object type:float64>
# Iteration 874: diff = <object type:float64>
# Iteration 875: diff = <object type:float64>
# Iteration 876: diff = <object type:float64>
# Iteration 877: diff = <object type:float64>
# Iteration 878: diff = <object type:float64>
# Iteration 879: diff = <object type:float64>
# Iteration 880: diff = <object type:float64>
# Iteration 881: diff = <object type:float64>
# Iteration 882: diff = <object type:float64>
# Iteration 883: diff = <object type:float64>
# Iteration 884: diff = <object type:float64>
# Iteration 885: diff = <object type:float64>
# Iteration 886: diff = <object type:float64>
# Iteration 887: diff = <object type:float64>
# Iteration 888: diff = <object type:float64>
# Iteration 889: diff = <object type:float64>
# Iteration 890: diff = <object type:float64>
# Iteration 891: diff = <object type:float64>
# Iteration 892: diff = <object type:float64>
# Iteration 893: diff = <object type:float64>
# Iteration 894: diff = <object type:float64>
# Iteration 895: diff = <object type:float64>
# Iteration 896: diff = <object type:float64>
# Iteration 897: diff = <object type:float64>
# Iteration 898: diff = <object type:float64>
# Iteration 899: diff = <object type:float64>
# Iteration 900: diff = <object type:float64>
# Iteration 901: diff = <object type:float64>
# Iteration 902: diff = <object type:float64>
# Iteration 903: diff = <object type:float64>
# Iteration 904: diff = <object type:float64>
# Iteration 905: diff = <object type:float64>
# Iteration 906: diff = <object type:float64>
# Iteration 907: diff = <object type:float64>
# Iteration 908: diff = <object type:float64>
# Iteration 909: diff = <object type:float64>
# Iteration 910: diff = <object type:float64>
# Iteration 911: diff = <object type:float64>
# Iteration 912: diff = <object type:float64>
# Iteration 913: diff = <object type:float64>
# Iteration 914: diff = <object type:float64>
# Iteration 915: diff = <object type:float64>
# Iteration 916: diff = <object type:float64>
# Iteration 917: diff = <object type:float64>
# Iteration 918: diff = <object type:float64>
# Iteration 919: diff = <object type:float64>
# Iteration 920: diff = <object type:float64>
# Iteration 921: diff = <object type:float64>
# Iteration 922: diff = <object type:float64>
# Iteration 923: diff = <object type:float64>
# Iteration 924: diff = <object type:float64>
# Iteration 925: diff = <object type:float64>
# Iteration 926: diff = <object type:float64>
# Iteration 927: diff = <object type:float64>
# Iteration 928: diff = <object type:float64>
# Iteration 929: diff = <object type:float64>
# Iteration 930: diff = <object type:float64>
# Iteration 931: diff = <object type:float64>
# Iteration 932: diff = <object type:float64>
# Iteration 933: diff = <object type:float64>
# Iteration 934: diff = <object type:float64>
# Iteration 935: diff = <object type:float64>
# Iteration 936: diff = <object type:float64>
# Iteration 937: diff = <object type:float64>
# Iteration 938: diff = <object type:float64>
# Iteration 939: diff = <object type:float64>
# Iteration 940: diff = <object type:float64>
# Iteration 941: diff = <object type:float64>
# Iteration 942: diff = <object type:float64>
# Iteration 943: diff = <object type:float64>
# Iteration 944: diff = <object type:float64>
# Iteration 945: diff = <object type:float64>
# Iteration 946: diff = <object type:float64>
# Iteration 947: diff = <object type:float64>
# Iteration 948: diff = <object type:float64>
# Iteration 949: diff = <object type:float64>
# Iteration 950: diff = <object type:float64>
# Iteration 951: diff = <object type:float64>
# Iteration 952: diff = <object type:float64>
# Iteration 953: diff = <object type:float64>
# Iteration 954: diff = <object type:float64>
# Iteration 955: diff = <object type:float64>
# Iteration 956: diff = <object type:float64>
# Iteration 957: diff = <object type:float64>
# Iteration 958: diff = <object type:float64>
# Iteration 959: diff = <object type:float64>
# Iteration 960: diff = <object type:float64>
# Iteration 961: diff = <object type:float64>
# Iteration 962: diff = <object type:float64>
# Iteration 963: diff = <object type:float64>
# Iteration 964: diff = <object type:float64>
# Iteration 965: diff = <object type:float64>
# Iteration 966: diff = <object type:float64>
# Iteration 967: diff = <object type:float64>
# Iteration 968: diff = <object type:float64>
# Iteration 969: diff = <object type:float64>
# Iteration 970: diff = <object type:float64>
# Iteration 971: diff = <object type:float64>
# Iteration 972: diff = <object type:float64>
# Iteration 973: diff = <object type:float64>
# Iteration 974: diff = <object type:float64>
# Iteration 975: diff = <object type:float64>
# Iteration 976: diff = <object type:float64>
# Iteration 977: diff = <object type:float64>
# Iteration 978: diff = <object type:float64>
# Iteration 979: diff = <object type:float64>
# Iteration 980: diff = <object type:float64>
# Iteration 981: diff = <object type:float64>
# Iteration 982: diff = <object type:float64>
# Iteration 983: diff = <object type:float64>
# Iteration 984: diff = <object type:float64>
# Iteration 985: diff = <object type:float64>
# Iteration 986: diff = <object type:float64>
# Iteration 987: diff = <object type:float64>
# Iteration 988: diff = <object type:float64>
# Iteration 989: diff = <object type:float64>
# Iteration 990: diff = <object type:float64>
# Iteration 991: diff = <object type:float64>
# Iteration 992: diff = <object type:float64>
# Iteration 993: diff = <object type:float64>
# Iteration 994: diff = <object type:float64>
# Iteration 995: diff = <object type:float64>
# Iteration 996: diff = <object type:float64>
# Iteration 997: diff = <object type:float64>
# Iteration 998: diff = <object type:float64>
# Iteration 999: diff = <object type:float64>
# Iteration 1000: diff = <object type:float64>
# Total iterations until convergence: 1000
# Stationary distribution f_{i,j}:
# [[1.46285425e+113 9.45038937e+277]
#  [1.46285425e+113 2.28001367e+087]
#  [9.45038937e+277 2.28001367e+087]]
# array([[1.46285425e+113, 9.45038937e+277],
#        [1.46285425e+113, 2.28001367e+087],
#        [9.45038937e+277, 2.28001367e+087]])

# %%
import numpy as np

pf_grid = hfun_c
a_grid = hp.a_grid
sd_grid = np.full(pf_grid.shape, 1/pf_grid.size)
Pmatrix = hp.Pz

import time

start = time.perf_counter() #計測開始

test = solve_stationary_dist(pf_grid, a_grid, sd_grid, Pmatrix)

end = time.perf_counter() #計測終了
print('{:.2f}'.format((end-start)/60)) # 87.97(秒→分に直し、小数点以下の桁数を指定して出力)
# Out:
# Iteration 1: diff = <object type:float64>
# Iteration 2: diff = <object type:float64>
# Iteration 3: diff = <object type:float64>
# Iteration 4: diff = <object type:float64>
# Iteration 5: diff = <object type:float64>
# Iteration 6: diff = <object type:float64>
# Iteration 7: diff = <object type:float64>
# Iteration 8: diff = <object type:float64>
# Iteration 9: diff = <object type:float64>
# Iteration 10: diff = <object type:float64>
# Iteration 11: diff = <object type:float64>
# Iteration 12: diff = <object type:float64>
# Iteration 13: diff = <object type:float64>
# Iteration 14: diff = <object type:float64>
# Iteration 15: diff = <object type:float64>
# Iteration 16: diff = <object type:float64>
# Iteration 17: diff = <object type:float64>
# Iteration 18: diff = <object type:float64>
# Iteration 19: diff = <object type:float64>
# Iteration 20: diff = <object type:float64>
# Iteration 21: diff = <object type:float64>
# Iteration 22: diff = <object type:float64>
# Iteration 23: diff = <object type:float64>
# Iteration 24: diff = <object type:float64>
# Iteration 25: diff = <object type:float64>
# Iteration 26: diff = <object type:float64>
# Iteration 27: diff = <object type:float64>
# Iteration 28: diff = <object type:float64>
# Iteration 29: diff = <object type:float64>
# Iteration 30: diff = <object type:float64>
# Iteration 31: diff = <object type:float64>
# Iteration 32: diff = <object type:float64>
# Iteration 33: diff = <object type:float64>
# Iteration 34: diff = <object type:float64>
# Iteration 35: diff = <object type:float64>
# Iteration 36: diff = <object type:float64>
# Iteration 37: diff = <object type:float64>
# Iteration 38: diff = <object type:float64>
# Iteration 39: diff = <object type:float64>
# Iteration 40: diff = <object type:float64>
# Iteration 41: diff = <object type:float64>
# Iteration 42: diff = <object type:float64>
# Iteration 43: diff = <object type:float64>
# Iteration 44: diff = <object type:float64>
# Iteration 45: diff = <object type:float64>
# Iteration 46: diff = <object type:float64>
# Iteration 47: diff = <object type:float64>
# Iteration 48: diff = <object type:float64>
# Iteration 49: diff = <object type:float64>
# Iteration 50: diff = <object type:float64>
# Iteration 51: diff = <object type:float64>
# Iteration 52: diff = <object type:float64>
# Iteration 53: diff = <object type:float64>
# Iteration 54: diff = <object type:float64>
# Iteration 55: diff = <object type:float64>
# Iteration 56: diff = <object type:float64>
# Iteration 57: diff = <object type:float64>
# Iteration 58: diff = <object type:float64>
# Iteration 59: diff = <object type:float64>
# Iteration 60: diff = <object type:float64>
# Iteration 61: diff = <object type:float64>
# Iteration 62: diff = <object type:float64>
# Iteration 63: diff = <object type:float64>
# Iteration 64: diff = <object type:float64>
# Iteration 65: diff = <object type:float64>
# Iteration 66: diff = <object type:float64>
# Iteration 67: diff = <object type:float64>
# Iteration 68: diff = <object type:float64>
# Iteration 69: diff = <object type:float64>
# Iteration 70: diff = <object type:float64>
# Iteration 71: diff = <object type:float64>
# Iteration 72: diff = <object type:float64>
# Iteration 73: diff = <object type:float64>
# Iteration 74: diff = <object type:float64>
# Iteration 75: diff = <object type:float64>
# Iteration 76: diff = <object type:float64>
# Iteration 77: diff = <object type:float64>
# Iteration 78: diff = <object type:float64>
# Iteration 79: diff = <object type:float64>
# Iteration 80: diff = <object type:float64>
# Iteration 81: diff = <object type:float64>
# Iteration 82: diff = <object type:float64>
# Iteration 83: diff = <object type:float64>
# Iteration 84: diff = <object type:float64>
# Iteration 85: diff = <object type:float64>
# Iteration 86: diff = <object type:float64>
# Iteration 87: diff = <object type:float64>
# Iteration 88: diff = <object type:float64>
# Iteration 89: diff = <object type:float64>
# Iteration 90: diff = <object type:float64>
# Iteration 91: diff = <object type:float64>
# Iteration 92: diff = <object type:float64>
# Iteration 93: diff = <object type:float64>
# Iteration 94: diff = <object type:float64>
# Iteration 95: diff = <object type:float64>
# Iteration 96: diff = <object type:float64>
# Iteration 97: diff = <object type:float64>
# Iteration 98: diff = <object type:float64>
# Iteration 99: diff = <object type:float64>
# Iteration 100: diff = <object type:float64>
# Iteration 101: diff = <object type:float64>
# Iteration 102: diff = <object type:float64>
# Iteration 103: diff = <object type:float64>
# Iteration 104: diff = <object type:float64>
# Iteration 105: diff = <object type:float64>
# Iteration 106: diff = <object type:float64>
# Iteration 107: diff = <object type:float64>
# Iteration 108: diff = <object type:float64>
# Iteration 109: diff = <object type:float64>
# Iteration 110: diff = <object type:float64>
# Iteration 111: diff = <object type:float64>
# Iteration 112: diff = <object type:float64>
# Iteration 113: diff = <object type:float64>
# Iteration 114: diff = <object type:float64>
# Iteration 115: diff = <object type:float64>
# Iteration 116: diff = <object type:float64>
# Iteration 117: diff = <object type:float64>
# Iteration 118: diff = <object type:float64>
# Iteration 119: diff = <object type:float64>
# Iteration 120: diff = <object type:float64>
# Iteration 121: diff = <object type:float64>
# Iteration 122: diff = <object type:float64>
# Iteration 123: diff = <object type:float64>
# Iteration 124: diff = <object type:float64>
# Iteration 125: diff = <object type:float64>
# Iteration 126: diff = <object type:float64>
# Iteration 127: diff = <object type:float64>
# Iteration 128: diff = <object type:float64>
# Iteration 129: diff = <object type:float64>
# Iteration 130: diff = <object type:float64>
# Iteration 131: diff = <object type:float64>
# Iteration 132: diff = <object type:float64>
# Iteration 133: diff = <object type:float64>
# Iteration 134: diff = <object type:float64>
# Iteration 135: diff = <object type:float64>
# Iteration 136: diff = <object type:float64>
# Iteration 137: diff = <object type:float64>
# Iteration 138: diff = <object type:float64>
# Iteration 139: diff = <object type:float64>
# Iteration 140: diff = <object type:float64>
# Iteration 141: diff = <object type:float64>
# Iteration 142: diff = <object type:float64>
# Iteration 143: diff = <object type:float64>
# Iteration 144: diff = <object type:float64>
# Iteration 145: diff = <object type:float64>
# Iteration 146: diff = <object type:float64>
# Iteration 147: diff = <object type:float64>
# Iteration 148: diff = <object type:float64>
# Iteration 149: diff = <object type:float64>
# Iteration 150: diff = <object type:float64>
# Iteration 151: diff = <object type:float64>
# Iteration 152: diff = <object type:float64>
# Iteration 153: diff = <object type:float64>
# Iteration 154: diff = <object type:float64>
# Iteration 155: diff = <object type:float64>
# Iteration 156: diff = <object type:float64>
# Iteration 157: diff = <object type:float64>
# Iteration 158: diff = <object type:float64>
# Iteration 159: diff = <object type:float64>
# Iteration 160: diff = <object type:float64>
# Iteration 161: diff = <object type:float64>
# Iteration 162: diff = <object type:float64>
# Iteration 163: diff = <object type:float64>
# Iteration 164: diff = <object type:float64>
# Iteration 165: diff = <object type:float64>
# Iteration 166: diff = <object type:float64>
# Iteration 167: diff = <object type:float64>
# Iteration 168: diff = <object type:float64>
# Iteration 169: diff = <object type:float64>
# Iteration 170: diff = <object type:float64>
# Iteration 171: diff = <object type:float64>
# Iteration 172: diff = <object type:float64>
# Iteration 173: diff = <object type:float64>
# Iteration 174: diff = <object type:float64>
# Iteration 175: diff = <object type:float64>
# Iteration 176: diff = <object type:float64>
# Iteration 177: diff = <object type:float64>
# Iteration 178: diff = <object type:float64>
# Iteration 179: diff = <object type:float64>
# Iteration 180: diff = <object type:float64>
# Iteration 181: diff = <object type:float64>
# Iteration 182: diff = <object type:float64>
# Iteration 183: diff = <object type:float64>
# Iteration 184: diff = <object type:float64>
# Iteration 185: diff = <object type:float64>
# Iteration 186: diff = <object type:float64>
# Iteration 187: diff = <object type:float64>
# Iteration 188: diff = <object type:float64>
# Iteration 189: diff = <object type:float64>
# Iteration 190: diff = <object type:float64>
# Iteration 191: diff = <object type:float64>
# Iteration 192: diff = <object type:float64>
# Iteration 193: diff = <object type:float64>
# Iteration 194: diff = <object type:float64>
# Iteration 195: diff = <object type:float64>
# Iteration 196: diff = <object type:float64>
# Iteration 197: diff = <object type:float64>
# Iteration 198: diff = <object type:float64>
# Iteration 199: diff = <object type:float64>
# Iteration 200: diff = <object type:float64>
# Iteration 201: diff = <object type:float64>
# Iteration 202: diff = <object type:float64>
# Iteration 203: diff = <object type:float64>
# Iteration 204: diff = <object type:float64>
# Iteration 205: diff = <object type:float64>
# Iteration 206: diff = <object type:float64>
# Iteration 207: diff = <object type:float64>
# Iteration 208: diff = <object type:float64>
# Iteration 209: diff = <object type:float64>
# Iteration 210: diff = <object type:float64>
# Iteration 211: diff = <object type:float64>
# Iteration 212: diff = <object type:float64>
# Iteration 213: diff = <object type:float64>
# Iteration 214: diff = <object type:float64>
# Iteration 215: diff = <object type:float64>
# Iteration 216: diff = <object type:float64>
# Iteration 217: diff = <object type:float64>
# Iteration 218: diff = <object type:float64>
# Iteration 219: diff = <object type:float64>
# Iteration 220: diff = <object type:float64>
# Iteration 221: diff = <object type:float64>
# Iteration 222: diff = <object type:float64>
# Iteration 223: diff = <object type:float64>
# Iteration 224: diff = <object type:float64>
# Iteration 225: diff = <object type:float64>
# Iteration 226: diff = <object type:float64>
# Iteration 227: diff = <object type:float64>
# Iteration 228: diff = <object type:float64>
# Iteration 229: diff = <object type:float64>
# Iteration 230: diff = <object type:float64>
# Iteration 231: diff = <object type:float64>
# Iteration 232: diff = <object type:float64>
# Iteration 233: diff = <object type:float64>
# Iteration 234: diff = <object type:float64>
# Iteration 235: diff = <object type:float64>
# Iteration 236: diff = <object type:float64>
# Iteration 237: diff = <object type:float64>
# Iteration 238: diff = <object type:float64>
# Iteration 239: diff = <object type:float64>
# Iteration 240: diff = <object type:float64>
# Iteration 241: diff = <object type:float64>
# Iteration 242: diff = <object type:float64>
# Iteration 243: diff = <object type:float64>
# Iteration 244: diff = <object type:float64>
# Iteration 245: diff = <object type:float64>
# Iteration 246: diff = <object type:float64>
# Iteration 247: diff = <object type:float64>
# Iteration 248: diff = <object type:float64>
# Iteration 249: diff = <object type:float64>
# Iteration 250: diff = <object type:float64>
# Iteration 251: diff = <object type:float64>
# Iteration 252: diff = <object type:float64>
# Iteration 253: diff = <object type:float64>
# Iteration 254: diff = <object type:float64>
# Iteration 255: diff = <object type:float64>
# Iteration 256: diff = <object type:float64>
# Iteration 257: diff = <object type:float64>
# Iteration 258: diff = <object type:float64>
# Iteration 259: diff = <object type:float64>
# Iteration 260: diff = <object type:float64>
# Iteration 261: diff = <object type:float64>
# Iteration 262: diff = <object type:float64>
# Iteration 263: diff = <object type:float64>
# Iteration 264: diff = <object type:float64>
# Iteration 265: diff = <object type:float64>
# Iteration 266: diff = <object type:float64>
# Iteration 267: diff = <object type:float64>
# Iteration 268: diff = <object type:float64>
# Iteration 269: diff = <object type:float64>
# Iteration 270: diff = <object type:float64>
# Iteration 271: diff = <object type:float64>
# Iteration 272: diff = <object type:float64>
# Iteration 273: diff = <object type:float64>
# Iteration 274: diff = <object type:float64>
# Iteration 275: diff = <object type:float64>
# Iteration 276: diff = <object type:float64>
# Iteration 277: diff = <object type:float64>
# Iteration 278: diff = <object type:float64>
# Iteration 279: diff = <object type:float64>
# Iteration 280: diff = <object type:float64>
# Iteration 281: diff = <object type:float64>
# Iteration 282: diff = <object type:float64>
# Iteration 283: diff = <object type:float64>
# Iteration 284: diff = <object type:float64>
# Iteration 285: diff = <object type:float64>
# Iteration 286: diff = <object type:float64>
# Iteration 287: diff = <object type:float64>
# Iteration 288: diff = <object type:float64>
# Iteration 289: diff = <object type:float64>
# Iteration 290: diff = <object type:float64>
# Iteration 291: diff = <object type:float64>
# Iteration 292: diff = <object type:float64>
# Iteration 293: diff = <object type:float64>
# Iteration 294: diff = <object type:float64>
# Iteration 295: diff = <object type:float64>
# Iteration 296: diff = <object type:float64>
# Iteration 297: diff = <object type:float64>
# Iteration 298: diff = <object type:float64>
# Iteration 299: diff = <object type:float64>
# Iteration 300: diff = <object type:float64>
# Iteration 301: diff = <object type:float64>
# Iteration 302: diff = <object type:float64>
# Iteration 303: diff = <object type:float64>
# Iteration 304: diff = <object type:float64>
# Iteration 305: diff = <object type:float64>
# Iteration 306: diff = <object type:float64>
# Iteration 307: diff = <object type:float64>
# Iteration 308: diff = <object type:float64>
# Iteration 309: diff = <object type:float64>
# Iteration 310: diff = <object type:float64>
# Iteration 311: diff = <object type:float64>
# Iteration 312: diff = <object type:float64>
# Iteration 313: diff = <object type:float64>
# Iteration 314: diff = <object type:float64>
# Iteration 315: diff = <object type:float64>
# Iteration 316: diff = <object type:float64>
# Iteration 317: diff = <object type:float64>
# Iteration 318: diff = <object type:float64>
# Iteration 319: diff = <object type:float64>
# Iteration 320: diff = <object type:float64>
# Iteration 321: diff = <object type:float64>
# Iteration 322: diff = <object type:float64>
# Iteration 323: diff = <object type:float64>
# Iteration 324: diff = <object type:float64>
# Iteration 325: diff = <object type:float64>
# Iteration 326: diff = <object type:float64>
# Iteration 327: diff = <object type:float64>
# Iteration 328: diff = <object type:float64>
# Iteration 329: diff = <object type:float64>
# Iteration 330: diff = <object type:float64>
# Iteration 331: diff = <object type:float64>
# Iteration 332: diff = <object type:float64>
# Iteration 333: diff = <object type:float64>
# Iteration 334: diff = <object type:float64>
# Iteration 335: diff = <object type:float64>
# Iteration 336: diff = <object type:float64>
# Iteration 337: diff = <object type:float64>
# Iteration 338: diff = <object type:float64>
# Iteration 339: diff = <object type:float64>
# Iteration 340: diff = <object type:float64>
# Iteration 341: diff = <object type:float64>
# Iteration 342: diff = <object type:float64>
# Iteration 343: diff = <object type:float64>
# Iteration 344: diff = <object type:float64>
# Iteration 345: diff = <object type:float64>
# Iteration 346: diff = <object type:float64>
# Iteration 347: diff = <object type:float64>
# Iteration 348: diff = <object type:float64>
# Iteration 349: diff = <object type:float64>
# Iteration 350: diff = <object type:float64>
# Iteration 351: diff = <object type:float64>
# Iteration 352: diff = <object type:float64>
# Iteration 353: diff = <object type:float64>
# Iteration 354: diff = <object type:float64>
# Iteration 355: diff = <object type:float64>
# Iteration 356: diff = <object type:float64>
# Iteration 357: diff = <object type:float64>
# Iteration 358: diff = <object type:float64>
# Iteration 359: diff = <object type:float64>
# Iteration 360: diff = <object type:float64>
# Iteration 361: diff = <object type:float64>
# Iteration 362: diff = <object type:float64>
# Iteration 363: diff = <object type:float64>
# Iteration 364: diff = <object type:float64>
# Iteration 365: diff = <object type:float64>
# Iteration 366: diff = <object type:float64>
# Iteration 367: diff = <object type:float64>
# Iteration 368: diff = <object type:float64>
# Iteration 369: diff = <object type:float64>
# Iteration 370: diff = <object type:float64>
# Iteration 371: diff = <object type:float64>
# Iteration 372: diff = <object type:float64>
# Iteration 373: diff = <object type:float64>
# Iteration 374: diff = <object type:float64>
# Iteration 375: diff = <object type:float64>
# Iteration 376: diff = <object type:float64>
# Iteration 377: diff = <object type:float64>
# Iteration 378: diff = <object type:float64>
# Iteration 379: diff = <object type:float64>
# Iteration 380: diff = <object type:float64>
# Iteration 381: diff = <object type:float64>
# Iteration 382: diff = <object type:float64>
# Iteration 383: diff = <object type:float64>
# Iteration 384: diff = <object type:float64>
# Iteration 385: diff = <object type:float64>
# Iteration 386: diff = <object type:float64>
# Iteration 387: diff = <object type:float64>
# Iteration 388: diff = <object type:float64>
# Iteration 389: diff = <object type:float64>
# Iteration 390: diff = <object type:float64>
# Iteration 391: diff = <object type:float64>
# Iteration 392: diff = <object type:float64>
# Iteration 393: diff = <object type:float64>
# Iteration 394: diff = <object type:float64>
# Iteration 395: diff = <object type:float64>
# Iteration 396: diff = <object type:float64>
# Iteration 397: diff = <object type:float64>
# Iteration 398: diff = <object type:float64>
# Iteration 399: diff = <object type:float64>
# Iteration 400: diff = <object type:float64>
# Iteration 401: diff = <object type:float64>
# Iteration 402: diff = <object type:float64>
# Iteration 403: diff = <object type:float64>
# Iteration 404: diff = <object type:float64>
# Iteration 405: diff = <object type:float64>
# Iteration 406: diff = <object type:float64>
# Iteration 407: diff = <object type:float64>
# Iteration 408: diff = <object type:float64>
# Iteration 409: diff = <object type:float64>
# Iteration 410: diff = <object type:float64>
# Iteration 411: diff = <object type:float64>
# Iteration 412: diff = <object type:float64>
# Iteration 413: diff = <object type:float64>
# Iteration 414: diff = <object type:float64>
# Iteration 415: diff = <object type:float64>
# Iteration 416: diff = <object type:float64>
# Iteration 417: diff = <object type:float64>
# Iteration 418: diff = <object type:float64>
# Iteration 419: diff = <object type:float64>
# Iteration 420: diff = <object type:float64>
# Iteration 421: diff = <object type:float64>
# Iteration 422: diff = <object type:float64>
# Iteration 423: diff = <object type:float64>
# Iteration 424: diff = <object type:float64>
# Iteration 425: diff = <object type:float64>
# Iteration 426: diff = <object type:float64>
# Iteration 427: diff = <object type:float64>
# Iteration 428: diff = <object type:float64>
# Iteration 429: diff = <object type:float64>
# Iteration 430: diff = <object type:float64>
# Iteration 431: diff = <object type:float64>
# Iteration 432: diff = <object type:float64>
# Iteration 433: diff = <object type:float64>
# Iteration 434: diff = <object type:float64>
# Iteration 435: diff = <object type:float64>
# Iteration 436: diff = <object type:float64>
# Iteration 437: diff = <object type:float64>
# Iteration 438: diff = <object type:float64>
# Iteration 439: diff = <object type:float64>
# Iteration 440: diff = <object type:float64>
# Iteration 441: diff = <object type:float64>
# Iteration 442: diff = <object type:float64>
# Iteration 443: diff = <object type:float64>
# Iteration 444: diff = <object type:float64>
# Iteration 445: diff = <object type:float64>
# Iteration 446: diff = <object type:float64>
# Iteration 447: diff = <object type:float64>
# Iteration 448: diff = <object type:float64>
# Iteration 449: diff = <object type:float64>
# Iteration 450: diff = <object type:float64>
# Iteration 451: diff = <object type:float64>
# Iteration 452: diff = <object type:float64>
# Iteration 453: diff = <object type:float64>
# Iteration 454: diff = <object type:float64>
# Iteration 455: diff = <object type:float64>
# Iteration 456: diff = <object type:float64>
# Iteration 457: diff = <object type:float64>
# Iteration 458: diff = <object type:float64>
# Iteration 459: diff = <object type:float64>
# Iteration 460: diff = <object type:float64>
# Iteration 461: diff = <object type:float64>
# Iteration 462: diff = <object type:float64>
# Iteration 463: diff = <object type:float64>
# Iteration 464: diff = <object type:float64>
# Iteration 465: diff = <object type:float64>
# Iteration 466: diff = <object type:float64>
# Iteration 467: diff = <object type:float64>
# Iteration 468: diff = <object type:float64>
# Iteration 469: diff = <object type:float64>
# Iteration 470: diff = <object type:float64>
# Iteration 471: diff = <object type:float64>
# Iteration 472: diff = <object type:float64>
# Iteration 473: diff = <object type:float64>
# Iteration 474: diff = <object type:float64>
# Iteration 475: diff = <object type:float64>
# Iteration 476: diff = <object type:float64>
# Iteration 477: diff = <object type:float64>
# Iteration 478: diff = <object type:float64>
# Iteration 479: diff = <object type:float64>
# Iteration 480: diff = <object type:float64>
# Iteration 481: diff = <object type:float64>
# Iteration 482: diff = <object type:float64>
# Iteration 483: diff = <object type:float64>
# Iteration 484: diff = <object type:float64>
# Iteration 485: diff = <object type:float64>
# Iteration 486: diff = <object type:float64>
# Iteration 487: diff = <object type:float64>
# Iteration 488: diff = <object type:float64>
# Iteration 489: diff = <object type:float64>
# Iteration 490: diff = <object type:float64>
# Iteration 491: diff = <object type:float64>
# Iteration 492: diff = <object type:float64>
# Iteration 493: diff = <object type:float64>
# Iteration 494: diff = <object type:float64>
# Iteration 495: diff = <object type:float64>
# Iteration 496: diff = <object type:float64>
# Iteration 497: diff = <object type:float64>
# Iteration 498: diff = <object type:float64>
# Iteration 499: diff = <object type:float64>
# Iteration 500: diff = <object type:float64>
# Iteration 501: diff = <object type:float64>
# Iteration 502: diff = <object type:float64>
# Iteration 503: diff = <object type:float64>
# Iteration 504: diff = <object type:float64>
# Iteration 505: diff = <object type:float64>
# Iteration 506: diff = <object type:float64>
# Iteration 507: diff = <object type:float64>
# Iteration 508: diff = <object type:float64>
# Iteration 509: diff = <object type:float64>
# Iteration 510: diff = <object type:float64>
# Iteration 511: diff = <object type:float64>
# Iteration 512: diff = <object type:float64>
# Iteration 513: diff = <object type:float64>
# Iteration 514: diff = <object type:float64>
# Iteration 515: diff = <object type:float64>
# Iteration 516: diff = <object type:float64>
# Iteration 517: diff = <object type:float64>
# Iteration 518: diff = <object type:float64>
# Iteration 519: diff = <object type:float64>
# Iteration 520: diff = <object type:float64>
# Iteration 521: diff = <object type:float64>
# Iteration 522: diff = <object type:float64>
# Iteration 523: diff = <object type:float64>
# Iteration 524: diff = <object type:float64>
# Iteration 525: diff = <object type:float64>
# Iteration 526: diff = <object type:float64>
# Iteration 527: diff = <object type:float64>
# Iteration 528: diff = <object type:float64>
# Iteration 529: diff = <object type:float64>
# Iteration 530: diff = <object type:float64>
# Iteration 531: diff = <object type:float64>
# Iteration 532: diff = <object type:float64>
# Iteration 533: diff = <object type:float64>
# Iteration 534: diff = <object type:float64>
# Iteration 535: diff = <object type:float64>
# Iteration 536: diff = <object type:float64>
# Iteration 537: diff = <object type:float64>
# Iteration 538: diff = <object type:float64>
# Iteration 539: diff = <object type:float64>
# Iteration 540: diff = <object type:float64>
# Iteration 541: diff = <object type:float64>
# Iteration 542: diff = <object type:float64>
# Iteration 543: diff = <object type:float64>
# Iteration 544: diff = <object type:float64>
# Iteration 545: diff = <object type:float64>
# Iteration 546: diff = <object type:float64>
# Iteration 547: diff = <object type:float64>
# Iteration 548: diff = <object type:float64>
# Iteration 549: diff = <object type:float64>
# Iteration 550: diff = <object type:float64>
# Iteration 551: diff = <object type:float64>
# Iteration 552: diff = <object type:float64>
# Iteration 553: diff = <object type:float64>
# Iteration 554: diff = <object type:float64>
# Iteration 555: diff = <object type:float64>
# Iteration 556: diff = <object type:float64>
# Iteration 557: diff = <object type:float64>
# Iteration 558: diff = <object type:float64>
# Iteration 559: diff = <object type:float64>
# Iteration 560: diff = <object type:float64>
# Iteration 561: diff = <object type:float64>
# Iteration 562: diff = <object type:float64>
# Iteration 563: diff = <object type:float64>
# Iteration 564: diff = <object type:float64>
# Iteration 565: diff = <object type:float64>
# Iteration 566: diff = <object type:float64>
# Iteration 567: diff = <object type:float64>
# Iteration 568: diff = <object type:float64>
# Iteration 569: diff = <object type:float64>
# Iteration 570: diff = <object type:float64>
# Iteration 571: diff = <object type:float64>
# Iteration 572: diff = <object type:float64>
# Iteration 573: diff = <object type:float64>
# Iteration 574: diff = <object type:float64>
# Iteration 575: diff = <object type:float64>
# Iteration 576: diff = <object type:float64>
# Iteration 577: diff = <object type:float64>
# Iteration 578: diff = <object type:float64>
# Iteration 579: diff = <object type:float64>
# Iteration 580: diff = <object type:float64>
# Iteration 581: diff = <object type:float64>
# Iteration 582: diff = <object type:float64>
# Iteration 583: diff = <object type:float64>
# Iteration 584: diff = <object type:float64>
# Iteration 585: diff = <object type:float64>
# Iteration 586: diff = <object type:float64>
# Iteration 587: diff = <object type:float64>
# Iteration 588: diff = <object type:float64>
# Iteration 589: diff = <object type:float64>
# Iteration 590: diff = <object type:float64>
# Iteration 591: diff = <object type:float64>
# Iteration 592: diff = <object type:float64>
# Iteration 593: diff = <object type:float64>
# Iteration 594: diff = <object type:float64>
# Iteration 595: diff = <object type:float64>
# Iteration 596: diff = <object type:float64>
# Iteration 597: diff = <object type:float64>
# Iteration 598: diff = <object type:float64>
# Iteration 599: diff = <object type:float64>
# Iteration 600: diff = <object type:float64>
# Iteration 601: diff = <object type:float64>
# Iteration 602: diff = <object type:float64>
# Iteration 603: diff = <object type:float64>
# Iteration 604: diff = <object type:float64>
# Iteration 605: diff = <object type:float64>
# Iteration 606: diff = <object type:float64>
# Iteration 607: diff = <object type:float64>
# Iteration 608: diff = <object type:float64>
# Iteration 609: diff = <object type:float64>
# Iteration 610: diff = <object type:float64>
# Iteration 611: diff = <object type:float64>
# Iteration 612: diff = <object type:float64>
# Iteration 613: diff = <object type:float64>
# Iteration 614: diff = <object type:float64>
# Iteration 615: diff = <object type:float64>
# Iteration 616: diff = <object type:float64>
# Iteration 617: diff = <object type:float64>
# Iteration 618: diff = <object type:float64>
# Iteration 619: diff = <object type:float64>
# Iteration 620: diff = <object type:float64>
# Iteration 621: diff = <object type:float64>
# Iteration 622: diff = <object type:float64>
# Iteration 623: diff = <object type:float64>
# Iteration 624: diff = <object type:float64>
# Iteration 625: diff = <object type:float64>
# Iteration 626: diff = <object type:float64>
# Iteration 627: diff = <object type:float64>
# Iteration 628: diff = <object type:float64>
# Iteration 629: diff = <object type:float64>
# Iteration 630: diff = <object type:float64>
# Iteration 631: diff = <object type:float64>
# Iteration 632: diff = <object type:float64>
# Iteration 633: diff = <object type:float64>
# Iteration 634: diff = <object type:float64>
# Iteration 635: diff = <object type:float64>
# Iteration 636: diff = <object type:float64>
# Iteration 637: diff = <object type:float64>
# Iteration 638: diff = <object type:float64>
# Iteration 639: diff = <object type:float64>
# Iteration 640: diff = <object type:float64>
# Iteration 641: diff = <object type:float64>
# Iteration 642: diff = <object type:float64>
# Iteration 643: diff = <object type:float64>
# Iteration 644: diff = <object type:float64>
# Iteration 645: diff = <object type:float64>
# Iteration 646: diff = <object type:float64>
# Iteration 647: diff = <object type:float64>
# Iteration 648: diff = <object type:float64>
# Iteration 649: diff = <object type:float64>
# Iteration 650: diff = <object type:float64>
# Iteration 651: diff = <object type:float64>
# Iteration 652: diff = <object type:float64>
# Iteration 653: diff = <object type:float64>
# Iteration 654: diff = <object type:float64>
# Iteration 655: diff = <object type:float64>
# Iteration 656: diff = <object type:float64>
# Iteration 657: diff = <object type:float64>
# Iteration 658: diff = <object type:float64>
# Iteration 659: diff = <object type:float64>
# Iteration 660: diff = <object type:float64>
# Iteration 661: diff = <object type:float64>
# Iteration 662: diff = <object type:float64>
# Iteration 663: diff = <object type:float64>
# Iteration 664: diff = <object type:float64>
# Iteration 665: diff = <object type:float64>
# Iteration 666: diff = <object type:float64>
# Iteration 667: diff = <object type:float64>
# Iteration 668: diff = <object type:float64>
# Iteration 669: diff = <object type:float64>
# Iteration 670: diff = <object type:float64>
# Iteration 671: diff = <object type:float64>
# Iteration 672: diff = <object type:float64>
# Iteration 673: diff = <object type:float64>
# Iteration 674: diff = <object type:float64>
# Iteration 675: diff = <object type:float64>
# Iteration 676: diff = <object type:float64>
# Iteration 677: diff = <object type:float64>
# Iteration 678: diff = <object type:float64>
# Iteration 679: diff = <object type:float64>
# Iteration 680: diff = <object type:float64>
# Iteration 681: diff = <object type:float64>
# Iteration 682: diff = <object type:float64>
# Iteration 683: diff = <object type:float64>
# Iteration 684: diff = <object type:float64>
# Iteration 685: diff = <object type:float64>
# Iteration 686: diff = <object type:float64>
# Iteration 687: diff = <object type:float64>
# Iteration 688: diff = <object type:float64>
# Iteration 689: diff = <object type:float64>
# Iteration 690: diff = <object type:float64>
# Iteration 691: diff = <object type:float64>
# Iteration 692: diff = <object type:float64>
# Iteration 693: diff = <object type:float64>
# Iteration 694: diff = <object type:float64>
# Iteration 695: diff = <object type:float64>
# Iteration 696: diff = <object type:float64>
# Iteration 697: diff = <object type:float64>
# Iteration 698: diff = <object type:float64>
# Iteration 699: diff = <object type:float64>
# Iteration 700: diff = <object type:float64>
# Iteration 701: diff = <object type:float64>
# Iteration 702: diff = <object type:float64>
# Iteration 703: diff = <object type:float64>
# Iteration 704: diff = <object type:float64>
# Iteration 705: diff = <object type:float64>
# Iteration 706: diff = <object type:float64>
# Iteration 707: diff = <object type:float64>
# Iteration 708: diff = <object type:float64>
# Iteration 709: diff = <object type:float64>
# Iteration 710: diff = <object type:float64>
# Iteration 711: diff = <object type:float64>
# Iteration 712: diff = <object type:float64>
# Iteration 713: diff = <object type:float64>
# Iteration 714: diff = <object type:float64>
# Iteration 715: diff = <object type:float64>
# Iteration 716: diff = <object type:float64>
# Iteration 717: diff = <object type:float64>
# Iteration 718: diff = <object type:float64>
# Iteration 719: diff = <object type:float64>
# Iteration 720: diff = <object type:float64>
# Iteration 721: diff = <object type:float64>
# Iteration 722: diff = <object type:float64>
# Iteration 723: diff = <object type:float64>
# Iteration 724: diff = <object type:float64>
# Iteration 725: diff = <object type:float64>
# Iteration 726: diff = <object type:float64>
# Iteration 727: diff = <object type:float64>
# Iteration 728: diff = <object type:float64>
# Iteration 729: diff = <object type:float64>
# Iteration 730: diff = <object type:float64>
# Iteration 731: diff = <object type:float64>
# Iteration 732: diff = <object type:float64>
# Iteration 733: diff = <object type:float64>
# Iteration 734: diff = <object type:float64>
# Iteration 735: diff = <object type:float64>
# Iteration 736: diff = <object type:float64>
# Iteration 737: diff = <object type:float64>
# Iteration 738: diff = <object type:float64>
# Iteration 739: diff = <object type:float64>
# Iteration 740: diff = <object type:float64>
# Iteration 741: diff = <object type:float64>
# Iteration 742: diff = <object type:float64>
# Iteration 743: diff = <object type:float64>
# Iteration 744: diff = <object type:float64>
# Iteration 745: diff = <object type:float64>
# Iteration 746: diff = <object type:float64>
# Iteration 747: diff = <object type:float64>
# Iteration 748: diff = <object type:float64>
# Iteration 749: diff = <object type:float64>
# Iteration 750: diff = <object type:float64>
# Iteration 751: diff = <object type:float64>
# Iteration 752: diff = <object type:float64>
# Iteration 753: diff = <object type:float64>
# Iteration 754: diff = <object type:float64>
# Iteration 755: diff = <object type:float64>
# Iteration 756: diff = <object type:float64>
# Iteration 757: diff = <object type:float64>
# Iteration 758: diff = <object type:float64>
# Iteration 759: diff = <object type:float64>
# Iteration 760: diff = <object type:float64>
# Iteration 761: diff = <object type:float64>
# Iteration 762: diff = <object type:float64>
# Iteration 763: diff = <object type:float64>
# Iteration 764: diff = <object type:float64>
# Iteration 765: diff = <object type:float64>
# Iteration 766: diff = <object type:float64>
# Iteration 767: diff = <object type:float64>
# Iteration 768: diff = <object type:float64>
# Iteration 769: diff = <object type:float64>
# Iteration 770: diff = <object type:float64>
# Iteration 771: diff = <object type:float64>
# Iteration 772: diff = <object type:float64>
# Iteration 773: diff = <object type:float64>
# Iteration 774: diff = <object type:float64>
# Iteration 775: diff = <object type:float64>
# Iteration 776: diff = <object type:float64>
# Iteration 777: diff = <object type:float64>
# Iteration 778: diff = <object type:float64>
# Iteration 779: diff = <object type:float64>
# Iteration 780: diff = <object type:float64>
# Iteration 781: diff = <object type:float64>
# Iteration 782: diff = <object type:float64>
# Iteration 783: diff = <object type:float64>
# Iteration 784: diff = <object type:float64>
# Iteration 785: diff = <object type:float64>
# Iteration 786: diff = <object type:float64>
# Iteration 787: diff = <object type:float64>
# Iteration 788: diff = <object type:float64>
# Iteration 789: diff = <object type:float64>
# Iteration 790: diff = <object type:float64>
# Iteration 791: diff = <object type:float64>
# Iteration 792: diff = <object type:float64>
# Iteration 793: diff = <object type:float64>
# Iteration 794: diff = <object type:float64>
# Iteration 795: diff = <object type:float64>
# Iteration 796: diff = <object type:float64>
# Iteration 797: diff = <object type:float64>
# Iteration 798: diff = <object type:float64>
# Iteration 799: diff = <object type:float64>
# Iteration 800: diff = <object type:float64>
# Iteration 801: diff = <object type:float64>
# Iteration 802: diff = <object type:float64>
# Iteration 803: diff = <object type:float64>
# Iteration 804: diff = <object type:float64>
# Iteration 805: diff = <object type:float64>
# Iteration 806: diff = <object type:float64>
# Iteration 807: diff = <object type:float64>
# Iteration 808: diff = <object type:float64>
# Iteration 809: diff = <object type:float64>
# Iteration 810: diff = <object type:float64>
# Iteration 811: diff = <object type:float64>
# Iteration 812: diff = <object type:float64>
# Iteration 813: diff = <object type:float64>
# Iteration 814: diff = <object type:float64>
# Iteration 815: diff = <object type:float64>
# Iteration 816: diff = <object type:float64>
# Iteration 817: diff = <object type:float64>
# Iteration 818: diff = <object type:float64>
# Iteration 819: diff = <object type:float64>
# Iteration 820: diff = <object type:float64>
# Iteration 821: diff = <object type:float64>
# Iteration 822: diff = <object type:float64>
# Iteration 823: diff = <object type:float64>
# Iteration 824: diff = <object type:float64>
# Iteration 825: diff = <object type:float64>
# Iteration 826: diff = <object type:float64>
# Iteration 827: diff = <object type:float64>
# Iteration 828: diff = <object type:float64>
# Iteration 829: diff = <object type:float64>
# Iteration 830: diff = <object type:float64>
# Iteration 831: diff = <object type:float64>
# Iteration 832: diff = <object type:float64>
# Iteration 833: diff = <object type:float64>
# Iteration 834: diff = <object type:float64>
# Iteration 835: diff = <object type:float64>
# Iteration 836: diff = <object type:float64>
# Iteration 837: diff = <object type:float64>
# Iteration 838: diff = <object type:float64>
# Iteration 839: diff = <object type:float64>
# Iteration 840: diff = <object type:float64>
# Iteration 841: diff = <object type:float64>
# Iteration 842: diff = <object type:float64>
# Iteration 843: diff = <object type:float64>
# Iteration 844: diff = <object type:float64>
# Iteration 845: diff = <object type:float64>
# Iteration 846: diff = <object type:float64>
# Iteration 847: diff = <object type:float64>
# Iteration 848: diff = <object type:float64>
# Iteration 849: diff = <object type:float64>
# Iteration 850: diff = <object type:float64>
# Iteration 851: diff = <object type:float64>
# Iteration 852: diff = <object type:float64>
# Iteration 853: diff = <object type:float64>
# Iteration 854: diff = <object type:float64>
# Iteration 855: diff = <object type:float64>
# Iteration 856: diff = <object type:float64>
# Iteration 857: diff = <object type:float64>
# Iteration 858: diff = <object type:float64>
# Iteration 859: diff = <object type:float64>
# Iteration 860: diff = <object type:float64>
# Iteration 861: diff = <object type:float64>
# Iteration 862: diff = <object type:float64>
# Iteration 863: diff = <object type:float64>
# Iteration 864: diff = <object type:float64>
# Iteration 865: diff = <object type:float64>
# Iteration 866: diff = <object type:float64>
# Iteration 867: diff = <object type:float64>
# Iteration 868: diff = <object type:float64>
# Iteration 869: diff = <object type:float64>
# Iteration 870: diff = <object type:float64>
# Iteration 871: diff = <object type:float64>
# Iteration 872: diff = <object type:float64>
# Iteration 873: diff = <object type:float64>
# Iteration 874: diff = <object type:float64>
# Iteration 875: diff = <object type:float64>
# Iteration 876: diff = <object type:float64>
# Iteration 877: diff = <object type:float64>
# Iteration 878: diff = <object type:float64>
# Iteration 879: diff = <object type:float64>
# Iteration 880: diff = <object type:float64>
# Iteration 881: diff = <object type:float64>
# Iteration 882: diff = <object type:float64>
# Iteration 883: diff = <object type:float64>
# Iteration 884: diff = <object type:float64>
# Iteration 885: diff = <object type:float64>
# Iteration 886: diff = <object type:float64>
# Iteration 887: diff = <object type:float64>
# Iteration 888: diff = <object type:float64>
# Iteration 889: diff = <object type:float64>
# Iteration 890: diff = <object type:float64>
# Iteration 891: diff = <object type:float64>
# Iteration 892: diff = <object type:float64>
# Iteration 893: diff = <object type:float64>
# Iteration 894: diff = <object type:float64>
# Iteration 895: diff = <object type:float64>
# Iteration 896: diff = <object type:float64>
# Iteration 897: diff = <object type:float64>
# Iteration 898: diff = <object type:float64>
# Iteration 899: diff = <object type:float64>
# Iteration 900: diff = <object type:float64>
# Iteration 901: diff = <object type:float64>
# Iteration 902: diff = <object type:float64>
# Iteration 903: diff = <object type:float64>
# Iteration 904: diff = <object type:float64>
# Iteration 905: diff = <object type:float64>
# Iteration 906: diff = <object type:float64>
# Iteration 907: diff = <object type:float64>
# Iteration 908: diff = <object type:float64>
# Iteration 909: diff = <object type:float64>
# Iteration 910: diff = <object type:float64>
# Iteration 911: diff = <object type:float64>
# Iteration 912: diff = <object type:float64>
# Iteration 913: diff = <object type:float64>
# Iteration 914: diff = <object type:float64>
# Iteration 915: diff = <object type:float64>
# Iteration 916: diff = <object type:float64>
# Iteration 917: diff = <object type:float64>
# Iteration 918: diff = <object type:float64>
# Iteration 919: diff = <object type:float64>
# Iteration 920: diff = <object type:float64>
# Iteration 921: diff = <object type:float64>
# Iteration 922: diff = <object type:float64>
# Iteration 923: diff = <object type:float64>
# Iteration 924: diff = <object type:float64>
# Iteration 925: diff = <object type:float64>
# Iteration 926: diff = <object type:float64>
# Iteration 927: diff = <object type:float64>
# Iteration 928: diff = <object type:float64>
# Iteration 929: diff = <object type:float64>
# Iteration 930: diff = <object type:float64>
# Iteration 931: diff = <object type:float64>
# Iteration 932: diff = <object type:float64>
# Iteration 933: diff = <object type:float64>
# Iteration 934: diff = <object type:float64>
# Iteration 935: diff = <object type:float64>
# Iteration 936: diff = <object type:float64>
# Iteration 937: diff = <object type:float64>
# Iteration 938: diff = <object type:float64>
# Iteration 939: diff = <object type:float64>
# Iteration 940: diff = <object type:float64>
# Iteration 941: diff = <object type:float64>
# Iteration 942: diff = <object type:float64>
# Iteration 943: diff = <object type:float64>
# Iteration 944: diff = <object type:float64>
# Iteration 945: diff = <object type:float64>
# Iteration 946: diff = <object type:float64>
# Iteration 947: diff = <object type:float64>
# Iteration 948: diff = <object type:float64>
# Iteration 949: diff = <object type:float64>
# Iteration 950: diff = <object type:float64>
# Iteration 951: diff = <object type:float64>
# Iteration 952: diff = <object type:float64>
# Iteration 953: diff = <object type:float64>
# Iteration 954: diff = <object type:float64>
# Iteration 955: diff = <object type:float64>
# Iteration 956: diff = <object type:float64>
# Iteration 957: diff = <object type:float64>
# Iteration 958: diff = <object type:float64>
# Iteration 959: diff = <object type:float64>
# Iteration 960: diff = <object type:float64>
# Iteration 961: diff = <object type:float64>
# Iteration 962: diff = <object type:float64>
# Iteration 963: diff = <object type:float64>
# Iteration 964: diff = <object type:float64>
# Iteration 965: diff = <object type:float64>
# Iteration 966: diff = <object type:float64>
# Iteration 967: diff = <object type:float64>
# Iteration 968: diff = <object type:float64>
# Iteration 969: diff = <object type:float64>
# Iteration 970: diff = <object type:float64>
# Iteration 971: diff = <object type:float64>
# Iteration 972: diff = <object type:float64>
# Iteration 973: diff = <object type:float64>
# Iteration 974: diff = <object type:float64>
# Iteration 975: diff = <object type:float64>
# Iteration 976: diff = <object type:float64>
# Iteration 977: diff = <object type:float64>
# Iteration 978: diff = <object type:float64>
# Iteration 979: diff = <object type:float64>
# Iteration 980: diff = <object type:float64>
# Iteration 981: diff = <object type:float64>
# Iteration 982: diff = <object type:float64>
# Iteration 983: diff = <object type:float64>
# Iteration 984: diff = <object type:float64>
# Iteration 985: diff = <object type:float64>
# Iteration 986: diff = <object type:float64>
# Iteration 987: diff = <object type:float64>
# Iteration 988: diff = <object type:float64>
# Iteration 989: diff = <object type:float64>
# Iteration 990: diff = <object type:float64>
# Iteration 991: diff = <object type:float64>
# Iteration 992: diff = <object type:float64>
# Iteration 993: diff = <object type:float64>
# Iteration 994: diff = <object type:float64>
# Iteration 995: diff = <object type:float64>
# Iteration 996: diff = <object type:float64>
# Iteration 997: diff = <object type:float64>
# Iteration 998: diff = <object type:float64>
# Iteration 999: diff = <object type:float64>
# Iteration 1000: diff = <object type:float64>
# Total iterations until convergence: 1000
# Stationary distribution f_{i,j}:
# [[3.53800993e+066 8.22859281e+057]
#  [1.03211740e+219 1.63495838e+222]
#  [1.00000000e-001 1.00000000e-001]
#  [1.00000000e-001 1.00000000e-001]
#  [1.00000000e-001 1.00000000e-001]]
# 0.05

# %%
nk = 3



# Step: initialization of the distribution functions */

# Variant 1: uniform distribution
gk = np.ones((nk,2))/nk
gk = gk * np.transpose(pp1)
gk
# Out:
# array([[0.04703448, 0.28629886],
#        [0.04703448, 0.28629886],
#        [0.04703448, 0.28629886]])

# %%
nk = 3



# Step: initialization of the distribution functions */

# Variant 1: uniform distribution
gk = np.ones((nk,2))/nk
gk = gk * np.transpose(pp1)

# # Variant 2: equal distribution, all hold KK0
# gk = np.zeros((nk,2))
# gk[nk0,0] = pp1[0]
# gk[nk0,1] = pp1[1]


gk0 = gk+0             # distribution in period t
gk = np.zeros((nk,2))    # distribution in period t+1

for l in range(2):     # iteration over employment types in period t
    # prepare interpolation of optimal next-period asset policy
    aopt_polate = interpolate.interp1d(a_grid_pf,pf[:,l])
    for i in range(nk):  # iteration over assets in period t
        k0 = a_grid[i]  #a_grid_pfとa_gridは一般に異なるかもしれないので、pfのinterpolationをする必要がある
        if k0 <= amin:
            k1 = pf[0,l]
        elif k0 >= amax:
          k1=pf[na-1,l]
        else:
          k1 = aopt_polate(k0) # linear interpolation for a'(a)

        if k1 <= amin:
            gk[0,0] = gk[0,0] + gk0[i,l]*prob[l,0]
            gk[0,1]= gk[0,1] + gk0[i,l]*prob[l,1]
        elif k1 >= amax:
            gk[nk-1,0] = gk[nk-1,0] + gk0[i,l]*prob[l,0]
            gk[nk-1,1] = gk[nk-1,1] + gk0[i,l]*prob[l,1]
        elif (k1>amin) and (k1<amax):
            j = sum(a_grid<=k1) # k1 lies between ag[j-1] and ag[j]
            n0 = (k1-a_grid[j-1]) / (a_grid[j]-a_grid[j-1])
            gk[j,0] = gk[j,0] + n0*gk0[i,l]*prob[l,0]
            gk[j,1] = gk[j,1] + n0*gk0[i,l]*prob[l,1]
            gk[j-1,0] =gk[j-1,0] + (1-n0)*gk0[i,l]*prob[l,0]
            gk[j-1,1] =gk[j-1,1] + (1-n0)*gk0[i,l]*prob[l,1]

# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Jan 4 11:16:54 2020


author: Burkhard Heer

book: Dynamic General Equilibrium Modeling: Computational
        Methods and Applications, with Alfred Maussner

Chapter 8.2., distribution function

Algorithm 8.2.3 in Heer/Maussner (2023)

computation of the policy functions and the distribution function
in the heterogenous-agent neoclassical growth model
with value function iteration

Linear interpolation between grid points

Maximization of value function: golden section search method


"""

# Part 1: import libraries
import numpy as np
from scipy.linalg import inv
from scipy import interpolate
import time
import matplotlib.pyplot as plt
import math

log = math.log

# Part 2: functions
# equivec1 computes the ergodic distribution
# see pages 654-656 in Heer/Maussner (2009)
# on DSGE modeling, 2nd edition
def equivec1(p):
    nrows,ncols = p.shape
    for i in range(nrows):
        p[i,i] = p[i,i]-1

    q = p[:,0:nrows-1]
    # appends column vector
    q = np.c_[q,np.ones(nrows)]
    x = np.zeros(nrows-1)
    # appends element in row vector
    x = np.r_[x,1]
    y =  np.transpose(x) @ inv(q)
    return np.transpose(y)


#
# wage function
def wage_rate(k,l):
    return (1-alpha) * k**alpha * l**(-alpha)

# interest rate function
def interest_rate(k,l):
    return alpha * k**(alpha - 1) * l**(1-alpha) - delta


# utility function
def utility(x):
    if sigma==1:
        return  log(x)
    else:
        return x**(1-sigma) / (1-sigma)


# right-hand-side of the Bellman equation
# input:
# a0 - wealth a in period t
# a1 - wealth a' in period t+1
# y - employment status in period t
# output:
# rhs of Bellman eq.
def bellman(a0,a1,y):
   if y==0:     # y=0: employed, y=1: unemployed
      c = (1+(1-tau)*r) * a0 + (1-tau)*w - a1
   else:
       c = (1+(1-tau)*r)*a0 + b - a1

   if c<0:
      return negvalue

   if a1>amax:
      return a1**2*negvalue

   # output: right-hand side of the Bellman equation
   return utility(c) + beta*(prob[y,0]*value(a1,0) + prob[y,1]*value(a1,1))



# value interpolates value function vold[a,e] at a
def value(x,y):
    if y==0:
        return ve_polate(x)
    else:
        return vu_polate(x)


# value1 rewrites the Bellman function
# as a function of one variable x=a', the next-period asset level
# for given present period assets a[i] and employment status e
# -> function in one argument x necessary for applying
# Golden Section Search
def value1(x):
    return bellman(ainit,x,e)

# searches the MAXIMUM using golden section search
# see also Chapter 11.6.1 in Heer/Maussner, 2009,
# Dynamic General Equilibrium Modeling: Computational
# Methods and Applications, 2nd ed. (or later)
def GoldenSectionMax(f,ay,by,cy,tol):
    r1 = 0.61803399
    r2 = 1-r1
    x0 = ay
    x3 = cy
    if abs(cy-by) <= abs(by-ay):
        x1 = by
        x2 = by + r2 * (cy-by)
    else:
        x2 = by
        x1 = by - r2 * (by-ay)

    f1 = - f(x1)
    f2 = - f(x2)

    while abs(x3-x0) > tol*(abs(x1)+abs(x2)):
        if f2<f1:
            x0 = x1
            x1 = x2
            x2 = r1*x1+r2*x3
            f1 = f2
            f2 = -f(x2)
        else:
            x3 = x2
            x2 = x1
            x1 = r1*x2+r2*x0
            f2 = f1
            f1 = -f(x1)

    if f1 <= f2:
        xmin = x1
    else:
        xmin = x2

    return xmin

def testfunc(x):
    return -x**2 + 4*x + 6

# test goldensectionsearch
xmax = GoldenSectionMax(testfunc,-2.2,0.0,10.0,0.001)
print(xmax)

start_time = time.time()

# Part 3: Numerical parameters
tol = 0.001             # stopping criterion for final solution of K
tol1 = 1e-7             # stopping criterion for golden section search
tolg = 0.0000001        # stopping criterion for distribution function
negvalue = -1e10             # initialization for the value function
eps = 0.05              # minimum distance between grid point amin and amin+varepsilon
                         # in order to check if amin is binding lower bound
nit = 100                # maximum number of maximum iterations over value function
ngk = 0                  # initial number of iterations over distribution function
crit1 = 1 + tol          # percentage deviation in the iteration over the aggregate capital stock
critg = 1 + tol          # deviation of two successive solutions for distribution function:
                         # kritg=sumc(abs(gk0-gk));
nq = 70                  # maximum number of iterations over K, outer loop

psi1 = 0.95              # linear update of K and tau in the outer loop
                         # K^{i+1} = psi1 * K^i + (1-psi1) * K^{i*}, where K^{i*} new solution in iteration i
kbarq = np.zeros(nq)
k1barq = np.zeros(nq)           # convergence of kk1 ?
kritvq = np.zeros(nq)       # convergence of value function
crit = 1+tol                    # error in value function: crit=meanc(abs(vold-v));


# Part 4: Parameterization of the model
alpha = 0.36
beta = 0.995
delta = 0.005
sigma = 2
tau = 0.02
r = 0.005
rep = 0.25
pp0 = np.array([[0.9565,0.0435],[0.5,0.5]]) # for the computaton of the
                                            # ergodic distribution
prob = pp0 + 0  # entries are the same as in pp0



# asset grid: Value function
amin = -2               # lower bound asset grid over value function
amax = 3000             # upper bound
na = 201                 # number of equispaced points
a =  np.linspace(amin, amax, na)   # asset grid


# asset grid: Distribution function: Step 5.1 from Algorithm 7.2.2
nk = 3*na            # number of asset grid points over distribution
nk = na
ag =  np.linspace(amin, amax, nk)   # asset grid for distribution function

# initialization distribution function
gk = np.zeros((nk,2))

# Part 5: Computation of the
# stationary employment /unemployment
# with the help of the ergodic distribution
print(prob)
pp1 = equivec1(pp0)
nn0 = pp1[0] # measure of employed households in economy
print(pp1)
print(prob)

# Part 6: Initial guess K and tau
kk0 = (alpha/(1/beta-1+delta))**(1/(1-alpha))*nn0

# Compute w and r and b
w0 = wage_rate(kk0,nn0)
r0 = interest_rate(kk0, nn0)
b = w0*rep  # unemployment insurance


# Part 7:
# initialization of the value function, consumption and next-period asset
#              policy functions
# assumption: employed/unemployed consumes his income permanently

ve = utility( (1-tau)*r*a+(1-tau)*w0) # utility of the employed with asset a
vu = utility( (1-tau)*r*a+b )    # utility of the unemployed with asset a
v =   np.c_[ve,vu]
v = v/(1-beta)                  # agents consume their income
copt = np.zeros((na,2))         # optimal consumption
aopt = np.zeros((na,2))         # optimal next-period assets

kk1 = kk0-1                  # initialization so that kk1 \ne kk0


nk0 = sum(ag<=kk0)              # asset grid point ag[nk0] is chosen as initial distribution
                                # => all households hold capital stock kk0

# outer loop over aggregate capital stock K
q = -1
while q<nq-1  and (crit1>tol or ngk<25000):    # iteration over K
    q = q+1
    w = wage_rate(kk0,nn0)
    r = interest_rate(kk0, nn0)

    kbarq[q] = kk0 # saving aggregate capital stock in iteration q

    # slow increment of the number of iterations over distribution
    # gk, corresponding to the number of iteration i over f_i in the textbook
    if ngk<25000:
        ngk = ngk+500

    # mean wealth during iteration over f_i for given w, r and b
    kt = np.zeros(ngk)

    # incremental increase in number of iterations over value functions
    nit=nit+2

    # loop over value function
    crit=1+tol
    j = -1
    while j<=50 or (j<nit-1 and crit>tol):
        j=j+1

        vold = v + 0
        # prepare interpolation in value1()
        ve_polate = interpolate.interp1d(a,vold[:,0])
        vu_polate = interpolate.interp1d(a,vold[:,1])
        #print("iteration j~q: " + str([j,q]))
        #print("kk0~kk1 " + str([kk0,kk1]) )
        #sec = (time.time() - start_time)
        #ty_res = time.gmtime(sec)
        #res = time.strftime("%H : %M : %S", ty_res)
        #print(res)
        #print("error value function: " + str(crit) )
        #print("error k: " + str(crit1) )
        #print("error distribution function: " + str(critg))

        # ----------------------------------------------------------------
        #
        # Step: Compute the household's decision function
        #        Iteration of the value function
        #
        # -----------------------------------------------------------------

        # iteration over the employment status
        # e=0 employed, e=1 unemployed

        for e in range(2):
            l0 = -1  # initialization of a'
                    # exploiting monotonocity of a'(a)
            # iteration over the asset grid a = a_1,...a_na
            for i in range(na):
                ainit = a[i]
                l = l0
                v0 = negvalue
                # iteration over a' to bracket the maximum of
                # the rhs of the Bellman equation,
                # ax < bx < cx and a' is between ax and cx

                ax = a[0]
                bx = a[0]
                cx = amax

                while l<na-1:
                    l = l+1
                    if e==0:
                        c0 = (1+(1-tau)*r) * ainit + (1-tau)*w - a[l]
                    else:
                        c0 = (1+(1-tau)*r) * ainit + b - a[l]


                    if c0>0:
                        v1 = bellman(ainit,a[l],e)
                        if v1>v0:
                            v[i,e] = v1
                            if l==0:
                               ax=a[0]
                               bx=a[0]
                               cx=a[1]
                            elif l==na-1:
                                ax=a[na-2]
                                bx=a[na-1]
                                cx=a[na-1]
                            else:
                                ax=a[l-1]
                                bx=a[l]
                                cx=a[l+1]

                            v0=v1
                            l0=l-1
                        else:
                            l=na-1   # concavity of value function

                    else:
                        l=na-1


                if ax==bx:  # boundary optimum, ax=bx=a[1]
                    bx = ax+eps*(a[1]-a[0])
                    if value(bx,e)<value(ax,e):
                        aopt[i,e] = a[0]
                    else:
                        aopt[i,e] = GoldenSectionMax(value1,ax,bx,cx,tol1)
                elif bx==cx:  # boundary optimum, bx=cx=a[na-1]
                    bx = cx-eps*(a[na-1]-a[na-2])
                    if value(bx,e)<value(cx,e):
                        aopt[i,e] = a[na-1]
                    else:
                        aopt[i,e] = GoldenSectionMax(value1,ax,bx,cx,tol1)

                else:
                    aopt[i,e] = GoldenSectionMax(value1,ax,bx,cx,tol1)

                v[i,e] = bellman(a[i],aopt[i,e],e)

        x = abs(vold-v)
        crit = x.mean(0)  # mean of the columns, value functions of employed
                          # and unemployd
        crit = max(crit)

    if q==0: # plotting the value and policy function
        fig, ax = plt.subplots()
        label1 = 'employed'
        label2 = 'unemployed'
        ax.plot(a,v[:,0], linewidth=2, label=label1)
        ax.plot(a,v[:,1], linewidth=2, label=label2)
        ax.legend()
        plt.show()

    # iteration over value function complete
    copt[:,0] = (1+(1-tau)*r)*a + (1-tau)*w - aopt[:,0]
    copt[:,1] = (1+(1-tau)*r)*a + b - aopt[:,1]
    kritvq[q] = crit

    # iteration to find invariant distribution */

    kritg = 1+tol
    kconv = np.zeros(ngk+1) # convergence criterion
    # Step: initialization of the distribution functions */

    # Variant 1: uniform distribution
    #    gk = np.ones((nk,2))/nk
    #    gk = gk * np.transpose(pp1)
    #
    # Variant 2: equal distribution, all hold KK0
    gk = np.zeros((nk,2))
    gk[nk0,0] = pp1[0]
    gk[nk0,1] = pp1[1]

    for q1 in range(ngk):   # iteration over periods (dynamics of distribution)
         gk0 = gk+0             # distribution in period t
         gk = np.zeros((nk,2))    # distribution in period t+1

         for l in range(2):     # iteration over employment types in period t
             # prepare interpolation of optimal next-period asset policy
             aopt_polate = interpolate.interp1d(a,aopt[:,l])
             for i in range(nk):  # iteration over assets in period t
                 k0 = ag[i]
                 if k0 <= amin:
                     k1 = aopt[0,l]
                 elif k0 >= amax:
                    k1=aopt[na-1,l]
                 else:
                    k1 = aopt_polate(k0) # linear interpolation for a'(a)

                 if k1 <= amin:
                     gk[0,0] = gk[0,0] + gk0[i,l]*prob[l,0]
                     gk[0,1]= gk[0,1] + gk0[i,l]*prob[l,1]
                 elif k1 >= amax:
                     gk[nk-1,0] = gk[nk-1,0] + gk0[i,l]*prob[l,0]
                     gk[nk-1,1] = gk[nk-1,1] + gk0[i,l]*prob[l,1]
                 elif (k1>amin) and (k1<amax):
                     j = sum(ag<=k1) # k1 lies between ag[j-1] and ag[j]
                     n0 = (k1-ag[j-1]) / (ag[j]-ag[j-1])
                     gk[j,0] = gk[j,0] + n0*gk0[i,l]*prob[l,0]
                     gk[j,1] = gk[j,1] + n0*gk0[i,l]*prob[l,1]
                     gk[j-1,0] =gk[j-1,0] + (1-n0)*gk0[i,l]*prob[l,0]
                     gk[j-1,1] =gk[j-1,1] + (1-n0)*gk0[i,l]*prob[l,1]

         gk=gk/sum(sum(gk))
         kk1 = np.transpose(gk[:,0]+gk[:,1]) @ ag # new mean capital stock
         critg=sum(sum(abs(gk0-gk)))
         kconv[q1] = critg
         kt[q1] = kk1

    if q==0: # plotting the value and policy function
        fig, ax = plt.subplots()
        label1 = 'employed'
        label2 = 'unemployed'
        ax.plot(ag[0:200],gk[0:200,0], linewidth=2, label=label1)
        ax.plot(ag[0:200],gk[0:200,1], linewidth=2, label=label2)
        ax.legend()
        plt.show()



    crit1 = abs((kk1-kk0)/kk0)   # end outer loop over K, q=1,..

    print("kk0~kk1: " + str([kk0,kk1]) )
    print("outer iteration q: " + str(q))
    print("crit value fucntion: " +str(crit))
    print("crit K: " +str(crit1))
    print("crit distribution: " + str(critg))
    sec = (time.time() - start_time)
    ty_res = time.gmtime(sec)
    res = time.strftime("%H : %M : %S", ty_res)
    print(res)

    kk0 = psi1*kk0+(1-psi1)*kk1
    tau = b*pp1[1]/(w*nn0+r*kk0)


k1barq[q] = kk1
print("kk0~kk1 " + str([kk0,kk1]) )
sec = (time.time() - start_time)
ty_res = time.gmtime(sec)
res = time.strftime("%H : %M : %S", ty_res)
print(res)
print("error value function: " + str(crit) )
print("error k: " + str(crit1) )
print("error distribution function: " + str(critg))


plt.plot(kbarq)
plt.show()


plt.plot(kt)
plt.show()
