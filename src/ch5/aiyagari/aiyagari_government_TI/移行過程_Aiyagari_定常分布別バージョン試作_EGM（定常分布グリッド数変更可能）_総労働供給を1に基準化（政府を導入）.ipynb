# %% [markdown]
# # すべてをまとめて実行

# %% [markdown]
# ## インストール、インポート

# %%
# !pip install quantecon
# !pip install numba
# !pip install interpolation

# %%
import numpy as np
from quantecon.optimize import brentq
from quantecon.markov import rouwenhorst, tauchen
from interpolation import interp
from numba import njit, guvectorize
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import scipy

# %% [markdown]
# ## Aiyagariの設定

# %% [markdown]
# ### Calibration

# %%
# パラメータ
beta = 0.96
gamma = 3.0
rho = 0.6
sigma = 0.4
alpha = 0.36
delta = 0.08
b = 3.0

# %% [markdown]
# ### 政策関数の計算のための関数

# %%
# Maliarグリッド

@njit
def maliar_grid(a_min, a_max, N, theta):
		a_grid = np.empty(N)
		for i in range(1,N+1):
				a_grid[i-1] = a_min + (a_max - a_min)*((i-1)/(N-1))**theta

		return a_grid

# %%
# exponentialグリッド

@njit
def exponential_grid(a_min, a_max, N):
    """
    対数空間を使ったグリッド生成関数
    Parameters:
        a_min: float, グリッドの最小値
        a_max: float, グリッドの最大値
        N: int, グリッドの分割数
    Returns:
        grid: np.ndarray, 生成されたグリッド
    """
    # 対数変換
    log_a_min = np.log1p(a_min)  # log(1 + a_min)
    log_a_max = np.log1p(a_max)  # log(1 + a_max)

    # 等間隔のグリッドを生成
    log_grid = np.linspace(log_a_min, log_a_max, N)

    # 再変換して結果を格納
    grid = np.expm1(log_grid)  # exp(x) - 1
    return grid

# %%
# 補間のための関数（外挿あり）
@guvectorize(['void(float64[:], float64[:], float64[:], float64[:])'], '(n),(nq),(n)->(nq)')
def interpolate_y(x, xq, y, yq):
    """Efficient linear interpolation exploiting monotonicity.
    Extrapolates linearly when xq out of domain of x.
    """
    nxq, nx = xq.shape[0], x.shape[0]

    xi = 0
    x_low = x[0]
    x_high = x[1]
    for xqi_cur in range(nxq):
        xq_cur = xq[xqi_cur]
        while xi < nx - 2:
            if x_high >= xq_cur:
                break
            xi += 1
            x_low = x_high
            x_high = x[xi + 1]

        xqpi_cur = (x_high - xq_cur) / (x_high - x_low)
        yq[xqi_cur] = xqpi_cur * y[xi] + (1 - xqpi_cur) * y[xi + 1]

# %%
# 解く問題の設定を行う（パラメータ, グリッド, 効用関数や生産関数）
# モデルを変更する場合にはここを修正
class Setting:

    def __init__(self,
                 R=1.01,                          # 粗実質利子率
                 beta=0.99,                          # 割引因子
                 gamma=1,                          # 相対的リスク回避度(異時点間の代替弾力性の逆数)
                 b=3,                             # 内生的な状態変数の最小値, 借入制約
                 a_max=16,                        # 内生的な状態変数の最大値
                 na=21,                           # 内生的な状態変数のグリッド数
                 na_sd = 800,                     # 定常分布における資本のグリッド数
                 tau = 0.1,                       # 資本課税率
                 Xi = 0.1,                        # 所得移転額
                 mu=0,                            # 外生変数のAR(1)過程の定数項
                 rho=0.6,                        # 外生変数のAR(1)過程の慣性
                 sigma=0.4,                       # 外生変数のAR(1)過程のショック項の標準偏差
                 nz = 11,                         # 外生変数のグリッド数
                 w = 0,                         # 賃金
                 lambdaPF = 1):                 # 政策関数の更新度

        # パラメータを設定する
        self.R = R
        self.beta = beta
        self.b = b
        self.gamma = gamma
        self.na_sd = na_sd
        self.tau = tau
        self.Xi = Xi


        # 外生変数の遷移確率とグリッドを設定する

        #1 rowenhorst
        # mc = rouwenhorst(nz, rho, sigma, mu)
        # self.Pz = mc.P
        # self.z_grid = np.exp(mc.state_values)

        #2 tauchen
        mc = tauchen(nz, rho, sigma, mu, n_std = 2)
        self.Pz = np.array(mc.P)
        if mc.state_values is None:
           raise ValueError("mc.state_values is None, cannot apply np.exp.")
        self.z_grid = np.exp(mc.state_values)


        # 内生的な状態変数のグリッドを設定する
        # a_grid = np.linspace(-b, a_max, na)
        a_grid = maliar_grid(-b, a_max, na, 2)
        #a_grid = exponential_grid(-b, a_max, na)
        self.a_grid = a_grid


        # 賃金を設定
        self.w = w

        # 政策関数の更新度を設定する
        self.lambdaPF = lambdaPF

        # CRRA型効用関数と限界効用を定義する
        gamma = self.gamma
        if gamma == 1:
            self.utility = np.log
            self.mutility = njit(lambda x: 1 / x)
        else:
            self.utility = njit(lambda x: x**(1-gamma) / (1 - gamma))
            self.mutility = njit(lambda x: x**(-gamma))


		    # 政策関数の初期値を定義する
        z_grid = self.z_grid
        hfun_old = np.empty((len(a_grid), len(z_grid)))
        for i_a, a in enumerate(a_grid):
            for i_z, z in enumerate(z_grid):
                c_max = 0.5* (R * a + z + b)
                hfun_old[i_a, i_z] = c_max
        self.hfun_old = hfun_old


# 特定のアルゴリズムを実行して政策関数を更新する関数を出力する
# FOCを変更する場合やアルゴリズムを変更する場合はここを修正

# 今期の状態変数について繰り返し記号はi, 来期の状態変数について繰り返し記号はj

def EGMIterationWithGov(hp): # hpはSettingクラスからつくられるインスタンス

    # インスタンスからローカル変数を定義する
    R, beta, b, gamma, mutility, tau  = hp.R, hp.beta, hp.b, hp.gamma, hp.mutility, hp.tau
    a_grid, z_grid, Pz, w, Xi = hp.a_grid, hp.z_grid, hp.Pz, hp.w, hp.Xi

    R_net = 1 + (1-tau) * (R - 1.00)  # after-tax interest

    @njit
    def UpdatePF(h_old):

        h_new = np.empty_like(h_old)
        a_tilde = np.empty_like(a_grid)
        aprime_new = np.empty_like(a_grid)

        for i_z in range(len(z_grid)): # 今期の生産性について繰り返し
            z = z_grid[i_z]

            for j_a in range(len(a_grid)): # 来期の資産について繰り返し
                aprime = a_grid[j_a]

                expectation = 0
                for j_z in range(len(z_grid)): # 来期の生産性について繰り返し

                    # オイラー方程式の右辺を計算する
                    expectation += mutility(h_old[j_a, j_z]) * Pz[i_z, j_z]

                rhs = R_net * beta * expectation
                c_tilde = rhs**(-1.0/gamma)

                # 今期の資産を計算
                a_tilde[j_a] = (aprime - z*w - Xi + c_tilde)/R_net


            # 来期の資産の政策関数をinterpolationで求める
            interpolate_y(a_tilde, a_grid, a_grid, aprime_new)

            for i_a in range(len(a_grid)): # 今期の資産について繰り返し

                # 来期の資産の政策関数をinterpolationで求める
                #aprime_new = interp(a_tilde, a_grid, a_grid[i_a])

                # 借り入れ制約を考慮しつつ来期の資産を求める
                if aprime_new[i_a] < -b:
                    aprime_new[i_a] = -b
                else:
                    aprime_new[i_a] = aprime_new[i_a]

                # 消費の政策関数を求める
                h_new[i_a,i_z] = R_net * a_grid[i_a] + z*w + Xi - aprime_new[i_a]

        return h_new

    return UpdatePF



# メイン関数：特定のアルゴリズムでiterationを行い、問題を解く関数
# 基本的には変更する必要がない

def SolveProblem(hp,               # Settingクラスからつくられるインスタンス
                Algorithm,         # アルゴリズムを指定
                tol=1e-4,          # 許容繰り返し誤差
                max_iter=10000,     # iteration回数の最大値
                verbose=True,      # 進捗を表示するかどうか
                print_skip=25):    # 進捗を何回ごとに表示するか


    # インスタンスからローカル変数を定義する
    # R, beta, b, mutility = hp.R, hp.beta, hp.b, hp.mutility
    # a_grid, z_grid, Pz = hp.a_grid, hp.z_grid, hp.Pz
    lambdaPF = hp.lambdaPF
    hfun_old = hp.hfun_old

    # チェックのために外生変数のグリッドと遷移確率を表示する
    # print(f"About exogenous variables:")
    # print(f"grid is {z_grid}.")
    # print(f"Transition matrix is {Pz}.")



    # 政策関数を更新する関数を取得する
    UpdatePF = Algorithm(hp)

    # iterationを行い、問題を解く
    i = 0
    error = tol + 1

    while i < max_iter and error > tol:

        # 政策関数を更新する
        hfun_new_tilde = UpdatePF(hfun_old)

        # 古い政策関数と加重平均する
        hfun_new = lambdaPF*hfun_new_tilde + (1-lambdaPF)*hfun_old

        error = np.max(np.abs(hfun_new-hfun_old))
        i += 1
        if verbose and i % print_skip == 0:      # 進捗をprint_skip回ごとに表示する
            print(f"PF Error at iteration {i} is {error}.")
        hfun_old = hfun_new

    if i == max_iter:
        print("Failed to converge!")

    if verbose and i < max_iter:
        print(f"\nConverged in {i} iterations.")

    return hfun_new

# %% [markdown]
# ### 定常分布の計算のための関数

# %%
from numba import njit
import numpy as np


@njit
def gridlookup2(x0, xgrid):
    nx = np.shape(xgrid)[0]
    ix = 0
    for jx in range(nx):
        if x0 <= xgrid[jx]:
            break
        ix += 1
    ix = min(max(1, ix), nx-1)
    return ix - 1

#sd = solve_sd(sd_grid, len(hp.a_grid), len(hp.z_grid),len(a_grid_sd),a_grid, a_grid_sd, hp.Pz, hfun_aprime)


@njit
def solve_sd(mu0: np.ndarray,
                        na: int,
                        nz: int,
                        na_sd: int,    # mu0.shape[0]のこと
                        agrid: np.ndarray,
                        agrid_sd: np.ndarray,
                        Pz: np.ndarray,
                        pfgrid: np.ndarray,
                        critmu: float = 1e-6):

    # -1. 政策関数の行列を補間して、行数を na 個から na_sd 個に変える
    # pfgrid -> pfgrid_new
    pfgrid_new = np.empty((na_sd,nz))              # 空の箱を用意
    for z_index in range(nz):
      aprime_new = np.empty(na_sd)
      interpolate_y(agrid, agrid_sd, pfgrid[:, z_index], aprime_new)
      pfgrid_new[:,z_index] = aprime_new


    # 0. transition matrixを計算
    G = np.zeros((na_sd*nz,na_sd*nz))
    weight = np.zeros((na_sd,nz))

    for iz in range(nz):
      for ia in range(na_sd):

        # 政策関数 pfgrid[ia, iz] に合わせる
        aprime = pfgrid_new[ia, iz]


        if aprime < agrid_sd[0]:
            weight[ia, iz] = 1.0
            jtilde = 0
        elif aprime > agrid_sd[-1]:
            weight[ia, iz] = 0
            jtilde = na_sd - 2
        else:
          # aprimeが落ちる区間の左端のグリッドのインデックスを探す
          jtilde = gridlookup2(aprime, agrid_sd)
          # 重み weight[ia, iz] に格納
          weight[ia, iz] = (agrid_sd[jtilde+1] - aprime) / (agrid_sd[jtilde+1] - agrid_sd[jtilde])

        # スタックしたときの現在の状態のインデックスを計算
        i_s = iz * na_sd + ia

        # 次期外生状態 jz でループ
        for jz in range(nz):

            # スタックしたときの次期の状態のインデックスを計算
            j_s  = jz * na_sd + jtilde

            # 遷移確率行列 G に代入
            #   - Pe[iz, jz] : 現在 iz から次期 jz への外生ショックの遷移確率
            G[i_s, j_s ] += weight[ia, iz]   * Pz[iz, jz]
            G[i_s, j_s + 1] += (1.0 - weight[ia, iz]) * Pz[iz, jz]


    diffmu = 1.0e4
    mu1    = np.zeros((na_sd, nz))

    # 分布の初期値をスタックしてベクトル化
    mu0 = mu0.T.flatten()

    while diffmu > 1e-6:

        # 1. 分布の更新 : dist_new = G' * dist
        mu1 = G.T @ mu0

        # 2. 収束判定
        diffmu = np.max(np.abs(mu1 - mu0))

        # 3. normalizeして次のループへ
        mu0 = mu1 / np.sum(mu1)

    sd = mu0.reshape(nz, na_sd).T
    return sd

# %% [markdown]
# ### 総労働供給を求める

# %%
# 生産性の定常分布を求める

hp = Setting(nz = 7, rho = rho, sigma = sigma) # 生産性の定常分布を求めるために必要ない変数については初期値のまま

muZ_old = np.ones(len(hp.z_grid)) / len(hp.z_grid)

tol=1E-11
maxit=100^4

for it in range(maxit):
  muZ_new = muZ_old @ hp.Pz
  if np.max(np.abs(muZ_new - muZ_old)) < tol: break
  muZ_old = muZ_new

# 総労働供給を求める
Lbar = sum(muZ_new*hp.z_grid)
print(Lbar)
# Out:
# 1.125707392526809

# %% [markdown]
# ## 初期定常状態(ini)実行

# %%
import time

start_time = time.time()  # 計測開始

r0 = 0.029
tau = 0.0

diff = 1
loop = 0
while abs(diff) > 1e-6:
    loop += 1
    # print("loop: ", loop)

    # 1
    K0d = ((r0 + delta) / alpha) ** (1 / (alpha - 1)) * Lbar
    w0 = (1 - alpha) * (K0d/Lbar) ** alpha
    Xi0 = tau * r0 * K0d

    # 2
    hp = Setting(beta=beta, gamma = gamma, b = b, a_max = 45, lambdaPF = 1, na = 50, na_sd= 50, nz = 7, rho = rho, sigma = sigma, R = 1 + r0, w = w0, Xi = Xi0, tau=tau)
    hfun_c = SolveProblem(hp,EGMIterationWithGov)

    # 3
    # hfun_c から 次期のアセット aの政策関数を求める
    hfun_aprime = np.empty((len(hp.a_grid), len(hp.z_grid)))
    a_mesh, z_mesh = np.meshgrid(hp.a_grid, hp.z_grid, indexing='ij') # ユニバーサル関数を使用するためのグリッドを生成
    R_net = 1.0 + (1.0 - tau) * r0
    hfun_aprime = R_net * a_mesh + hp.w * z_mesh - hfun_c + hp.Xi


    # 定常分布用のグリッドを用意
    a_grid_sd = np.linspace(-hp.b, hp.a_grid[-1], hp.na_sd)
    # a_grid_sd = maliar_grid(-hp.b , hp.a_grid[-1], hp.na_sd, 2)

    # 初期の定常分布を定義
    sd_grid = np.full((len(a_grid_sd), len(hp.z_grid)),
                      1 / (len(a_grid_sd) * len(hp.z_grid))
                      )

    sd = solve_sd(sd_grid, len(hp.a_grid), len(hp.z_grid),len(a_grid_sd),hp.a_grid, a_grid_sd, hp.Pz, hfun_aprime)

    # 4
    #Amesh, _ = np.meshgrid(a_grid_sd, hp.z_grid, indexing='ij')
    #K0s = np.sum(Amesh * sd)
    # --- hfun_aprime を補間 ---
    hfun_aprime_interp = np.empty((len(a_grid_sd), len(hp.z_grid)))
    for iz in range(len(hp.z_grid)):
        interpolate_y(hp.a_grid, a_grid_sd, hfun_aprime[:, iz], hfun_aprime_interp[:, iz])
    # 総資本ストック供給 K_s の計算
    K0s = np.sum(hfun_aprime_interp * sd)

    # print("K0s: ", K0s)
    diff = (K0s - K0d)
    # print("diff: ", diff)
    # print("r0: ", r0)

    r0 = r0 - 0.001 * diff

r0 = r0 + 0.001 * diff


end_time = time.time()  # 計測終了

print("Elapsed time:", end_time - start_time, "seconds")
# Out:
# PF Error at iteration 25 is 0.06564909355203952.
# PF Error at iteration 50 is 0.013325259987844618.
# PF Error at iteration 75 is 0.004002687388442894.
# PF Error at iteration 100 is 0.0013100284285911812.
# PF Error at iteration 125 is 0.00042415677028628807.
# PF Error at iteration 150 is 0.00013129958279023413.
#
# Converged in 156 iterations.
# PF Error at iteration 25 is 0.06567180297006558.
# PF Error at iteration 50 is 0.013344167705511722.
# PF Error at iteration 75 is 0.00402211533071295.
# PF Error at iteration 100 is 0.0013270939572151974.
# PF Error at iteration 125 is 0.00043582211939963145.
# PF Error at iteration 150 is 0.00013761030211867364.
#
# Converged in 157 iterations.
# PF Error at iteration 25 is 0.06567795104987795.
# PF Error at iteration 50 is 0.013349146188609495.
# PF Error at iteration 75 is 0.004027264718054369.
# PF Error at iteration 100 is 0.0013316773442184626.
# PF Error at iteration 125 is 0.00043901082541708547.
# PF Error at iteration 150 is 0.00013937048050394196.
#
# Converged in 158 iterations.
# PF Error at iteration 25 is 0.0656795028401973.
# PF Error at iteration 50 is 0.01335039271354077.
# PF Error at iteration 75 is 0.004028556912899717.
# PF Error at iteration 100 is 0.0013328318543202045.
# PF Error at iteration 125 is 0.00043980784038666343.
# PF Error at iteration 150 is 0.0001398187057901623.
#
# Converged in 158 iterations.
# PF Error at iteration 25 is 0.06567988770175504.
# PF Error at iteration 50 is 0.013350701191789938.
# PF Error at iteration 75 is 0.0040288768814988885.
# PF Error at iteration 100 is 0.0013331179982998265.
# PF Error at iteration 125 is 0.00044000630911256167.
# PF Error at iteration 150 is 0.00013993010384893978.
#
# Converged in 158 iterations.
# PF Error at iteration 25 is 0.06567997739351483.
# PF Error at iteration 50 is 0.013350773043697473.
# PF Error at iteration 75 is 0.004028951420735893.
# PF Error at iteration 100 is 0.0013331846803055214.
# PF Error at iteration 125 is 0.0004400526719692266.
# PF Error at iteration 150 is 0.00013995607783101605.
#
# Converged in 158 iterations.
# PF Error at iteration 25 is 0.06567999825753645.
# PF Error at iteration 50 is 0.013350789755740777.
# PF Error at iteration 75 is 0.004028968758404972.
# PF Error at iteration 100 is 0.0013332001912829128.
# PF Error at iteration 125 is 0.00044006345725478013.
# PF Error at iteration 150 is 0.00013996212060618518.
#
# Converged in 158 iterations.
# PF Error at iteration 25 is 0.0656800031087883.
# PF Error at iteration 50 is 0.013350793641471626.
# PF Error at iteration 75 is 0.004028972789640761.
# PF Error at iteration 100 is 0.00133320379784152.
# PF Error at iteration 125 is 0.0004400659650869443.
# PF Error at iteration 150 is 0.00013996352573286686.
#
# Converged in 158 iterations.
# PF Error at iteration 25 is 0.06568000423668963.
# PF Error at iteration 50 is 0.013350794544898292.
# PF Error at iteration 75 is 0.004028973726889262.
# PF Error at iteration 100 is 0.0013332046363530026.
# PF Error at iteration 125 is 0.0004400665481156807.
# PF Error at iteration 150 is 0.00013996385240488962.
#
# Converged in 158 iterations.
# PF Error at iteration 25 is 0.06568000449891542.
# PF Error at iteration 50 is 0.013350794754913409.
# PF Error at iteration 75 is 0.004028973944777192.
# PF Error at iteration 100 is 0.0013332048312975076.
# PF Error at iteration 125 is 0.0004400666836659184.
# PF Error at iteration 150 is 0.00013996392836190807.
#
# Converged in 158 iterations.
# PF Error at iteration 25 is 0.06568000455987999.
# PF Error at iteration 50 is 0.013350794803756116.
# PF Error at iteration 75 is 0.0040289739954602055.
# PF Error at iteration 100 is 0.0013332048766088178.
# PF Error at iteration 125 is 0.00044006671518559415.
# PF Error at iteration 150 is 0.00013996394599047335.
#
# Converged in 158 iterations.
# Elapsed time: 2.3881988525390625 seconds

# %%
sd_ini =  sd
k_ini = K0d

w = (1 - alpha) * (K0d/Lbar) ** alpha
w_ini = w
r_ini = r0

xi_ini = tau * r0 * K0d

aprime_ini = np.squeeze(hfun_aprime)

c_ini = np.squeeze(hfun_c)

# %% [markdown]
# ## 最終定常状態(fin)実行

# %%
import time

start_time = time.time()  # 計測開始

r0 = 0.029
# tau = 0.1
tau = 0.01
diff = 1
loop = 0
while abs(diff) > 1e-6:
    loop += 1
    # print("loop: ", loop)

    # 1
    K0d = ((r0 + delta) / alpha) ** (1 / (alpha - 1)) * Lbar
    w0 = (1 - alpha) * (K0d/Lbar) ** alpha
    Xi0 = tau * r0 * K0d

    # 2
    hp = Setting(beta=beta, gamma = gamma, b = b, a_max = 45, lambdaPF = 1, na = 50, na_sd= 50, nz = 7, rho = rho, sigma = sigma, R = 1 + r0, w = w0, Xi = Xi0, tau=tau)
    hfun_c = SolveProblem(hp,EGMIterationWithGov)

    # 3
    # hfun_c から 次期のアセット aの政策関数を求める
    hfun_aprime = np.empty((len(hp.a_grid), len(hp.z_grid)))
    a_mesh, z_mesh = np.meshgrid(hp.a_grid, hp.z_grid, indexing='ij') # ユニバーサル関数を使用するためのグリッドを生成
    R_net = 1.0 + (1.0 - tau) * r0
    hfun_aprime = R_net * a_mesh + hp.w * z_mesh - hfun_c + hp.Xi


    # 定常分布用のグリッドを用意
    a_grid_sd = np.linspace(-hp.b, hp.a_grid[-1], hp.na_sd)
    # a_grid_sd = maliar_grid(-hp.b , hp.a_grid[-1], hp.na_sd, 2)

    # 初期の定常分布を定義
    sd_grid = np.full((len(a_grid_sd), len(hp.z_grid)),
                      1 / (len(a_grid_sd) * len(hp.z_grid))
                      )

    sd = solve_sd(sd_grid, len(hp.a_grid), len(hp.z_grid),len(a_grid_sd),hp.a_grid, a_grid_sd, hp.Pz, hfun_aprime)

    # 4
    #Amesh, _ = np.meshgrid(a_grid_sd, hp.z_grid, indexing='ij')
    #K0s = np.sum(Amesh * sd)
    # --- hfun_aprime を補間 ---
    hfun_aprime_interp = np.empty((len(a_grid_sd), len(hp.z_grid)))
    for iz in range(len(hp.z_grid)):
        interpolate_y(hp.a_grid, a_grid_sd, hfun_aprime[:, iz], hfun_aprime_interp[:, iz])
    # 総資本ストック供給 K_s の計算
    K0s = np.sum(hfun_aprime_interp * sd)

    # print("K0s: ", K0s)
    diff = (K0s - K0d)
    # print("diff: ", diff)
    # print("r0: ", r0)

    r0 = r0 - 0.001 * diff

r0 = r0 + 0.001 * diff


end_time = time.time()  # 計測終了

print("Elapsed time:", end_time - start_time, "seconds")
# Out:
# PF Error at iteration 25 is 0.06562970984242611.
# PF Error at iteration 50 is 0.013312638826320722.
# PF Error at iteration 75 is 0.003990641884868751.
# PF Error at iteration 100 is 0.0012996942477414564.
# PF Error at iteration 125 is 0.0004172191425766414.
# PF Error at iteration 150 is 0.00012762166252855422.
#
# Converged in 156 iterations.
# PF Error at iteration 25 is 0.06566179151023022.
# PF Error at iteration 50 is 0.01333975382382846.
# PF Error at iteration 75 is 0.004018405682550963.
# PF Error at iteration 100 is 0.001323907590013107.
# PF Error at iteration 125 is 0.00043360481425480657.
# PF Error at iteration 150 is 0.00013638709150143313.
#
# Converged in 157 iterations.
# PF Error at iteration 25 is 0.0656710481428533.
# PF Error at iteration 50 is 0.013347298171140665.
# PF Error at iteration 75 is 0.00402619359141454.
# PF Error at iteration 100 is 0.0013308202436448369.
# PF Error at iteration 125 is 0.00043839905508491483.
# PF Error at iteration 150 is 0.00013901746702771334.
#
# Converged in 157 iterations.
# PF Error at iteration 25 is 0.06567352342899824.
# PF Error at iteration 50 is 0.013349291172438882.
# PF Error at iteration 75 is 0.004028257502525889.
# PF Error at iteration 100 is 0.0013326628442200672.
# PF Error at iteration 125 is 0.0004396830929849216.
# PF Error at iteration 150 is 0.0001397315870619309.
#
# Converged in 158 iterations.
# PF Error at iteration 25 is 0.0656741630670652.
# PF Error at iteration 50 is 0.01334980439951039.
# PF Error at iteration 75 is 0.0040287894783332945.
# PF Error at iteration 100 is 0.0013331385033197307.
# PF Error at iteration 125 is 0.0004400114824392176.
# PF Error at iteration 150 is 0.00013991673699109697.
#
# Converged in 158 iterations.
# PF Error at iteration 25 is 0.06567431882555042.
# PF Error at iteration 50 is 0.01334992926319245.
# PF Error at iteration 75 is 0.004028918934835701.
# PF Error at iteration 100 is 0.0013332543054076496.
# PF Error at iteration 125 is 0.0004400915618631984.
# PF Error at iteration 150 is 0.00013996186121545406.
#
# Converged in 158 iterations.
# PF Error at iteration 25 is 0.065674356646376.
# PF Error at iteration 50 is 0.013349959575165826.
# PF Error at iteration 75 is 0.004028950363988315.
# PF Error at iteration 100 is 0.0013332824226637285.
# PF Error at iteration 125 is 0.0004401110077907333.
# PF Error at iteration 150 is 0.00013997282048450188.
#
# Converged in 158 iterations.
# PF Error at iteration 25 is 0.0656743658235186.
# PF Error at iteration 50 is 0.013349966929879997.
# PF Error at iteration 75 is 0.004028957989916648.
# PF Error at iteration 100 is 0.001333289245138758.
# PF Error at iteration 125 is 0.0004401157263558275.
# PF Error at iteration 150 is 0.00013997547987543157.
#
# Converged in 158 iterations.
# PF Error at iteration 25 is 0.06567436804995452.
# PF Error at iteration 50 is 0.013349968714152283.
# PF Error at iteration 75 is 0.004028959839999402.
# PF Error at iteration 100 is 0.00133329090033385.
# PF Error at iteration 125 is 0.00044011687109701825.
# PF Error at iteration 150 is 0.00013997612506955193.
#
# Converged in 158 iterations.
# PF Error at iteration 25 is 0.06567436859006648.
# PF Error at iteration 50 is 0.013349969146986496.
# PF Error at iteration 75 is 0.004028960288792405.
# PF Error at iteration 100 is 0.0013332913018544446.
# PF Error at iteration 125 is 0.0004401171488339628.
# PF Error at iteration 150 is 0.0001399762815736949.
#
# Converged in 158 iterations.
# PF Error at iteration 25 is 0.06567436872107635.
# PF Error at iteration 50 is 0.013349969251990501.
# PF Error at iteration 75 is 0.004028960397683079.
# PF Error at iteration 100 is 0.0013332913992556428.
# PF Error at iteration 125 is 0.00044011721619341415.
# PF Error at iteration 150 is 0.00013997631953799328.
#
# Converged in 158 iterations.
# Elapsed time: 2.1045258045196533 seconds

# %%
sd_fin =  sd
k_fin = K0d

w = (1 - alpha) * (K0d/Lbar) ** alpha
w_fin = w
r_fin = r0
xi_fin = tau * r0 * K0d

aprime_fin = np.squeeze(hfun_aprime)

c_fin = np.squeeze(hfun_c)

# %%
r_fin # Xi入れ忘れバージョン 0.030167123686931658
# Out:
# np.float64(0.030017118508695123)

# %% [markdown]
# ## 移行過程

# %% [markdown]
# まずは三期間で考える

# %% [markdown]
# ### 最終定常状態(fin)の価値関数を導出

# %%
T = 150 # iniからfinまでの期間を設定
tau = np.zeros(T) # T期間分のtauを格納する箱を作る
tau[1:] = 0.01 # 初期状態以外のtauを0.1に設定

K_list = np.linspace(k_ini, k_fin, T) # 資本ストックの初期値を当て推量、最初と最後の値は定常状態のものを用いる
w = (1 - alpha) * (K_list/Lbar) ** alpha # 当て推量したKを基に賃金を計算
r = alpha * (K_list / Lbar) ** (alpha - 1) - delta # 当て推量したKを基に金利を計算
xi = K_list * tau * r # 当て推量したK,rとtauより政府移転を計算

# %%
value_function_list = np.empty((T,len(hp.a_grid), len(hp.z_grid))) # 計算した価値関数を格納する箱を設定
v_old_box = np.zeros((len(hp.a_grid), len(hp.z_grid))) # 繰り返し計算前の価値関数を格納する箱を設定
v_tilde_box = np.empty((len(hp.a_grid), len(hp.z_grid))) # 繰り返し計算後の価値関数を格納する箱を設定

diff = 1
loop = 0
while diff > 1e-6: # 繰り返し計算前後で価値関数が等しくなるまで
    loop += 1
    for i_a in range(len(hp.a_grid)): # 今期の資産グリッドで繰り返し
        for i_z in range(len(hp.z_grid)): # 今期の生産性で繰り返し
            aprime = (1 + (1 - tau[-1]) * r_fin) * hp.a_grid[i_a] + w_fin * hp.z_grid[i_z] + tau[-1] * r_fin * k_fin - c_fin[i_a, i_z] #
            value = 0
            for j_z in range(len(hp.z_grid)): # 次期の生産性で繰り返し
                v_tilde_interp = np.interp(aprime, hp.a_grid, v_old_box[:, j_z])
                # interpolate_y(hp.a_grid, aprime, v_old_box[:, j_z], v_tilde_box)
                value += v_tilde_interp * hp.Pz[i_z, j_z]
            v_tilde_box[i_a, i_z] = hp.utility(c_fin[i_a, i_z]) + beta * value

    diff = np.max(np.abs(v_tilde_box - v_old_box))
    # print("diff: ", diff)
    v_old_box = v_tilde_box # 価値関数を更新
    v_tilde_box = np.empty((len(hp.a_grid), len(hp.z_grid))) # 次のループの計算のために空にする
    v_tilde_box_interp = np.empty((len(hp.a_grid), len(hp.z_grid))) # 次のループの計算のために空にする

value_function_list[-1] = v_old_box # 計算した価値関数を格納、これがfinでの価値関数となる

# %% [markdown]
# ### 収束するまで繰り返し

# %% [markdown]
# ### 4-a政策関数と価値関数の導出

# %%
# 何を引数として何を出力してくれる関数なのかをそれぞれに記載する。
from scipy.optimize import fminbound
from numba import jit
import numpy as np

# maximization_problem関数の定義（JIT化）
# @jit(nopython=True)
def maximization_problem(c, i_a,  i_z, vfun_next, t):
    """ 今期の消費、資産、状態、次期の価値関数を用いて、今期の最大化問題を定義する関数
    Args:
    c : 今期の消費
    i_a : 今期の資産
    i_z : 今期の状態
    vfun_next : 次期の価値関数
    t : 今期の期数
    """

    aprime = (1 + (1 - tau[t-1]) * r[t-1]) * hp.a_grid + w[t-1] * hp.z_grid[i_z] + tau[t-1] * r[t-1] * K_list[t-1] - c
    expectation = 0.0

    for j_z in range(len(hp.z_grid)):  # 次期の生産性
        value_function_interp = np.empty(len(hp.a_grid), dtype=np.float64)
        interpolate_y(hp.a_grid, aprime, vfun_next[:, j_z], value_function_interp) #interpolate_yはベクトルを返すもの
        expectation += value_function_interp[i_a] * hp.Pz[i_z, j_z]

    u_value = (hp.utility(c) + beta * expectation)  # brent_maxをつかうなら最大化するために負にしない
    return u_value

# 消費cを最大化する関数を定義
def maximize_u_value(vfun_next):
    optimal_c_list = np.zeros((len(hp.a_grid), len(hp.z_grid)))  # 最適な消費を格納するための箱（初期化）
    v_value_list = np.zeros((len(hp.a_grid), len(hp.z_grid)))  # 価値関数の箱（初期化）

    for i_a in range(len(hp.a_grid)):

        for i_z in range(len(hp.z_grid)):

            # objective関数を定義（rhsを最大化するために負にする）
            def objective(c):
                return -maximization_problem(c, i_a, i_z, vfun_next, t)

            # fminboundを使ってcを最適化
            c_min = 1e-8
            c_max = (1 + (1 - tau[t-1]) * r[t-1]) * hp.a_grid[i_a] + w[t-1] * hp.z_grid[i_z] + b + tau[t-1] * r[t-1] * K_list[t-1] #消費の最大値（借入制約に引っかかったとき）
            sol = fminbound(objective, c_min, c_max, xtol=1e-05, full_output = True)
            # print(sol)

            optimal_c = sol[0]
            v_value = sol[1]

            # 最適な消費と価値関数の値を格納
            optimal_c_list[i_a, i_z] = optimal_c # 最適な消費を代入
            v_value_list[i_a, i_z] = -v_value #価値関数の値を代入


    return optimal_c_list, v_value_list  # 両方を返す

# %% [markdown]
# ### 4-b

# %%
@njit
def split_prob_to_agrid(aprime: float, agrid: np.ndarray) -> np.ndarray:
    """ 政策関数によって得られた a の値が、a_grid のどの点に移動するのかを示す確率ベクトルを計算する関数

    Args:
    aprime: 政策関数によって得られた a の値
    agrid: a のグリッド
    return: aprime が agrid のどの点に移動するのかを示す確率ベクトル
    """
    probs = np.zeros(len(agrid))
    # a の値が a_grid の最小値より小さい場合
    if aprime <= agrid[0]:
        probs[0] = 1.0
        return probs

    # a の値が a_grid の最大値より大きい場合
    if aprime >= agrid[-1]:
        probs[-1] = 1.0
        return probs

    # a の値が a_grid の最小値より大きく最大値より小さい場合
    for i in range(len(agrid)-1):
        if agrid[i] <= aprime <= agrid[i+1]:
            probs[i] = (agrid[i+1] - aprime) / (agrid[i+1] - agrid[i])
            probs[i+1] = (aprime - agrid[i]) / (agrid[i+1] - agrid[i])
            return probs

    # この行までに return されていない場合はエラーを出す
    raise ValueError("Splitting probability failed.")

@njit
def calc_weight_matrix(aprime_grid: np.ndarray, agrid: np.ndarray, split_prob_to_agrid = split_prob_to_agrid) -> np.ndarray:
    """ 前期の定常分布に係る重みづけ確率行列 weight_matrix を計算する関数

    Args:
        aprime_grid: 政策関数の行き先のグリッド
        agrid: 資産のグリッド
        split_prob: 政策関数によって得られた a の値が、a_grid のどの点に移動するのかを示す確率ベクトルを計算する関数

    Returns:
        weight_matrix: 前期の定常分布に係る重みづけ確率のグリッド、shape は aprime_grid と同じ
    """
    weight_matrix = np.empty((len(aprime_grid), len(aprime_grid[0]), len(agrid)))

    # aprime_grid は 二次元配列
    for i in range(len(aprime_grid)):
        for j in range(len(aprime_grid[0])):
            weight_matrix[i, j] = split_prob_to_agrid(float(aprime_grid[i, j]), agrid)
    return weight_matrix

@njit
def gen_pmesh(aprime_grid: np.ndarray, P: np.ndarray, next_y_index: int) -> np.ndarray:
    """ 遷移確率を 政策関数 aprime_grid との要素ごとの計算に使えるように meshgrid を生成する関数

    Args:
        aprime_grid (np.ndarray): 政策関数のグリッド
        P (np.ndarray): 遷移確率行列
        next_y_index (int): 次期の所得状態 y' のインデックス

    Returns:
        np.ndarray: 政策関数と遷移確率行列を使って計算するための meshgrid
    """
    pmesh = np.zeros(aprime_grid.shape)
    for i in range(len(aprime_grid)):
        for j in range(len(aprime_grid[0])):
            pmesh[i, j] = P[j, next_y_index]
    return pmesh

# def calc_sd_point(Pmesh, weight, sd_old) -> float:
#     """ 定常分布の一点を計算する関数

#     Args:
#         Pmesh (np.ndarray): 政策関数と遷移確率行列を使って計算した meshgrid
#         weight (np.ndarray): 前期の定常分布に係る重みづけ確率
#         sd_old (np.ndarray): 一期前の定常分布 f(a, y)

#     Returns:
#         float: 更新された(次期の)定常分布の一点の値
#     """
#     return np.sum(Pmesh * weight * sd_old)

@njit
def update_sd(aprime_grid: np.ndarray, agrid: np.ndarray, sd_old: np.ndarray, P: np.ndarray,
            split_prob_to_agrid = split_prob_to_agrid, calc_weight_matrix = calc_weight_matrix,
            gen_P = gen_pmesh,
            # calc_sd_point = calc_sd_point
            ) -> np.ndarray:
    """ 定常分布を更新する関数

    Args:
        aprime_grid (np.ndarray): 政策関数のグリッド
        agrid (np.ndarray): 資産のグリッド
        sd_old (np.ndarray): 更新前の定常分布
        P (np.ndarray): 遷移確率行列
        split_prob (Callable): 政策関数によって得られた a の値が、a_grid のどの点に移動するのかを示す確率ベクトルを計算する関数
        calc_weight (Callable): 前期の定常分布に係る重みづけ確率 weight を計算する関数
        gen_P (Callable): 遷移確率を 政策関数 aprime_grid との要素ごとの計算に使えるように meshgrid を生成する関数
        calc_sd_point (Callable): 定常分布の一点を計算する関数

    Returns:
        sd_new（np.ndarray）: 更新された定常分布のグリッド
    """
    sd_new = np.zeros(sd_old.shape)
    weight_matrix = calc_weight_matrix(aprime_grid, agrid, split_prob_to_agrid)
    for i in range(len(aprime_grid)):
        for j in range(len(aprime_grid[0])):
            p_mesh = gen_P(aprime_grid, P, j)
            # sd_new[i, j] = calc_sd_point(p_mesh, weight_matrix[:,:,i], sd_old)
            sd_new[i,j] = np.sum(p_mesh * weight_matrix[:,:,i] * sd_old)

    return sd_new

@njit
def sd_calculation(sd0: np.ndarray, aprime_grid: np.ndarray, agrid: np.ndarray, P: np.ndarray,

                        update_sd = update_sd) -> np.ndarray:
    """ 定常分布を計算する関数

    Args:
        aprime_grid (np.ndarray): 政策関数のグリッド
        agrid (np.ndarray): 資産のグリッド
        guess_sd (np.ndarray): 初期の定常分布のグリッド
        P (np.ndarray): 遷移確率行列
        tol (float, optional): 許容する誤差. Defaults to 1e-6.
        max_iter (int, optional): 最大の反復回数. Defaults to 1000.
        update_sd (_type_, optional): 定常分布を更新する関数. Defaults to update_sd.

    Returns:
        np.ndarray: 収束した定常分布のグリッド
    """
    sd_old = sd0
    sd_next = update_sd(aprime_grid, agrid, sd_old, P)
    return sd_next

# %%
from numba import njit
import numpy as np

@njit
def sd_calculation(sd_old: np.ndarray,
                   aprime_grid: np.ndarray,
                   agrid: np.ndarray,
                   Pz: np.ndarray) -> np.ndarray:
    """
    solve_sd() のロジックを用いて、1回だけ次期の定常分布を計算する関数。

    Parameters:
    - sd_old: np.ndarray, 現在の分布 (na, nz)
    - aprime_grid: np.ndarray, 政策関数 (na, nz)
    - agrid: np.ndarray, 資産グリッド (na,)
    - Pz: np.ndarray, 所得ショックの遷移行列 (nz, nz)

    Returns:
    - sd_next: np.ndarray, 次期の分布 (na, nz)
    """
    na, nz = aprime_grid.shape
    G = np.zeros((na * nz, na * nz))
    weight = np.zeros((na, nz))

    for iz in range(nz):
        for ia in range(na):
            aprime = aprime_grid[ia, iz]

            if aprime < agrid[0]:
                weight[ia, iz] = 1.0
                jtilde = 0
            elif aprime > agrid[-1]:
                weight[ia, iz] = 0.0
                jtilde = na - 2
            else:
                for i in range(len(agrid) - 1):
                    if agrid[i] <= aprime <= agrid[i + 1]:
                        jtilde = i
                        weight[ia, iz] = (agrid[i + 1] - aprime) / (agrid[i + 1] - agrid[i])
                        break

            i_s = iz * na + ia
            for jz in range(nz):
                j_s = jz * na + jtilde
                G[i_s, j_s] += weight[ia, iz] * Pz[iz, jz]
                G[i_s, j_s + 1] += (1.0 - weight[ia, iz]) * Pz[iz, jz]

    # sd_old をベクトル化して更新
    mu_old = sd_old.T.flatten()  # shape = (na * nz,)
    mu_new = G.T @ mu_old
    mu_new = mu_new / np.sum(mu_new)  # 正規化

    # 2次元 (na, nz) に戻して返す
    sd_next = mu_new.reshape(nz, na).T
    return sd_next

# %% [markdown]
# ### 4-c

# %%
def compute_K_path(sd_list: list, a_grid: np.ndarray) -> list:
    """
    分布リスト sd_list をもとに、各期の総資本 K_t を計算する関数

    Parameters
    ----------
    sd_list : list of ndarray
        各期の分布（shape: (na, nz)）のリスト
    a_grid : ndarray
        資産グリッド（shape: (na,)）

    Returns
    -------
    K_path : list of float
        各期の総資本 K_t のリスト
    """
    K_path = []

    for mu in sd_list:
        K_t = np.sum(mu * a_grid[:, np.newaxis])  # 資産×分布の要素積
        K_path.append(float(K_t))

    return K_path

# %% [markdown]
# ### 4-d

# %%
def compute_K_error(K_path_new: list, K_path_old: list) -> float:
    """
    新しく求めた K_path と当初の予測 K_path_old との最大誤差を返す関数

    Parameters
    ----------
    K_path_new : list of float
        新しく計算された各期の総資本（K_path）
    K_path_old : list of float
        当て推量された各期の総資本

    Returns
    -------
    max_error : float
        各期の誤差の絶対値の最大値
    """
    K_path_new = np.array(K_path_new)
    K_path_old = np.array(K_path_old)

    error = (K_path_new - K_path_old)
    max_abs_error = np.max(np.abs(error))

    return max_abs_error, error

# %% [markdown]
# ### 実行

# %%
max_abs_error_list = []

# %%
T = 150

tau = np.zeros(T) # T期間分のtauを格納する箱を作る
tau[1:] = 0.01 # 初期状態以外のtauを0.1に設定

K_list = np.linspace(k_ini, k_fin, T) # 資本ストックの初期値を当て推量、最初と最後の値は定常状態のものを用いる


# print(K_list)
max_abs_error = 1
loop = 0

while max_abs_error > 1e-6: # 繰り返し計算前後で価値関数が等しくなるまで
      loop = loop + 1
# for loop in range(10):

      w = (1 - alpha) * (K_list/Lbar) ** alpha # 当て推量したKを基に賃金を計算
      r = alpha * (K_list / Lbar) ** (alpha - 1) - delta # 当て推量したKを基に金利を計算
      # print(f"r:{r}")
      xi = K_list * tau * r # 当て推量したK,rとtauより政府移転を計算

      hfun_aprime = np.empty((T,len(hp.a_grid), len(hp.z_grid)))
      hfun_c = np.empty((T,len(hp.a_grid), len(hp.z_grid)))

      for t in range(T-1,-1,-1):
          # t期の政策関数を求める
          hfun_c[t-1], value_function_list[t-1] = maximize_u_value(value_function_list[t])

          for i_a in range(len(hp.a_grid)):
              for i_z in range(len(hp.z_grid)):
                hfun_aprime[t-1, i_a, i_z] = (hp.a_grid[i_a] * (1 + (1 - tau[t-1]) * r[t-1]) + w[t-1] * hp.z_grid[i_z] + tau[t-1] * r[t-1] * K_list[t-1] - hfun_c[t-1, i_a, i_z]) # ここまでが行き

      hfun_aprime[0] = aprime_ini

      sd_list = np.empty((T, len(hp.a_grid), len(hp.z_grid))) # sd_listはT＋1期分、初期状態が第0期とするため、ここからが戻り
      sd_list[0] = sd_ini.copy() # sd_listの一番最初はsd_ini、それ以外はのちの計算で埋まるためemptyのまま

      for t in range(1,T):
          sd_next = sd_calculation(sd_list[t-1], hfun_aprime[t-1], hp.a_grid, hp.Pz) # 1期前の分布より、今期の分布を求めている
          sd_list[t] = sd_next # 今期の分布をsd_listに保存

      K_pass = compute_K_path(sd_list, hfun_aprime)

      max_abs_error , error = compute_K_error(K_pass, K_list)

      K_list = K_list + error * 0.05
      K_list[0] = k_ini
      # K_list[-1] = k_fin　# 教科書では、1回目以降のイタレーションでK_finを使わない

      # print(f" k_pass: {k_pass}")

      print(f" ループ回数: {loop}")
      print(f" 最大誤差 (max_abs_error): {max_abs_error:.6e}")
      max_abs_error_list.append(max_abs_error)
# Out:
#  ループ回数: 1
#  最大誤差 (max_abs_error): 9.839012e+02
#  ループ回数: 2
#  最大誤差 (max_abs_error): 1.295865e+03
#  ループ回数: 3
#  最大誤差 (max_abs_error): 8.349203e+02
#  ループ回数: 4
#  最大誤差 (max_abs_error): 8.955776e+02
#  ループ回数: 5
#  最大誤差 (max_abs_error): 9.585060e+02
#  ループ回数: 6
#  最大誤差 (max_abs_error): 9.888676e+02
#  ループ回数: 7
#  最大誤差 (max_abs_error): 9.808429e+02
#  ループ回数: 8
#  最大誤差 (max_abs_error): 9.404622e+02
#  ループ回数: 9
#  最大誤差 (max_abs_error): 8.806594e+02
#  ループ回数: 10
#  最大誤差 (max_abs_error): 8.159666e+02
#  ループ回数: 11
#  最大誤差 (max_abs_error): 7.570822e+02
#  ループ回数: 12
#  最大誤差 (max_abs_error): 7.069166e+02
#  ループ回数: 13
#  最大誤差 (max_abs_error): 6.650969e+02
#  ループ回数: 14
#  最大誤差 (max_abs_error): 6.288097e+02
#  ループ回数: 15
#  最大誤差 (max_abs_error): 5.959975e+02
#  ループ回数: 16
#  最大誤差 (max_abs_error): 5.655484e+02
#  ループ回数: 17
#  最大誤差 (max_abs_error): 5.365497e+02
#  ループ回数: 18
#  最大誤差 (max_abs_error): 5.085664e+02
#  ループ回数: 19
#  最大誤差 (max_abs_error): 4.813224e+02
#  ループ回数: 20
#  最大誤差 (max_abs_error): 4.551314e+02
#  ループ回数: 21
#  最大誤差 (max_abs_error): 4.302625e+02
#  ループ回数: 22
#  最大誤差 (max_abs_error): 4.068981e+02
#  ループ回数: 23
#  最大誤差 (max_abs_error): 3.852439e+02
#  ループ回数: 24
#  最大誤差 (max_abs_error): 3.655526e+02
#  ループ回数: 25
#  最大誤差 (max_abs_error): 3.480048e+02
#  ループ回数: 26
#  最大誤差 (max_abs_error): 3.325394e+02
#  ループ回数: 27
#  最大誤差 (max_abs_error): 3.192382e+02
#  ループ回数: 28
#  最大誤差 (max_abs_error): 3.078853e+02
#  ループ回数: 29
#  最大誤差 (max_abs_error): 2.984776e+02
#  ループ回数: 30
#  最大誤差 (max_abs_error): 2.907628e+02
#  ループ回数: 31
#  最大誤差 (max_abs_error): 2.846534e+02
#  ループ回数: 32
#  最大誤差 (max_abs_error): 2.800194e+02
#  ループ回数: 33
#  最大誤差 (max_abs_error): 2.766026e+02
#  ループ回数: 34
#  最大誤差 (max_abs_error): 2.741234e+02
#  ループ回数: 35
#  最大誤差 (max_abs_error): 2.724358e+02
#  ループ回数: 36
#  最大誤差 (max_abs_error): 2.716785e+02
#  ループ回数: 37
#  最大誤差 (max_abs_error): 2.714251e+02
#  ループ回数: 38
#  最大誤差 (max_abs_error): 2.714654e+02
#  ループ回数: 39
#  最大誤差 (max_abs_error): 2.719843e+02
#  ループ回数: 40
#  最大誤差 (max_abs_error): 2.726437e+02
#  ループ回数: 41
#  最大誤差 (max_abs_error): 2.734518e+02
#  ループ回数: 42
#  最大誤差 (max_abs_error): 2.743683e+02
#  ループ回数: 43
#  最大誤差 (max_abs_error): 2.751774e+02
#  ループ回数: 44
#  最大誤差 (max_abs_error): 2.759251e+02
#  ループ回数: 45
#  最大誤差 (max_abs_error): 2.766003e+02
#  ループ回数: 46
#  最大誤差 (max_abs_error): 2.772149e+02
#  ループ回数: 47
#  最大誤差 (max_abs_error): 2.776476e+02
#  ループ回数: 48
#  最大誤差 (max_abs_error): 2.778756e+02
#  ループ回数: 49
#  最大誤差 (max_abs_error): 2.779973e+02
#  ループ回数: 50
#  最大誤差 (max_abs_error): 2.780581e+02
#  ループ回数: 51
#  最大誤差 (max_abs_error): 2.778769e+02
#  ループ回数: 52
#  最大誤差 (max_abs_error): 2.773844e+02
#  ループ回数: 53
#  最大誤差 (max_abs_error): 2.766538e+02
#  ループ回数: 54
#  最大誤差 (max_abs_error): 2.757389e+02
#  ループ回数: 55
#  最大誤差 (max_abs_error): 2.747086e+02
#  ループ回数: 56
#  最大誤差 (max_abs_error): 2.735350e+02
#  ループ回数: 57
#  最大誤差 (max_abs_error): 2.722496e+02
#  ループ回数: 58
#  最大誤差 (max_abs_error): 2.706060e+02
#  ループ回数: 59
#  最大誤差 (max_abs_error): 2.694227e+02
#  ループ回数: 60
#  最大誤差 (max_abs_error): 2.683248e+02
#  ループ回数: 61
#  最大誤差 (max_abs_error): 2.669986e+02
#  ループ回数: 62
#  最大誤差 (max_abs_error): 2.655524e+02
#  ループ回数: 63
#  最大誤差 (max_abs_error): 2.642270e+02
#  ループ回数: 64
#  最大誤差 (max_abs_error): 2.629368e+02
#  ループ回数: 65
#  最大誤差 (max_abs_error): 2.613964e+02
#  ループ回数: 66
#  最大誤差 (max_abs_error): 2.596545e+02
#  ループ回数: 67
#  最大誤差 (max_abs_error): 2.577066e+02
#  ループ回数: 68
#  最大誤差 (max_abs_error): 2.557210e+02
#  ループ回数: 69
#  最大誤差 (max_abs_error): 2.535862e+02
#  ループ回数: 70
#  最大誤差 (max_abs_error): 2.513479e+02
#  ループ回数: 71
#  最大誤差 (max_abs_error): 2.489882e+02
#  ループ回数: 72
#  最大誤差 (max_abs_error): 2.466020e+02
#  ループ回数: 73
#  最大誤差 (max_abs_error): 2.441694e+02
#  ループ回数: 74
#  最大誤差 (max_abs_error): 2.416241e+02
#  ループ回数: 75
#  最大誤差 (max_abs_error): 2.390513e+02
#  ループ回数: 76
#  最大誤差 (max_abs_error): 2.364316e+02
#  ループ回数: 77
#  最大誤差 (max_abs_error): 2.337336e+02
#  ループ回数: 78
#  最大誤差 (max_abs_error): 2.308599e+02
#  ループ回数: 79
#  最大誤差 (max_abs_error): 2.279768e+02
#  ループ回数: 80
#  最大誤差 (max_abs_error): 2.251213e+02
#  ループ回数: 81
#  最大誤差 (max_abs_error): 2.222790e+02
#  ループ回数: 82
#  最大誤差 (max_abs_error): 2.194464e+02
#  ループ回数: 83
#  最大誤差 (max_abs_error): 2.165975e+02
#  ループ回数: 84
#  最大誤差 (max_abs_error): 2.138040e+02
#  ループ回数: 85
#  最大誤差 (max_abs_error): 2.110414e+02
#  ループ回数: 86
#  最大誤差 (max_abs_error): 2.082712e+02
#  ループ回数: 87
#  最大誤差 (max_abs_error): 2.055244e+02
#  ループ回数: 88
#  最大誤差 (max_abs_error): 2.027490e+02
#  ループ回数: 89
#  最大誤差 (max_abs_error): 1.999242e+02
#  ループ回数: 90
#  最大誤差 (max_abs_error): 1.971075e+02
#  ループ回数: 91
#  最大誤差 (max_abs_error): 1.943150e+02
#  ループ回数: 92
#  最大誤差 (max_abs_error): 1.915951e+02
#  ループ回数: 93
#  最大誤差 (max_abs_error): 1.889216e+02
#  ループ回数: 94
#  最大誤差 (max_abs_error): 1.862744e+02
#  ループ回数: 95
#  最大誤差 (max_abs_error): 1.836194e+02
#  ループ回数: 96
#  最大誤差 (max_abs_error): 1.809474e+02
#  ループ回数: 97
#  最大誤差 (max_abs_error): 1.782773e+02
#  ループ回数: 98
#  最大誤差 (max_abs_error): 1.756584e+02
#  ループ回数: 99
#  最大誤差 (max_abs_error): 1.731798e+02
#  ループ回数: 100
#  最大誤差 (max_abs_error): 1.706961e+02
#  ループ回数: 101
#  最大誤差 (max_abs_error): 1.682606e+02
#  ループ回数: 102
#  最大誤差 (max_abs_error): 1.659082e+02
#  ループ回数: 103
#  最大誤差 (max_abs_error): 1.635813e+02
#  ループ回数: 104
#  最大誤差 (max_abs_error): 1.624496e+02
#  ループ回数: 105
#  最大誤差 (max_abs_error): 1.634270e+02
#  ループ回数: 106
#  最大誤差 (max_abs_error): 1.643915e+02
#  ループ回数: 107
#  最大誤差 (max_abs_error): 1.653396e+02
#  ループ回数: 108
#  最大誤差 (max_abs_error): 1.662709e+02
#  ループ回数: 109
#  最大誤差 (max_abs_error): 1.671873e+02
#  ループ回数: 110
#  最大誤差 (max_abs_error): 1.680937e+02
#  ループ回数: 111
#  最大誤差 (max_abs_error): 1.689877e+02
#  ループ回数: 112
#  最大誤差 (max_abs_error): 1.698711e+02
#  ループ回数: 113
#  最大誤差 (max_abs_error): 1.707443e+02
#  ループ回数: 114
#  最大誤差 (max_abs_error): 1.716067e+02
#  ループ回数: 115
#  最大誤差 (max_abs_error): 1.724537e+02
#  ループ回数: 116
#  最大誤差 (max_abs_error): 1.732873e+02
#  ループ回数: 117
#  最大誤差 (max_abs_error): 1.741077e+02
#  ループ回数: 118
#  最大誤差 (max_abs_error): 1.749139e+02
#  ループ回数: 119
#  最大誤差 (max_abs_error): 1.757059e+02
#  ループ回数: 120
#  最大誤差 (max_abs_error): 1.764858e+02
#  ループ回数: 121
#  最大誤差 (max_abs_error): 1.772529e+02
#  ループ回数: 122
#  最大誤差 (max_abs_error): 1.780076e+02
#  ループ回数: 123
#  最大誤差 (max_abs_error): 1.787502e+02
#  ループ回数: 124
#  最大誤差 (max_abs_error): 1.794824e+02
#  ループ回数: 125
#  最大誤差 (max_abs_error): 1.802037e+02
#  ループ回数: 126
#  最大誤差 (max_abs_error): 1.809141e+02
#  ループ回数: 127
#  最大誤差 (max_abs_error): 1.816165e+02
#  ループ回数: 128
#  最大誤差 (max_abs_error): 1.823103e+02
#  ループ回数: 129
#  最大誤差 (max_abs_error): 1.829935e+02
#  ループ回数: 130
#  最大誤差 (max_abs_error): 1.836655e+02
#  ループ回数: 131
#  最大誤差 (max_abs_error): 1.843261e+02
#  ループ回数: 132
#  最大誤差 (max_abs_error): 1.849753e+02
#  ループ回数: 133
#  最大誤差 (max_abs_error): 1.856151e+02
#  ループ回数: 134
#  最大誤差 (max_abs_error): 1.862456e+02
#  ループ回数: 135
#  最大誤差 (max_abs_error): 1.868678e+02
#  ループ回数: 136
#  最大誤差 (max_abs_error): 1.874815e+02
#  ループ回数: 137
#  最大誤差 (max_abs_error): 1.880853e+02
#  ループ回数: 138
#  最大誤差 (max_abs_error): 1.886782e+02
#  ループ回数: 139
#  最大誤差 (max_abs_error): 1.892605e+02
#  ループ回数: 140
#  最大誤差 (max_abs_error): 1.898306e+02
#  ループ回数: 141
#  最大誤差 (max_abs_error): 1.903907e+02
#  ループ回数: 142
#  最大誤差 (max_abs_error): 1.909412e+02
#  ループ回数: 143
#  最大誤差 (max_abs_error): 1.914836e+02
#  ループ回数: 144
#  最大誤差 (max_abs_error): 1.920205e+02
#  ループ回数: 145
#  最大誤差 (max_abs_error): 1.925509e+02
#  ループ回数: 146
#  最大誤差 (max_abs_error): 1.930751e+02
#  ループ回数: 147
#  最大誤差 (max_abs_error): 1.935923e+02
#  ループ回数: 148
#  最大誤差 (max_abs_error): 1.941035e+02
#  ループ回数: 149
#  最大誤差 (max_abs_error): 1.946078e+02
#  ループ回数: 150
#  最大誤差 (max_abs_error): 1.951043e+02
#  ループ回数: 151
#  最大誤差 (max_abs_error): 1.955940e+02
#  ループ回数: 152
#  最大誤差 (max_abs_error): 1.960759e+02
#  ループ回数: 153
#  最大誤差 (max_abs_error): 1.965497e+02
#  ループ回数: 154
#  最大誤差 (max_abs_error): 1.970147e+02
#  ループ回数: 155
#  最大誤差 (max_abs_error): 1.974711e+02
#  ループ回数: 156
#  最大誤差 (max_abs_error): 1.979194e+02
#  ループ回数: 157
#  最大誤差 (max_abs_error): 1.983601e+02
#  ループ回数: 158
#  最大誤差 (max_abs_error): 1.987934e+02
#  ループ回数: 159
#  最大誤差 (max_abs_error): 1.992198e+02
#  ループ回数: 160
#  最大誤差 (max_abs_error): 1.996398e+02
#  ループ回数: 161
#  最大誤差 (max_abs_error): 2.000538e+02
#  ループ回数: 162
#  最大誤差 (max_abs_error): 2.004621e+02
#  ループ回数: 163
#  最大誤差 (max_abs_error): 2.008638e+02
#  ループ回数: 164
#  最大誤差 (max_abs_error): 2.012587e+02
#  ループ回数: 165
#  最大誤差 (max_abs_error): 2.016477e+02
#  ループ回数: 166
#  最大誤差 (max_abs_error): 2.020305e+02
#  ループ回数: 167
#  最大誤差 (max_abs_error): 2.024080e+02
#  ループ回数: 168
#  最大誤差 (max_abs_error): 2.027803e+02
#  ループ回数: 169
#  最大誤差 (max_abs_error): 2.031471e+02
#  ループ回数: 170
#  最大誤差 (max_abs_error): 2.035074e+02
#  ループ回数: 171
#  最大誤差 (max_abs_error): 2.038617e+02
#  ループ回数: 172
#  最大誤差 (max_abs_error): 2.042104e+02
#  ループ回数: 173
#  最大誤差 (max_abs_error): 2.045534e+02
#  ループ回数: 174
#  最大誤差 (max_abs_error): 2.048906e+02
#  ループ回数: 175
#  最大誤差 (max_abs_error): 2.052219e+02
#  ループ回数: 176
#  最大誤差 (max_abs_error): 2.055472e+02
#  ループ回数: 177
#  最大誤差 (max_abs_error): 2.058663e+02
#  ループ回数: 178
#  最大誤差 (max_abs_error): 2.061797e+02
#  ループ回数: 179
#  最大誤差 (max_abs_error): 2.064876e+02
#  ループ回数: 180
#  最大誤差 (max_abs_error): 2.067902e+02
#  ループ回数: 181
#  最大誤差 (max_abs_error): 2.070876e+02
#  ループ回数: 182
#  最大誤差 (max_abs_error): 2.073793e+02
#  ループ回数: 183
#  最大誤差 (max_abs_error): 2.076657e+02
#  ループ回数: 184
#  最大誤差 (max_abs_error): 2.079469e+02
#  ループ回数: 185
#  最大誤差 (max_abs_error): 2.082236e+02
#  ループ回数: 186
#  最大誤差 (max_abs_error): 2.084957e+02
#  ループ回数: 187
#  最大誤差 (max_abs_error): 2.087633e+02
#  ループ回数: 188
#  最大誤差 (max_abs_error): 2.090265e+02
#  ループ回数: 189
#  最大誤差 (max_abs_error): 2.092853e+02
#  ループ回数: 190
#  最大誤差 (max_abs_error): 2.095398e+02
#  ループ回数: 191
#  最大誤差 (max_abs_error): 2.097900e+02
#  ループ回数: 192
#  最大誤差 (max_abs_error): 2.100362e+02
#  ループ回数: 193
#  最大誤差 (max_abs_error): 2.102783e+02
#  ループ回数: 194
#  最大誤差 (max_abs_error): 2.105163e+02
#  ループ回数: 195
#  最大誤差 (max_abs_error): 2.107502e+02
#  ループ回数: 196
#  最大誤差 (max_abs_error): 2.109801e+02
#  ループ回数: 197
#  最大誤差 (max_abs_error): 2.112061e+02
#  ループ回数: 198
#  最大誤差 (max_abs_error): 2.114284e+02
#  ループ回数: 199
#  最大誤差 (max_abs_error): 2.116469e+02
#  ループ回数: 200
#  最大誤差 (max_abs_error): 2.118615e+02
#  ループ回数: 201
#  最大誤差 (max_abs_error): 2.120722e+02
#  ループ回数: 202
#  最大誤差 (max_abs_error): 2.122792e+02
#  ループ回数: 203
#  最大誤差 (max_abs_error): 2.124827e+02
#  ループ回数: 204
#  最大誤差 (max_abs_error): 2.126829e+02
#  ループ回数: 205
#  最大誤差 (max_abs_error): 2.128796e+02
#  ループ回数: 206
#  最大誤差 (max_abs_error): 2.130730e+02
#  ループ回数: 207
#  最大誤差 (max_abs_error): 2.132635e+02
#  ループ回数: 208
#  最大誤差 (max_abs_error): 2.134508e+02
#  ループ回数: 209
#  最大誤差 (max_abs_error): 2.136353e+02
#  ループ回数: 210
#  最大誤差 (max_abs_error): 2.138168e+02
#  ループ回数: 211
#  最大誤差 (max_abs_error): 2.139954e+02
#  ループ回数: 212
#  最大誤差 (max_abs_error): 2.141711e+02
#  ループ回数: 213
#  最大誤差 (max_abs_error): 2.143438e+02
#  ループ回数: 214
#  最大誤差 (max_abs_error): 2.145134e+02
#  ループ回数: 215
#  最大誤差 (max_abs_error): 2.146800e+02
#  ループ回数: 216
#  最大誤差 (max_abs_error): 2.148437e+02
#  ループ回数: 217
#  最大誤差 (max_abs_error): 2.150046e+02
#  ループ回数: 218
#  最大誤差 (max_abs_error): 2.151626e+02
#  ループ回数: 219
#  最大誤差 (max_abs_error): 2.153176e+02
#  ループ回数: 220
#  最大誤差 (max_abs_error): 2.154700e+02
#  ループ回数: 221
#  最大誤差 (max_abs_error): 2.156197e+02
#  ループ回数: 222
#  最大誤差 (max_abs_error): 2.157668e+02
#  ループ回数: 223
#  最大誤差 (max_abs_error): 2.159111e+02
#  ループ回数: 224
#  最大誤差 (max_abs_error): 2.160529e+02
#  ループ回数: 225
#  最大誤差 (max_abs_error): 2.161923e+02
#  ループ回数: 226
#  最大誤差 (max_abs_error): 2.163291e+02
#  ループ回数: 227
#  最大誤差 (max_abs_error): 2.164635e+02
#  ループ回数: 228
#  最大誤差 (max_abs_error): 2.165955e+02
#  ループ回数: 229
#  最大誤差 (max_abs_error): 2.167251e+02
#  ループ回数: 230
#  最大誤差 (max_abs_error): 2.168523e+02
#  ループ回数: 231
#  最大誤差 (max_abs_error): 2.169774e+02
#  ループ回数: 232
#  最大誤差 (max_abs_error): 2.171005e+02
#  ループ回数: 233
#  最大誤差 (max_abs_error): 2.172214e+02
#  ループ回数: 234
#  最大誤差 (max_abs_error): 2.173401e+02
#  ループ回数: 235
#  最大誤差 (max_abs_error): 2.174566e+02
#  ループ回数: 236
#  最大誤差 (max_abs_error): 2.175711e+02
#  ループ回数: 237
#  最大誤差 (max_abs_error): 2.176836e+02
#  ループ回数: 238
#  最大誤差 (max_abs_error): 2.177941e+02
#  ループ回数: 239
#  最大誤差 (max_abs_error): 2.179027e+02
#  ループ回数: 240
#  最大誤差 (max_abs_error): 2.180093e+02
#  ループ回数: 241
#  最大誤差 (max_abs_error): 2.181141e+02
#  ループ回数: 242
#  最大誤差 (max_abs_error): 2.182169e+02
#  ループ回数: 243
#  最大誤差 (max_abs_error): 2.183180e+02
#  ループ回数: 244
#  最大誤差 (max_abs_error): 2.184171e+02
#  ループ回数: 245
#  最大誤差 (max_abs_error): 2.185146e+02
#  ループ回数: 246
#  最大誤差 (max_abs_error): 2.186102e+02
#  ループ回数: 247
#  最大誤差 (max_abs_error): 2.187043e+02
#  ループ回数: 248
#  最大誤差 (max_abs_error): 2.187966e+02
#  ループ回数: 249
#  最大誤差 (max_abs_error): 2.188875e+02
#  ループ回数: 250
#  最大誤差 (max_abs_error): 2.189767e+02
#  ループ回数: 251
#  最大誤差 (max_abs_error): 2.190644e+02
#  ループ回数: 252
#  最大誤差 (max_abs_error): 2.191506e+02
#  ループ回数: 253
#  最大誤差 (max_abs_error): 2.192354e+02
#  ループ回数: 254
#  最大誤差 (max_abs_error): 2.193187e+02
#  ループ回数: 255
#  最大誤差 (max_abs_error): 2.194005e+02
#  ループ回数: 256
#  最大誤差 (max_abs_error): 2.194809e+02
#  ループ回数: 257
#  最大誤差 (max_abs_error): 2.195600e+02
#  ループ回数: 258
#  最大誤差 (max_abs_error): 2.196378e+02
#  ループ回数: 259
#  最大誤差 (max_abs_error): 2.197143e+02
#  ループ回数: 260
#  最大誤差 (max_abs_error): 2.197895e+02
#  ループ回数: 261
#  最大誤差 (max_abs_error): 2.198633e+02
#  ループ回数: 262
#  最大誤差 (max_abs_error): 2.199359e+02
#  ループ回数: 263
#  最大誤差 (max_abs_error): 2.200071e+02
#  ループ回数: 264
#  最大誤差 (max_abs_error): 2.200771e+02
#  ループ回数: 265
#  最大誤差 (max_abs_error): 2.201458e+02
#  ループ回数: 266
#  最大誤差 (max_abs_error): 2.202133e+02
#  ループ回数: 267
#  最大誤差 (max_abs_error): 2.202796e+02
#  ループ回数: 268
#  最大誤差 (max_abs_error): 2.203447e+02
#  ループ回数: 269
#  最大誤差 (max_abs_error): 2.204086e+02
#  ループ回数: 270
#  最大誤差 (max_abs_error): 2.204714e+02
#  ループ回数: 271
#  最大誤差 (max_abs_error): 2.205331e+02
#  ループ回数: 272
#  最大誤差 (max_abs_error): 2.205936e+02
#  ループ回数: 273
#  最大誤差 (max_abs_error): 2.206531e+02
#  ループ回数: 274
#  最大誤差 (max_abs_error): 2.207115e+02
#  ループ回数: 275
#  最大誤差 (max_abs_error): 2.207690e+02
#  ループ回数: 276
#  最大誤差 (max_abs_error): 2.208255e+02
#  ループ回数: 277
#  最大誤差 (max_abs_error): 2.208809e+02
#  ループ回数: 278
#  最大誤差 (max_abs_error): 2.209354e+02
#  ループ回数: 279
#  最大誤差 (max_abs_error): 2.209889e+02
#  ループ回数: 280
#  最大誤差 (max_abs_error): 2.210415e+02
#  ループ回数: 281
#  最大誤差 (max_abs_error): 2.210932e+02
#  ループ回数: 282
#  最大誤差 (max_abs_error): 2.211439e+02
#  ループ回数: 283
#  最大誤差 (max_abs_error): 2.211938e+02
#  ループ回数: 284
#  最大誤差 (max_abs_error): 2.212428e+02
#  ループ回数: 285
#  最大誤差 (max_abs_error): 2.212910e+02
#  ループ回数: 286
#  最大誤差 (max_abs_error): 2.213383e+02
#  ループ回数: 287
#  最大誤差 (max_abs_error): 2.213849e+02
#  ループ回数: 288
#  最大誤差 (max_abs_error): 2.214306e+02
#  ループ回数: 289
#  最大誤差 (max_abs_error): 2.214756e+02
#  ループ回数: 290
#  最大誤差 (max_abs_error): 2.215198e+02
#  ループ回数: 291
#  最大誤差 (max_abs_error): 2.215633e+02
#  ループ回数: 292
#  最大誤差 (max_abs_error): 2.216059e+02
#  ループ回数: 293
#  最大誤差 (max_abs_error): 2.216478e+02
#  ループ回数: 294
#  最大誤差 (max_abs_error): 2.216890e+02
#  ループ回数: 295
#  最大誤差 (max_abs_error): 2.217295e+02
#  ループ回数: 296
#  最大誤差 (max_abs_error): 2.217693e+02
#  ループ回数: 297
#  最大誤差 (max_abs_error): 2.218084e+02
#  ループ回数: 298
#  最大誤差 (max_abs_error): 2.218468e+02
#  ループ回数: 299
#  最大誤差 (max_abs_error): 2.218846e+02
#  ループ回数: 300
#  最大誤差 (max_abs_error): 2.219217e+02
#  ループ回数: 301
#  最大誤差 (max_abs_error): 2.219581e+02
#  ループ回数: 302
#  最大誤差 (max_abs_error): 2.219940e+02
#  ループ回数: 303
#  最大誤差 (max_abs_error): 2.220292e+02
#  ループ回数: 304
#  最大誤差 (max_abs_error): 2.220638e+02
#  ループ回数: 305
#  最大誤差 (max_abs_error): 2.220978e+02
#  ループ回数: 306
#  最大誤差 (max_abs_error): 2.221312e+02
#  ループ回数: 307
#  最大誤差 (max_abs_error): 2.221641e+02
#  ループ回数: 308
#  最大誤差 (max_abs_error): 2.221964e+02
#  ループ回数: 309
#  最大誤差 (max_abs_error): 2.222281e+02
#  ループ回数: 310
#  最大誤差 (max_abs_error): 2.222593e+02
#  ループ回数: 311
#  最大誤差 (max_abs_error): 2.222900e+02
#  ループ回数: 312
#  最大誤差 (max_abs_error): 2.223202e+02
#  ループ回数: 313
#  最大誤差 (max_abs_error): 2.223498e+02
#  ループ回数: 314
#  最大誤差 (max_abs_error): 2.223789e+02
#  ループ回数: 315
#  最大誤差 (max_abs_error): 2.224075e+02
#  ループ回数: 316
#  最大誤差 (max_abs_error): 2.224357e+02
#  ループ回数: 317
#  最大誤差 (max_abs_error): 2.224633e+02
#  ループ回数: 318
#  最大誤差 (max_abs_error): 2.224905e+02
#  ループ回数: 319
#  最大誤差 (max_abs_error): 2.225172e+02
#  ループ回数: 320
#  最大誤差 (max_abs_error): 2.225434e+02
#  ループ回数: 321
#  最大誤差 (max_abs_error): 2.225692e+02
#  ループ回数: 322
#  最大誤差 (max_abs_error): 2.225945e+02
#  ループ回数: 323
#  最大誤差 (max_abs_error): 2.226194e+02
#  ループ回数: 324
#  最大誤差 (max_abs_error): 2.226439e+02
#  ループ回数: 325
#  最大誤差 (max_abs_error): 2.226680e+02
#  ループ回数: 326
#  最大誤差 (max_abs_error): 2.226916e+02
#  ループ回数: 327
#  最大誤差 (max_abs_error): 2.227149e+02
#  ループ回数: 328
#  最大誤差 (max_abs_error): 2.227378e+02
#  ループ回数: 329
#  最大誤差 (max_abs_error): 2.227602e+02
#  ループ回数: 330
#  最大誤差 (max_abs_error): 2.227823e+02
#  ループ回数: 331
#  最大誤差 (max_abs_error): 2.228040e+02
#  ループ回数: 332
#  最大誤差 (max_abs_error): 2.228254e+02
#  ループ回数: 333
#  最大誤差 (max_abs_error): 2.228464e+02
#  ループ回数: 334
#  最大誤差 (max_abs_error): 2.228671e+02
#  ループ回数: 335
#  最大誤差 (max_abs_error): 2.228873e+02
#  ループ回数: 336
#  最大誤差 (max_abs_error): 2.229073e+02
#  ループ回数: 337
#  最大誤差 (max_abs_error): 2.229269e+02
#  ループ回数: 338
#  最大誤差 (max_abs_error): 2.229461e+02
#  ループ回数: 339
#  最大誤差 (max_abs_error): 2.229650e+02
#  ループ回数: 340
#  最大誤差 (max_abs_error): 2.229836e+02
#  ループ回数: 341
#  最大誤差 (max_abs_error): 2.230019e+02
#  ループ回数: 342
#  最大誤差 (max_abs_error): 2.230198e+02
#  ループ回数: 343
#  最大誤差 (max_abs_error): 2.230375e+02
#  ループ回数: 344
#  最大誤差 (max_abs_error): 2.230548e+02
#  ループ回数: 345
#  最大誤差 (max_abs_error): 2.230719e+02
#  ループ回数: 346
#  最大誤差 (max_abs_error): 2.230886e+02
#  ループ回数: 347
#  最大誤差 (max_abs_error): 2.231051e+02
#  ループ回数: 348
#  最大誤差 (max_abs_error): 2.231213e+02
#  ループ回数: 349
#  最大誤差 (max_abs_error): 2.231372e+02
#  ループ回数: 350
#  最大誤差 (max_abs_error): 2.231528e+02
#  ループ回数: 351
#  最大誤差 (max_abs_error): 2.231682e+02
#  ループ回数: 352
#  最大誤差 (max_abs_error): 2.231833e+02
#  ループ回数: 353
#  最大誤差 (max_abs_error): 2.231981e+02
#  ループ回数: 354
#  最大誤差 (max_abs_error): 2.232127e+02
#  ループ回数: 355
#  最大誤差 (max_abs_error): 2.232270e+02
#  ループ回数: 356
#  最大誤差 (max_abs_error): 2.232411e+02
#  ループ回数: 357
#  最大誤差 (max_abs_error): 2.232549e+02
#  ループ回数: 358
#  最大誤差 (max_abs_error): 2.232685e+02
#  ループ回数: 359
#  最大誤差 (max_abs_error): 2.232819e+02
#  ループ回数: 360
#  最大誤差 (max_abs_error): 2.232950e+02
#  ループ回数: 361
#  最大誤差 (max_abs_error): 2.233079e+02
#  ループ回数: 362
#  最大誤差 (max_abs_error): 2.233206e+02
#  ループ回数: 363
#  最大誤差 (max_abs_error): 2.233330e+02
#  ループ回数: 364
#  最大誤差 (max_abs_error): 2.233452e+02
#  ループ回数: 365
#  最大誤差 (max_abs_error): 2.233572e+02
#  ループ回数: 366
#  最大誤差 (max_abs_error): 2.233690e+02
#  ループ回数: 367
#  最大誤差 (max_abs_error): 2.233806e+02
#  ループ回数: 368
#  最大誤差 (max_abs_error): 2.233920e+02
#  ループ回数: 369
#  最大誤差 (max_abs_error): 2.234032e+02
#  ループ回数: 370
#  最大誤差 (max_abs_error): 2.234142e+02
#  ループ回数: 371
#  最大誤差 (max_abs_error): 2.234251e+02
#  ループ回数: 372
#  最大誤差 (max_abs_error): 2.234357e+02
#  ループ回数: 373
#  最大誤差 (max_abs_error): 2.234461e+02
#  ループ回数: 374
#  最大誤差 (max_abs_error): 2.234564e+02
#  ループ回数: 375
#  最大誤差 (max_abs_error): 2.234665e+02
#  ループ回数: 376
#  最大誤差 (max_abs_error): 2.234764e+02
#  ループ回数: 377
#  最大誤差 (max_abs_error): 2.234861e+02
#  ループ回数: 378
#  最大誤差 (max_abs_error): 2.234956e+02
#  ループ回数: 379
#  最大誤差 (max_abs_error): 2.235050e+02
#  ループ回数: 380
#  最大誤差 (max_abs_error): 2.235143e+02
#  ループ回数: 381
#  最大誤差 (max_abs_error): 2.235233e+02
#  ループ回数: 382
#  最大誤差 (max_abs_error): 2.235323e+02
#  ループ回数: 383
#  最大誤差 (max_abs_error): 2.235410e+02
#  ループ回数: 384
#  最大誤差 (max_abs_error): 2.235496e+02
#  ループ回数: 385
#  最大誤差 (max_abs_error): 2.235581e+02
#  ループ回数: 386
#  最大誤差 (max_abs_error): 2.235664e+02
#  ループ回数: 387
#  最大誤差 (max_abs_error): 2.235745e+02
#  ループ回数: 388
#  最大誤差 (max_abs_error): 2.235826e+02
#  ループ回数: 389
#  最大誤差 (max_abs_error): 2.235905e+02
#  ループ回数: 390
#  最大誤差 (max_abs_error): 2.235982e+02
#  ループ回数: 391
#  最大誤差 (max_abs_error): 2.236058e+02
#  ループ回数: 392
#  最大誤差 (max_abs_error): 2.236133e+02
#  ループ回数: 393
#  最大誤差 (max_abs_error): 2.236206e+02
#  ループ回数: 394
#  最大誤差 (max_abs_error): 2.236279e+02
#  ループ回数: 395
#  最大誤差 (max_abs_error): 2.236350e+02
#  ループ回数: 396
#  最大誤差 (max_abs_error): 2.236419e+02
#  ループ回数: 397
#  最大誤差 (max_abs_error): 2.236488e+02
#  ループ回数: 398
#  最大誤差 (max_abs_error): 2.236555e+02
#  ループ回数: 399
#  最大誤差 (max_abs_error): 2.236621e+02
#  ループ回数: 400
#  最大誤差 (max_abs_error): 2.236686e+02
#  ループ回数: 401
#  最大誤差 (max_abs_error): 2.236750e+02
#  ループ回数: 402
#  最大誤差 (max_abs_error): 2.236813e+02
#  ループ回数: 403
#  最大誤差 (max_abs_error): 2.236874e+02
#  ループ回数: 404
#  最大誤差 (max_abs_error): 2.236935e+02
#  ループ回数: 405
#  最大誤差 (max_abs_error): 2.236994e+02
#  ループ回数: 406
#  最大誤差 (max_abs_error): 2.237053e+02
#  ループ回数: 407
#  最大誤差 (max_abs_error): 2.237110e+02
#  ループ回数: 408
#  最大誤差 (max_abs_error): 2.237167e+02
#  ループ回数: 409
#  最大誤差 (max_abs_error): 2.237222e+02
#  ループ回数: 410
#  最大誤差 (max_abs_error): 2.237277e+02
#  ループ回数: 411
#  最大誤差 (max_abs_error): 2.237330e+02
#  ループ回数: 412
#  最大誤差 (max_abs_error): 2.237383e+02
#  ループ回数: 413
#  最大誤差 (max_abs_error): 2.237435e+02
#  ループ回数: 414
#  最大誤差 (max_abs_error): 2.237485e+02
#  ループ回数: 415
#  最大誤差 (max_abs_error): 2.237535e+02
#  ループ回数: 416
#  最大誤差 (max_abs_error): 2.237584e+02
#  ループ回数: 417
#  最大誤差 (max_abs_error): 2.237633e+02
#  ループ回数: 418
#  最大誤差 (max_abs_error): 2.237680e+02
#  ループ回数: 419
#  最大誤差 (max_abs_error): 2.237726e+02
#  ループ回数: 420
#  最大誤差 (max_abs_error): 2.237772e+02
#  ループ回数: 421
#  最大誤差 (max_abs_error): 2.237817e+02
#  ループ回数: 422
#  最大誤差 (max_abs_error): 2.237861e+02
#  ループ回数: 423
#  最大誤差 (max_abs_error): 2.237905e+02
#  ループ回数: 424
#  最大誤差 (max_abs_error): 2.237947e+02
#  ループ回数: 425
#  最大誤差 (max_abs_error): 2.237989e+02
#  ループ回数: 426
#  最大誤差 (max_abs_error): 2.238030e+02
#  ループ回数: 427
#  最大誤差 (max_abs_error): 2.238071e+02
#  ループ回数: 428
#  最大誤差 (max_abs_error): 2.238111e+02
#  ループ回数: 429
#  最大誤差 (max_abs_error): 2.238150e+02
#  ループ回数: 430
#  最大誤差 (max_abs_error): 2.238188e+02
#  ループ回数: 431
#  最大誤差 (max_abs_error): 2.238226e+02
#  ループ回数: 432
#  最大誤差 (max_abs_error): 2.238263e+02
#  ループ回数: 433
#  最大誤差 (max_abs_error): 2.238299e+02
#  ループ回数: 434
#  最大誤差 (max_abs_error): 2.238335e+02
#  ループ回数: 435
#  最大誤差 (max_abs_error): 2.238370e+02
#  ループ回数: 436
#  最大誤差 (max_abs_error): 2.238405e+02
#  ループ回数: 437
#  最大誤差 (max_abs_error): 2.238439e+02
#  ループ回数: 438
#  最大誤差 (max_abs_error): 2.238472e+02
#  ループ回数: 439
#  最大誤差 (max_abs_error): 2.238505e+02
#  ループ回数: 440
#  最大誤差 (max_abs_error): 2.238537e+02
#  ループ回数: 441
#  最大誤差 (max_abs_error): 2.238569e+02
#  ループ回数: 442
#  最大誤差 (max_abs_error): 2.238600e+02
#  ループ回数: 443
#  最大誤差 (max_abs_error): 2.238631e+02
#  ループ回数: 444
#  最大誤差 (max_abs_error): 2.238661e+02
#  ループ回数: 445
#  最大誤差 (max_abs_error): 2.238690e+02
#  ループ回数: 446
#  最大誤差 (max_abs_error): 2.238719e+02
#  ループ回数: 447
#  最大誤差 (max_abs_error): 2.238748e+02
#  ループ回数: 448
#  最大誤差 (max_abs_error): 2.238776e+02
#  ループ回数: 449
#  最大誤差 (max_abs_error): 2.238803e+02
#  ループ回数: 450
#  最大誤差 (max_abs_error): 2.238830e+02
#  ループ回数: 451
#  最大誤差 (max_abs_error): 2.238857e+02
#  ループ回数: 452
#  最大誤差 (max_abs_error): 2.238883e+02
#  ループ回数: 453
#  最大誤差 (max_abs_error): 2.238908e+02
#  ループ回数: 454
#  最大誤差 (max_abs_error): 2.238934e+02
#  ループ回数: 455
#  最大誤差 (max_abs_error): 2.238958e+02
#  ループ回数: 456
#  最大誤差 (max_abs_error): 2.238983e+02
#  ループ回数: 457
#  最大誤差 (max_abs_error): 2.239007e+02
#  ループ回数: 458
#  最大誤差 (max_abs_error): 2.239030e+02
#  ループ回数: 459
#  最大誤差 (max_abs_error): 2.239053e+02
#  ループ回数: 460
#  最大誤差 (max_abs_error): 2.239076e+02
#  ループ回数: 461
#  最大誤差 (max_abs_error): 2.239098e+02
#  ループ回数: 462
#  最大誤差 (max_abs_error): 2.239120e+02
#  ループ回数: 463
#  最大誤差 (max_abs_error): 2.239142e+02
#  ループ回数: 464
#  最大誤差 (max_abs_error): 2.239163e+02
#  ループ回数: 465
#  最大誤差 (max_abs_error): 2.239184e+02
#  ループ回数: 466
#  最大誤差 (max_abs_error): 2.239204e+02
#  ループ回数: 467
#  最大誤差 (max_abs_error): 2.239224e+02
#  ループ回数: 468
#  最大誤差 (max_abs_error): 2.239244e+02
#  ループ回数: 469
#  最大誤差 (max_abs_error): 2.239263e+02
#  ループ回数: 470
#  最大誤差 (max_abs_error): 2.239282e+02
#  ループ回数: 471
#  最大誤差 (max_abs_error): 2.239301e+02
#  ループ回数: 472
#  最大誤差 (max_abs_error): 2.239320e+02
#  ループ回数: 473
#  最大誤差 (max_abs_error): 2.239338e+02
#  ループ回数: 474
#  最大誤差 (max_abs_error): 2.239355e+02
#  ループ回数: 475
#  最大誤差 (max_abs_error): 2.239373e+02
#  ループ回数: 476
#  最大誤差 (max_abs_error): 2.239390e+02
#  ループ回数: 477
#  最大誤差 (max_abs_error): 2.239407e+02
#  ループ回数: 478
#  最大誤差 (max_abs_error): 2.239423e+02
#  ループ回数: 479
#  最大誤差 (max_abs_error): 2.239440e+02
#  ループ回数: 480
#  最大誤差 (max_abs_error): 2.239456e+02
#  ループ回数: 481
#  最大誤差 (max_abs_error): 2.239471e+02
#  ループ回数: 482
#  最大誤差 (max_abs_error): 2.239487e+02
#  ループ回数: 483
#  最大誤差 (max_abs_error): 2.239502e+02
#  ループ回数: 484
#  最大誤差 (max_abs_error): 2.239517e+02
#  ループ回数: 485
#  最大誤差 (max_abs_error): 2.239532e+02
#  ループ回数: 486
#  最大誤差 (max_abs_error): 2.239546e+02
#  ループ回数: 487
#  最大誤差 (max_abs_error): 2.239560e+02
#  ループ回数: 488
#  最大誤差 (max_abs_error): 2.239574e+02
#  ループ回数: 489
#  最大誤差 (max_abs_error): 2.239588e+02
#  ループ回数: 490
#  最大誤差 (max_abs_error): 2.239601e+02
#  ループ回数: 491
#  最大誤差 (max_abs_error): 2.239614e+02
#  ループ回数: 492
#  最大誤差 (max_abs_error): 2.239627e+02
#  ループ回数: 493
#  最大誤差 (max_abs_error): 2.239640e+02
#  ループ回数: 494
#  最大誤差 (max_abs_error): 2.239652e+02
#  ループ回数: 495
#  最大誤差 (max_abs_error): 2.239665e+02
#  ループ回数: 496
#  最大誤差 (max_abs_error): 2.239677e+02
#  ループ回数: 497
#  最大誤差 (max_abs_error): 2.239689e+02
#  ループ回数: 498
#  最大誤差 (max_abs_error): 2.239700e+02
#  ループ回数: 499
#  最大誤差 (max_abs_error): 2.239712e+02
#  ループ回数: 500
#  最大誤差 (max_abs_error): 2.239723e+02
#  ループ回数: 501
#  最大誤差 (max_abs_error): 2.239734e+02
#  ループ回数: 502
#  最大誤差 (max_abs_error): 2.239745e+02
#  ループ回数: 503
#  最大誤差 (max_abs_error): 2.239756e+02
#  ループ回数: 504
#  最大誤差 (max_abs_error): 2.239766e+02
#  ループ回数: 505
#  最大誤差 (max_abs_error): 2.239777e+02
#  ループ回数: 506
#  最大誤差 (max_abs_error): 2.239787e+02
#  ループ回数: 507
#  最大誤差 (max_abs_error): 2.239797e+02
#  ループ回数: 508
#  最大誤差 (max_abs_error): 2.239806e+02
#  ループ回数: 509
#  最大誤差 (max_abs_error): 2.239816e+02
#  ループ回数: 510
#  最大誤差 (max_abs_error): 2.239826e+02
#  ループ回数: 511
#  最大誤差 (max_abs_error): 2.239835e+02
#  ループ回数: 512
#  最大誤差 (max_abs_error): 2.239844e+02
#  ループ回数: 513
#  最大誤差 (max_abs_error): 2.239853e+02
#  ループ回数: 514
#  最大誤差 (max_abs_error): 2.239862e+02
#  ループ回数: 515
#  最大誤差 (max_abs_error): 2.239870e+02
#  ループ回数: 516
#  最大誤差 (max_abs_error): 2.239879e+02
#  ループ回数: 517
#  最大誤差 (max_abs_error): 2.239887e+02
#  ループ回数: 518
#  最大誤差 (max_abs_error): 2.239895e+02
#  ループ回数: 519
#  最大誤差 (max_abs_error): 2.239904e+02
#  ループ回数: 520
#  最大誤差 (max_abs_error): 2.239911e+02
#  ループ回数: 521
#  最大誤差 (max_abs_error): 2.239919e+02
#  ループ回数: 522
#  最大誤差 (max_abs_error): 2.239927e+02
#  ループ回数: 523
#  最大誤差 (max_abs_error): 2.239934e+02
#  ループ回数: 524
#  最大誤差 (max_abs_error): 2.239942e+02
#  ループ回数: 525
#  最大誤差 (max_abs_error): 2.239949e+02
#  ループ回数: 526
#  最大誤差 (max_abs_error): 2.239956e+02
#  ループ回数: 527
#  最大誤差 (max_abs_error): 2.239963e+02
#  ループ回数: 528
#  最大誤差 (max_abs_error): 2.239970e+02
#  ループ回数: 529
#  最大誤差 (max_abs_error): 2.239977e+02
#  ループ回数: 530
#  最大誤差 (max_abs_error): 2.239984e+02
#  ループ回数: 531
#  最大誤差 (max_abs_error): 2.239990e+02
#  ループ回数: 532
#  最大誤差 (max_abs_error): 2.239997e+02
#  ループ回数: 533
#  最大誤差 (max_abs_error): 2.240003e+02
#  ループ回数: 534
#  最大誤差 (max_abs_error): 2.240009e+02
#  ループ回数: 535
#  最大誤差 (max_abs_error): 2.240015e+02
#  ループ回数: 536
#  最大誤差 (max_abs_error): 2.240021e+02
#  ループ回数: 537
#  最大誤差 (max_abs_error): 2.240027e+02
#  ループ回数: 538
#  最大誤差 (max_abs_error): 2.240033e+02
#  ループ回数: 539
#  最大誤差 (max_abs_error): 2.240039e+02
#  ループ回数: 540
#  最大誤差 (max_abs_error): 2.240044e+02
#  ループ回数: 541
#  最大誤差 (max_abs_error): 2.240050e+02
#  ループ回数: 542
#  最大誤差 (max_abs_error): 2.240055e+02
#  ループ回数: 543
#  最大誤差 (max_abs_error): 2.240060e+02
#  ループ回数: 544
#  最大誤差 (max_abs_error): 2.240066e+02
#  ループ回数: 545
#  最大誤差 (max_abs_error): 2.240071e+02
#  ループ回数: 546
#  最大誤差 (max_abs_error): 2.240076e+02
#  ループ回数: 547
#  最大誤差 (max_abs_error): 2.240081e+02
#  ループ回数: 548
#  最大誤差 (max_abs_error): 2.240086e+02
#  ループ回数: 549
#  最大誤差 (max_abs_error): 2.240090e+02
#  ループ回数: 550
#  最大誤差 (max_abs_error): 2.240095e+02
#  ループ回数: 551
#  最大誤差 (max_abs_error): 2.240100e+02
#  ループ回数: 552
#  最大誤差 (max_abs_error): 2.240104e+02
#  ループ回数: 553
#  最大誤差 (max_abs_error): 2.240109e+02
#  ループ回数: 554
#  最大誤差 (max_abs_error): 2.240113e+02
#  ループ回数: 555
#  最大誤差 (max_abs_error): 2.240117e+02
#  ループ回数: 556
#  最大誤差 (max_abs_error): 2.240121e+02
#  ループ回数: 557
#  最大誤差 (max_abs_error): 2.240126e+02
#  ループ回数: 558
#  最大誤差 (max_abs_error): 2.240130e+02
#  ループ回数: 559
#  最大誤差 (max_abs_error): 2.240134e+02
#  ループ回数: 560
#  最大誤差 (max_abs_error): 2.240138e+02
#  ループ回数: 561
#  最大誤差 (max_abs_error): 2.240141e+02
#  ループ回数: 562
#  最大誤差 (max_abs_error): 2.240145e+02
#  ループ回数: 563
#  最大誤差 (max_abs_error): 2.240149e+02
#  ループ回数: 564
#  最大誤差 (max_abs_error): 2.240153e+02
#  ループ回数: 565
#  最大誤差 (max_abs_error): 2.240156e+02
#  ループ回数: 566
#  最大誤差 (max_abs_error): 2.240160e+02
#  ループ回数: 567
#  最大誤差 (max_abs_error): 2.240163e+02
#  ループ回数: 568
#  最大誤差 (max_abs_error): 2.240167e+02
#  ループ回数: 569
#  最大誤差 (max_abs_error): 2.240170e+02
#  ループ回数: 570
#  最大誤差 (max_abs_error): 2.240173e+02
#  ループ回数: 571
#  最大誤差 (max_abs_error): 2.240177e+02
#  ループ回数: 572
#  最大誤差 (max_abs_error): 2.240180e+02
#  ループ回数: 573
#  最大誤差 (max_abs_error): 2.240183e+02
#  ループ回数: 574
#  最大誤差 (max_abs_error): 2.240186e+02
#  ループ回数: 575
#  最大誤差 (max_abs_error): 2.240189e+02
#  ループ回数: 576
#  最大誤差 (max_abs_error): 2.240192e+02
#  ループ回数: 577
#  最大誤差 (max_abs_error): 2.240195e+02
#  ループ回数: 578
#  最大誤差 (max_abs_error): 2.240198e+02
#  ループ回数: 579
#  最大誤差 (max_abs_error): 2.240201e+02
#  ループ回数: 580
#  最大誤差 (max_abs_error): 2.240203e+02
#  ループ回数: 581
#  最大誤差 (max_abs_error): 2.240206e+02
#  ループ回数: 582
#  最大誤差 (max_abs_error): 2.240209e+02
#  ループ回数: 583
#  最大誤差 (max_abs_error): 2.240211e+02
#  ループ回数: 584
#  最大誤差 (max_abs_error): 2.240214e+02
#  ループ回数: 585
#  最大誤差 (max_abs_error): 2.240217e+02
#  ループ回数: 586
#  最大誤差 (max_abs_error): 2.240219e+02
#  ループ回数: 587
#  最大誤差 (max_abs_error): 2.240222e+02
#  ループ回数: 588
#  最大誤差 (max_abs_error): 2.240224e+02
#  ループ回数: 589
#  最大誤差 (max_abs_error): 2.240226e+02
#  ループ回数: 590
#  最大誤差 (max_abs_error): 2.240229e+02
#  ループ回数: 591
#  最大誤差 (max_abs_error): 2.240231e+02
#  ループ回数: 592
#  最大誤差 (max_abs_error): 2.240233e+02
#  ループ回数: 593
#  最大誤差 (max_abs_error): 2.240235e+02
#  ループ回数: 594
#  最大誤差 (max_abs_error): 2.240238e+02
#  ループ回数: 595
#  最大誤差 (max_abs_error): 2.240240e+02
#  ループ回数: 596
#  最大誤差 (max_abs_error): 2.240242e+02
#  ループ回数: 597
#  最大誤差 (max_abs_error): 2.240244e+02
#  ループ回数: 598
#  最大誤差 (max_abs_error): 2.240246e+02
#  ループ回数: 599
#  最大誤差 (max_abs_error): 2.240248e+02
#  ループ回数: 600
#  最大誤差 (max_abs_error): 2.240250e+02
#  ループ回数: 601
#  最大誤差 (max_abs_error): 2.240252e+02
#  ループ回数: 602
#  最大誤差 (max_abs_error): 2.240254e+02
#  ループ回数: 603
#  最大誤差 (max_abs_error): 2.240256e+02
#  ループ回数: 604
#  最大誤差 (max_abs_error): 2.240257e+02
#  ループ回数: 605
#  最大誤差 (max_abs_error): 2.240259e+02
#  ループ回数: 606
#  最大誤差 (max_abs_error): 2.240261e+02
#  ループ回数: 607
#  最大誤差 (max_abs_error): 2.240263e+02
#  ループ回数: 608
#  最大誤差 (max_abs_error): 2.240264e+02
#  ループ回数: 609
#  最大誤差 (max_abs_error): 2.240266e+02
#  ループ回数: 610
#  最大誤差 (max_abs_error): 2.240268e+02
#  ループ回数: 611
#  最大誤差 (max_abs_error): 2.240269e+02
#  ループ回数: 612
#  最大誤差 (max_abs_error): 2.240271e+02
#  ループ回数: 613
#  最大誤差 (max_abs_error): 2.240272e+02
#  ループ回数: 614
#  最大誤差 (max_abs_error): 2.240274e+02
#  ループ回数: 615
#  最大誤差 (max_abs_error): 2.240275e+02
#  ループ回数: 616
#  最大誤差 (max_abs_error): 2.240277e+02
#  ループ回数: 617
#  最大誤差 (max_abs_error): 2.240278e+02
#  ループ回数: 618
#  最大誤差 (max_abs_error): 2.240280e+02
#  ループ回数: 619
#  最大誤差 (max_abs_error): 2.240281e+02
#  ループ回数: 620
#  最大誤差 (max_abs_error): 2.240283e+02
#  ループ回数: 621
#  最大誤差 (max_abs_error): 2.240284e+02
#  ループ回数: 622
#  最大誤差 (max_abs_error): 2.240285e+02
#  ループ回数: 623
#  最大誤差 (max_abs_error): 2.240286e+02
#  ループ回数: 624
#  最大誤差 (max_abs_error): 2.240288e+02
#  ループ回数: 625
#  最大誤差 (max_abs_error): 2.240289e+02
#  ループ回数: 626
#  最大誤差 (max_abs_error): 2.240290e+02
#  ループ回数: 627
#  最大誤差 (max_abs_error): 2.240292e+02
#  ループ回数: 628
#  最大誤差 (max_abs_error): 2.240293e+02
#  ループ回数: 629
#  最大誤差 (max_abs_error): 2.240294e+02
#  ループ回数: 630
#  最大誤差 (max_abs_error): 2.240295e+02
#  ループ回数: 631
#  最大誤差 (max_abs_error): 2.240296e+02
#  ループ回数: 632
#  最大誤差 (max_abs_error): 2.240297e+02
#  ループ回数: 633
#  最大誤差 (max_abs_error): 2.240298e+02
#  ループ回数: 634
#  最大誤差 (max_abs_error): 2.240299e+02
#  ループ回数: 635
#  最大誤差 (max_abs_error): 2.240301e+02
#  ループ回数: 636
#  最大誤差 (max_abs_error): 2.240302e+02
#  ループ回数: 637
#  最大誤差 (max_abs_error): 2.240303e+02
#  ループ回数: 638
#  最大誤差 (max_abs_error): 2.240304e+02
#  ループ回数: 639
#  最大誤差 (max_abs_error): 2.240305e+02
#  ループ回数: 640
#  最大誤差 (max_abs_error): 2.240306e+02
#  ループ回数: 641
#  最大誤差 (max_abs_error): 2.240307e+02
#  ループ回数: 642
#  最大誤差 (max_abs_error): 2.240307e+02
#  ループ回数: 643
#  最大誤差 (max_abs_error): 2.240308e+02
#  ループ回数: 644
#  最大誤差 (max_abs_error): 2.240309e+02
#  ループ回数: 645
#  最大誤差 (max_abs_error): 2.240310e+02
#  ループ回数: 646
#  最大誤差 (max_abs_error): 2.240311e+02
#  ループ回数: 647
#  最大誤差 (max_abs_error): 2.240312e+02
#  ループ回数: 648
#  最大誤差 (max_abs_error): 2.240313e+02
#  ループ回数: 649
#  最大誤差 (max_abs_error): 2.240314e+02
#  ループ回数: 650
#  最大誤差 (max_abs_error): 2.240314e+02
#  ループ回数: 651
#  最大誤差 (max_abs_error): 2.240315e+02
#  ループ回数: 652
#  最大誤差 (max_abs_error): 2.240316e+02
#  ループ回数: 653
#  最大誤差 (max_abs_error): 2.240317e+02
#  ループ回数: 654
#  最大誤差 (max_abs_error): 2.240317e+02
#  ループ回数: 655
#  最大誤差 (max_abs_error): 2.240318e+02
#  ループ回数: 656
#  最大誤差 (max_abs_error): 2.240319e+02
#  ループ回数: 657
#  最大誤差 (max_abs_error): 2.240320e+02
#  ループ回数: 658
#  最大誤差 (max_abs_error): 2.240320e+02
#  ループ回数: 659
#  最大誤差 (max_abs_error): 2.240321e+02
#  ループ回数: 660
#  最大誤差 (max_abs_error): 2.240322e+02
#  ループ回数: 661
#  最大誤差 (max_abs_error): 2.240322e+02
#  ループ回数: 662
#  最大誤差 (max_abs_error): 2.240323e+02
#  ループ回数: 663
#  最大誤差 (max_abs_error): 2.240324e+02
#  ループ回数: 664
#  最大誤差 (max_abs_error): 2.240324e+02
#  ループ回数: 665
#  最大誤差 (max_abs_error): 2.240325e+02
#  ループ回数: 666
#  最大誤差 (max_abs_error): 2.240326e+02
#  ループ回数: 667
#  最大誤差 (max_abs_error): 2.240326e+02
#  ループ回数: 668
#  最大誤差 (max_abs_error): 2.240327e+02
#  ループ回数: 669
#  最大誤差 (max_abs_error): 2.240327e+02
#  ループ回数: 670
#  最大誤差 (max_abs_error): 2.240328e+02
#  ループ回数: 671
#  最大誤差 (max_abs_error): 2.240329e+02
#  ループ回数: 672
#  最大誤差 (max_abs_error): 2.240329e+02
#  ループ回数: 673
#  最大誤差 (max_abs_error): 2.240330e+02
#  ループ回数: 674
#  最大誤差 (max_abs_error): 2.240330e+02
#  ループ回数: 675
#  最大誤差 (max_abs_error): 2.240331e+02
#  ループ回数: 676
#  最大誤差 (max_abs_error): 2.240331e+02
#  ループ回数: 677
#  最大誤差 (max_abs_error): 2.240332e+02
#  ループ回数: 678
#  最大誤差 (max_abs_error): 2.240332e+02
#  ループ回数: 679
#  最大誤差 (max_abs_error): 2.240333e+02
#  ループ回数: 680
#  最大誤差 (max_abs_error): 2.240333e+02
#  ループ回数: 681
#  最大誤差 (max_abs_error): 2.240334e+02
#  ループ回数: 682
#  最大誤差 (max_abs_error): 2.240334e+02
#  ループ回数: 683
#  最大誤差 (max_abs_error): 2.240335e+02
#  ループ回数: 684
#  最大誤差 (max_abs_error): 2.240335e+02
#  ループ回数: 685
#  最大誤差 (max_abs_error): 2.240336e+02
#  ループ回数: 686
#  最大誤差 (max_abs_error): 2.240336e+02
#  ループ回数: 687
#  最大誤差 (max_abs_error): 2.240336e+02
#  ループ回数: 688
#  最大誤差 (max_abs_error): 2.240337e+02
#  ループ回数: 689
#  最大誤差 (max_abs_error): 2.240337e+02
#  ループ回数: 690
#  最大誤差 (max_abs_error): 2.240338e+02
#  ループ回数: 691
#  最大誤差 (max_abs_error): 2.240338e+02
#  ループ回数: 692
#  最大誤差 (max_abs_error): 2.240338e+02
#  ループ回数: 693
#  最大誤差 (max_abs_error): 2.240339e+02
#  ループ回数: 694
#  最大誤差 (max_abs_error): 2.240339e+02
#  ループ回数: 695
#  最大誤差 (max_abs_error): 2.240340e+02
#  ループ回数: 696
#  最大誤差 (max_abs_error): 2.240340e+02
#  ループ回数: 697
#  最大誤差 (max_abs_error): 2.240340e+02
#  ループ回数: 698
#  最大誤差 (max_abs_error): 2.240341e+02
#  ループ回数: 699
#  最大誤差 (max_abs_error): 2.240341e+02
#  ループ回数: 700
#  最大誤差 (max_abs_error): 2.240341e+02
#  ループ回数: 701
#  最大誤差 (max_abs_error): 2.240342e+02
#  ループ回数: 702
#  最大誤差 (max_abs_error): 2.240342e+02
#  ループ回数: 703
#  最大誤差 (max_abs_error): 2.240342e+02
#  ループ回数: 704
#  最大誤差 (max_abs_error): 2.240343e+02
#  ループ回数: 705
#  最大誤差 (max_abs_error): 2.240343e+02
#  ループ回数: 706
#  最大誤差 (max_abs_error): 2.240343e+02
#  ループ回数: 707
#  最大誤差 (max_abs_error): 2.240343e+02
#  ループ回数: 708
#  最大誤差 (max_abs_error): 2.240344e+02
#  ループ回数: 709
#  最大誤差 (max_abs_error): 2.240344e+02
#  ループ回数: 710
#  最大誤差 (max_abs_error): 2.240344e+02
#  ループ回数: 711
#  最大誤差 (max_abs_error): 2.240345e+02
#  ループ回数: 712
#  最大誤差 (max_abs_error): 2.240345e+02
#  ループ回数: 713
#  最大誤差 (max_abs_error): 2.240345e+02
#  ループ回数: 714
#  最大誤差 (max_abs_error): 2.240345e+02
#  ループ回数: 715
#  最大誤差 (max_abs_error): 2.240346e+02
#  ループ回数: 716
#  最大誤差 (max_abs_error): 2.240346e+02
#  ループ回数: 717
#  最大誤差 (max_abs_error): 2.240346e+02
#  ループ回数: 718
#  最大誤差 (max_abs_error): 2.240346e+02
#  ループ回数: 719
#  最大誤差 (max_abs_error): 2.240347e+02
#  ループ回数: 720
#  最大誤差 (max_abs_error): 2.240347e+02
#  ループ回数: 721
#  最大誤差 (max_abs_error): 2.240347e+02
#  ループ回数: 722
#  最大誤差 (max_abs_error): 2.240347e+02
#  ループ回数: 723
#  最大誤差 (max_abs_error): 2.240348e+02
#  ループ回数: 724
#  最大誤差 (max_abs_error): 2.240348e+02
#  ループ回数: 725
#  最大誤差 (max_abs_error): 2.240348e+02
#  ループ回数: 726
#  最大誤差 (max_abs_error): 2.240348e+02
#  ループ回数: 727
#  最大誤差 (max_abs_error): 2.240349e+02
#  ループ回数: 728
#  最大誤差 (max_abs_error): 2.240349e+02
#  ループ回数: 729
#  最大誤差 (max_abs_error): 2.240349e+02
#  ループ回数: 730
#  最大誤差 (max_abs_error): 2.240349e+02
#  ループ回数: 731
#  最大誤差 (max_abs_error): 2.240349e+02
#  ループ回数: 732
#  最大誤差 (max_abs_error): 2.240350e+02
#  ループ回数: 733
#  最大誤差 (max_abs_error): 2.240350e+02
#  ループ回数: 734
#  最大誤差 (max_abs_error): 2.240350e+02
#  ループ回数: 735
#  最大誤差 (max_abs_error): 2.240350e+02
#  ループ回数: 736
#  最大誤差 (max_abs_error): 2.240350e+02
#  ループ回数: 737
#  最大誤差 (max_abs_error): 2.240350e+02
#  ループ回数: 738
#  最大誤差 (max_abs_error): 2.240351e+02
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 27
#      23 hfun_c = np.empty((T,len(hp.a_grid), len(hp.z_grid)))
#      25 for t in range(T-1,-1,-1):
#      26     # t期の政策関数を求める
# ---> 27     hfun_c[t-1], value_function_list[t-1] = maximize_u_value(value_function_list[t])
#      29     for i_a in range(len(hp.a_grid)):
#      30         for i_z in range(len(hp.z_grid)):
#
# Cell In[53], line 45, in maximize_u_value(vfun_next)
#      43 c_min = 1e-8
#      44 c_max = (1 + (1 - tau[t-1]) * r[t-1]) * hp.a_grid[i_a] + w[t-1] * hp.z_grid[i_z] + b + tau[t-1] * r[t-1] * K_list[t-1] #消費の最大値（借入制約に引っかかったとき）
# ---> 45 sol = fminbound(objective, c_min, c_max, xtol=1e-05, full_output = True)
#      46 # print(sol)
#      48 optimal_c = sol[0]
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/scipy/optimize/_optimize.py:2219, in fminbound(func, x1, x2, args, xtol, maxfun, full_output, disp)
#    2137 """Bounded minimization for scalar functions.
#    2138
#    2139 Parameters
#    (...)
#    2213 (4.000023843479476, 4.000023843479476)
#    2214 """
#    2215 options = {'xatol': xtol,
#    2216            'maxiter': maxfun,
#    2217            'disp': disp}
# -> 2219 res = _minimize_scalar_bounded(func, (x1, x2), args, **options)
#    2220 if full_output:
#    2221     return res['x'], res['fun'], res['status'], res['nfev']
#
# File ~/code_box/learn/python/quant-macro-workshop/venv/lib/python3.12/site-packages/scipy/optimize/_optimize.py:2283, in _minimize_scalar_bounded(func, bounds, args, xatol, maxiter, disp, **unknown_options)
#    2280     print(header)
#    2281     print("%5.0f   %12.6g %12.6g %s" % (fmin_data + (step,)))
# -> 2283 while (np.abs(xf - xm) > (tol2 - 0.5 * (b - a))):
#    2284     golden = 1
#    2285     # Check for parabolic fit
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

plt.plot(max_abs_error_list)
plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel('Max Absolute Error')
plt.title('Convergence of Capital Path')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(max_abs_error_list[250:])
plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel('Max Absolute Error')
plt.title('Convergence of Capital Path')
plt.show()

# %% [markdown]
# # テスト

# %%
K_list

# %%
T = 3
hfun_aprime = np.empty((T,len(hp.a_grid), len(hp.z_grid)))
hfun_c = np.empty((T,len(hp.a_grid), len(hp.z_grid)))
tmp = np.empty((T,len(hp.a_grid), len(hp.z_grid)))


for t in range(T-1,-1,-1):
    # t期の政策関数を求める
    hfun_c[t-1], value_function_list[t-1] = maximize_u_value(value_function_list[t])

    for i_a in range(len(hp.a_grid)):
        for i_z in range(len(hp.z_grid)):
          hfun_aprime[t-1, i_a, i_z] = (hp.a_grid[i_a] * (1 + (1 - tau[t-1]) * r[t-1]) + w[t-1] * hp.z_grid[i_z] + tau[t-1] * r[t-1] * K_list[t-1] - hfun_c[t-1, i_a, i_z])

# %%
hfun_c[1][:,0]

# %%
hfun_aprime[1][:,0]

# %%
  # 政策関数をプロット
df = pd.DataFrame({
    'x_axis': hp.a_grid,
    'y_axis': hfun_aprime[2][:,0]
})

# plot
plt.plot('x_axis', 'y_axis', data=df, linestyle='-', marker='o')
plt.show()

# %%
  # 政策関数をプロット
df = pd.DataFrame({
    'x_axis': hp.a_grid,
    'y_axis': hfun_c[2][:,0]
})

# plot
plt.plot('x_axis', 'y_axis', data=df, linestyle='-', marker='o')
plt.show()

# %%
I = 3
for i in range(1,I):
  print(i)

# %% [markdown]
# # 4-b分布の計算(過去)

# %%
@njit
def split_prob_to_agrid(aprime: float, agrid: np.ndarray) -> np.ndarray:
    """ 政策関数によって得られた a の値が、a_grid のどの点に移動するのかを示す確率ベクトルを計算する関数

    Args:
    aprime: 政策関数によって得られた a の値
    agrid: a のグリッド
    return: aprime が agrid のどの点に移動するのかを示す確率ベクトル
    """
    probs = np.zeros(len(agrid))
    # a の値が a_grid の最小値より小さい場合
    if aprime <= agrid[0]:
        probs[0] = 1.0
        return probs

    # a の値が a_grid の最大値より大きい場合
    if aprime >= agrid[-1]:
        probs[-1] = 1.0
        return probs

    # a の値が a_grid の最小値より大きく最大値より小さい場合
    for i in range(len(agrid)-1):
        if agrid[i] <= aprime <= agrid[i+1]:
            probs[i] = (agrid[i+1] - aprime) / (agrid[i+1] - agrid[i])
            probs[i+1] = (aprime - agrid[i]) / (agrid[i+1] - agrid[i])
            return probs

    # この行までに return されていない場合はエラーを出す
    raise ValueError("Splitting probability failed.")

@njit
def calc_weight_matrix(aprime_grid: np.ndarray, agrid: np.ndarray, split_prob_to_agrid = split_prob_to_agrid) -> np.ndarray:
    """ 前期の定常分布に係る重みづけ確率行列 weight_matrix を計算する関数

    Args:
        aprime_grid: 政策関数の行き先のグリッド
        agrid: 資産のグリッド
        split_prob: 政策関数によって得られた a の値が、a_grid のどの点に移動するのかを示す確率ベクトルを計算する関数

    Returns:
        weight_matrix: 前期の定常分布に係る重みづけ確率のグリッド、shape は aprime_grid と同じ
    """
    weight_matrix = np.empty((len(aprime_grid), len(aprime_grid[0]), len(agrid)))

    # aprime_grid は 二次元配列
    for i in range(len(aprime_grid)):
        for j in range(len(aprime_grid[0])):
            weight_matrix[i, j] = split_prob_to_agrid(float(aprime_grid[i, j]), agrid)
    return weight_matrix

@njit
def gen_pmesh(aprime_grid: np.ndarray, P: np.ndarray, next_y_index: int) -> np.ndarray:
    """ 遷移確率を 政策関数 aprime_grid との要素ごとの計算に使えるように meshgrid を生成する関数

    Args:
        aprime_grid (np.ndarray): 政策関数のグリッド
        P (np.ndarray): 遷移確率行列
        next_y_index (int): 次期の所得状態 y' のインデックス

    Returns:
        np.ndarray: 政策関数と遷移確率行列を使って計算するための meshgrid
    """
    pmesh = np.zeros(aprime_grid.shape)
    for i in range(len(aprime_grid)):
        for j in range(len(aprime_grid[0])):
            pmesh[i, j] = P[j, next_y_index]
    return pmesh

# def calc_sd_point(Pmesh, weight, sd_old) -> float:
#     """ 定常分布の一点を計算する関数

#     Args:
#         Pmesh (np.ndarray): 政策関数と遷移確率行列を使って計算した meshgrid
#         weight (np.ndarray): 前期の定常分布に係る重みづけ確率
#         sd_old (np.ndarray): 一期前の定常分布 f(a, y)

#     Returns:
#         float: 更新された(次期の)定常分布の一点の値
#     """
#     return np.sum(Pmesh * weight * sd_old)

@njit
def update_sd(aprime_grid: np.ndarray, agrid: np.ndarray, sd_old: np.ndarray, P: np.ndarray,
            split_prob_to_agrid = split_prob_to_agrid, calc_weight_matrix = calc_weight_matrix,
            gen_P = gen_pmesh,
            # calc_sd_point = calc_sd_point
            ) -> np.ndarray:
    """ 定常分布を更新する関数

    Args:
        aprime_grid (np.ndarray): 政策関数のグリッド
        agrid (np.ndarray): 資産のグリッド
        sd_old (np.ndarray): 更新前の定常分布
        P (np.ndarray): 遷移確率行列
        split_prob (Callable): 政策関数によって得られた a の値が、a_grid のどの点に移動するのかを示す確率ベクトルを計算する関数
        calc_weight (Callable): 前期の定常分布に係る重みづけ確率 weight を計算する関数
        gen_P (Callable): 遷移確率を 政策関数 aprime_grid との要素ごとの計算に使えるように meshgrid を生成する関数
        calc_sd_point (Callable): 定常分布の一点を計算する関数

    Returns:
        sd_new（np.ndarray）: 更新された定常分布のグリッド
    """
    sd_new = np.zeros(sd_old.shape)
    weight_matrix = calc_weight_matrix(aprime_grid, agrid, split_prob_to_agrid)
    for i in range(len(aprime_grid)):
        for j in range(len(aprime_grid[0])):
            p_mesh = gen_P(aprime_grid, P, j)
            # sd_new[i, j] = calc_sd_point(p_mesh, weight_matrix[:,:,i], sd_old)
            sd_new[i,j] = np.sum(p_mesh * weight_matrix[:,:,i] * sd_old)

    return sd_new

@njit
def sd_calculation(sd0: np.ndarray, aprime_grid: np.ndarray, agrid: np.ndarray, P: np.ndarray,

                        update_sd = update_sd) -> np.ndarray:
    """ 定常分布を計算する関数

    Args:
        aprime_grid (np.ndarray): 政策関数のグリッド
        agrid (np.ndarray): 資産のグリッド
        guess_sd (np.ndarray): 初期の定常分布のグリッド
        P (np.ndarray): 遷移確率行列
        tol (float, optional): 許容する誤差. Defaults to 1e-6.
        max_iter (int, optional): 最大の反復回数. Defaults to 1000.
        update_sd (_type_, optional): 定常分布を更新する関数. Defaults to update_sd.

    Returns:
        np.ndarray: 収束した定常分布のグリッド
    """
    sd_old = sd0
    sd_next = update_sd(aprime_grid, agrid, sd_old, P)
    return sd_next

# %% [markdown]
# # 正しい解があるかどうかのテスト

# %%
K_list
# Out:
# array([7.20629651, 6.95864747, 6.71099843])

# %%
T = 3

tau = np.zeros(T) # T期間分のtauを格納する箱を作る
tau[1:] = 0.1 # 初期状態以外のtauを0.1に設定

# K_list = np.linspace(k_ini, k_fin, T) # 資本ストックの初期値を当て推量、最初と最後の値は定常状態のものを用いる

K_test = np.linspace(k_ini, k_fin, 50) # 資本ストックの初期値を当て推量、最初と最後の値は定常状態のものを用いる



print(K_list)
max_abs_error = 1
loop = 0

# while max_abs_error > 1e-6: # 繰り返し計算前後で価値関数が等しくなるまで
for loop in range(len(K_test)):

      K_list = [k_ini,K_test[loop], k_fin]

      w = (1 - alpha) * (K_list/Lbar) ** alpha # 当て推量したKを基に賃金を計算
      r = alpha * (K_list / Lbar) ** (alpha - 1) - delta # 当て推量したKを基に金利を計算
      # print(f"r:{r}")
      xi = K_list * tau * r # 当て推量したK,rとtauより政府移転を計算

      hfun_aprime = np.empty((T,len(hp.a_grid), len(hp.z_grid)))
      hfun_c = np.empty((T,len(hp.a_grid), len(hp.z_grid)))

      for t in range(T-1,-1,-1):
          # t期の政策関数を求める
          hfun_c[t-1], value_function_list[t-1] = maximize_u_value(value_function_list[t])

          for i_a in range(len(hp.a_grid)):
              for i_z in range(len(hp.z_grid)):
                hfun_aprime[t-1, i_a, i_z] = (hp.a_grid[i_a] * (1 + (1 - tau[t-1]) * r[t-1]) + w[t-1] * hp.z_grid[i_z] + tau[t-1] * r[t-1] * K_list[t-1] - hfun_c[t-1, i_a, i_z])

      hfun_aprime[0] = aprime_ini

      sd_list = np.empty((T, len(hp.a_grid), len(hp.z_grid))) # sd_listはT＋1期分、初期状態が第0期とするため
      sd_list[0] = sd_ini.copy() # sd_listの一番最初はsd_ini、それ以外はのちの計算で埋まるためemptyのまま

      for t in range(1,T):
          sd_next = sd_calculation(sd_list[t-1], hfun_aprime[t-1], hp.a_grid, hp.Pz) # 1期前の分布より、今期の分布を求めている
          sd_list[t] = sd_next # 今期の分布をsd_listに保存

      sd_list[-1] = sd_fin

      k_pass = compute_K_path(sd_list, hfun_aprime)

      max_abs_error , error = compute_K_error(k_pass, K_list)

      print(f" error: {error}")

      print(f" ループ回数: {loop}")
# Out:
# [np.float64(7.206296512460907), np.float64(6.710998428190012), np.float64(6.710998428190012)]
#  error: [-6.27168105 -5.6638483  -6.35482674]
#  ループ回数: 0
#  error: [-6.27881684 -5.66087342 -6.36190762]
#  ループ回数: 1
#  error: [-6.28403321 -5.65606375 -6.36701688]
#  ループ回数: 2
#  error: [-6.28805199 -5.65007566 -6.37092107]
#  ループ回数: 3
#  error: [-6.29118919 -5.64319492 -6.37395399]
#  ループ回数: 4
#  error: [-6.29373333 -5.6357071  -6.37640642]
#  ループ回数: 5
#  error: [-6.29584338 -5.62777016 -6.37843825]
#  ループ回数: 6
#  error: [-6.29761896 -5.61948409 -6.38014873]
#  ループ回数: 7
#  error: [-6.29912533 -5.6109148  -6.38160202]
#  ループ回数: 8
#  error: [-6.30041663 -5.60211883 -6.38285085]
#  ループ回数: 9
#  error: [-6.30153393 -5.59313945 -6.38393492]
#  ループ回数: 10
#  error: [-6.30250713 -5.58400814 -6.38488293]
#  ループ回数: 11
#  error: [-6.30335928 -5.57474915 -6.3857169 ]
#  ループ回数: 12
#  error: [-6.30410855 -5.56538162 -6.3864541 ]
#  ループ回数: 13
#  error: [-6.30476693 -5.55591703 -6.38710593]
#  ループ回数: 14
#  error: [-6.30534496 -5.54637089 -6.38768067]
#  ループ回数: 15
#  error: [-6.30585867 -5.53675814 -6.38819467]
#  ループ回数: 16
#  error: [-6.30631289 -5.52708456 -6.38865234]
#  ループ回数: 17
#  error: [-6.30671424 -5.51735743 -6.38905976]
#  ループ回数: 18
#  error: [-6.30707318 -5.50758583 -6.38942738]
#  ループ回数: 19
#  error: [-6.30739469 -5.497775   -6.38975982]
#  ループ回数: 20
#  error: [-6.30768359 -5.48793009 -6.39006158]
#  ループ回数: 21
#  error: [-6.30794499 -5.47805946 -6.39033677]
#  ループ回数: 22
#  error: [-6.30818314 -5.46816721 -6.39058954]
#  ループ回数: 23
#  error: [-6.30841128 -5.45826567 -6.3908337 ]
#  ループ回数: 24
#  error: [-6.30861897 -5.44834274 -6.39105854]
#  ループ回数: 25
#  error: [-6.30880908 -5.43840154 -6.39126672]
#  ループ回数: 26
#  error: [-6.30898454 -5.42844531 -6.39146108]
#  ループ回数: 27
#  error: [-6.30914944 -5.41847868 -6.39164544]
#  ループ回数: 28
#  error: [-6.3093022  -5.40849952 -6.39181826]
#  ループ回数: 29
#  error: [-6.30944372 -5.39850876 -6.39198033]
#  ループ回数: 30
#  error: [-6.30957245 -5.38850637 -6.39212955]
#  ループ回数: 31
#  error: [-6.30969299 -5.37849543 -6.39227102]
#  ループ回数: 32
#  error: [-6.30980581 -5.36847655 -6.39240502]
#  ループ回数: 33
#  error: [-6.3099133  -5.35845213 -6.39253391]
#  ループ回数: 34
#  error: [-6.31001336 -5.34841988 -6.3926555 ]
#  ループ回数: 35
#  error: [-6.310107   -5.33838058 -6.39277081]
#  ループ回数: 36
#  error: [-6.31019563 -5.3283362  -6.39288127]
#  ループ回数: 37
#  error: [-6.31028072 -5.318288   -6.39298837]
#  ループ回数: 38
#  error: [-6.31036488 -5.30824009 -6.39309446]
#  ループ回数: 39
#  error: [-6.31044247 -5.29818569 -6.39319412]
#  ループ回数: 40
#  error: [-6.31051106 -5.28812516 -6.39328437]
#  ループ回数: 41
#  error: [-6.31057473 -5.27806145 -6.39336955]
#  ループ回数: 42
#  error: [-6.31063571 -5.26799514 -6.3934521 ]
#  ループ回数: 43
#  error: [-6.31069403 -5.25792607 -6.39353205]
#  ループ回数: 44
#  error: [-6.31074535 -5.24785061 -6.39360459]
#  ループ回数: 45
#  error: [-6.3108008  -5.23777721 -6.39368183]
#  ループ回数: 46
#  error: [-6.31085489 -5.22770239 -6.39375778]
#  ループ回数: 47
#  error: [-6.3109075  -5.217626   -6.39383232]
#  ループ回数: 48
#  error: [-6.31095877 -5.20754824 -6.39390556]
#  ループ回数: 49
