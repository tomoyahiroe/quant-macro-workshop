# %%
import numpy as np
from setting import Setting
from equilibrium import search_equilibrium
import time
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
loops = 1
times = np.empty(loops)
r_stars = np.empty(loops)
k_star = np.empty(loops)
w_star = np.empty(loops)
for i in range(loops):
    start = time.time()
    hp = Setting(beta=0.96, gamma=3, rho=0.6, sigma=0.4, 
                alpha=0.36, delta=0.08, b=3, a_max=45,
                nz = 7, na = 300, r0 = 0.03, tau = 0.1) 
    result = search_equilibrium(hp = hp, lambdaR = 0.002, DEBUG_MODE= True)
    end = time.time()

    times[i] = (end - start)
    r_stars[i] = result.r_star
    k_star[i] = result.K_star
    w_star[i] = result.w_star

print(f"TIME: {np.mean(times)}({np.std(times)})")
print(f"r_star: {np.mean(result.r_star)}({np.std(result.r_star)})")
print(f"K_star: {np.mean(result.K_star)}({np.std(result.K_star)})")
print(f"w_star: {np.mean(result.w_star)}({np.std(result.w_star)})")
# Out:
# PF Error at iteration 25 is 0.06549305572561437.
# PF Error at iteration 50 is 0.01322242121611339.
# PF Error at iteration 75 is 0.003904844934692786.
# PF Error at iteration 100 is 0.0012276006154405827.
# PF Error at iteration 125 is 0.00037094601142273476.
# PF Error at iteration 150 is 0.00010454797765202528.
#
# Converged in 151 iterations.
# A:  4.724829034714761
# loop:  1
# r:  0.03 , A:  4.724829034714761 , diff:  -1.6511456915236202
# PF Error at iteration 25 is 0.06561537599889089.
# PF Error at iteration 50 is 0.013352921048747746.
# PF Error at iteration 75 is 0.004039863064426719.
# PF Error at iteration 100 is 0.0013434322444974.
# PF Error at iteration 125 is 0.0004468854481651796.
# PF Error at iteration 150 is 0.00014357363058392636.
#
# Converged in 158 iterations.
# A:  5.996769905473725
# loop:  2
# r:  0.03330229138304724 , A:  5.996769905473725 , diff:  -0.09123087862967427
# PF Error at iteration 25 is 0.06561986884013038.
# PF Error at iteration 50 is 0.013357492295256623.
# PF Error at iteration 75 is 0.004044762524630929.
# PF Error at iteration 100 is 0.0013479122403352584.
# PF Error at iteration 125 is 0.00045009680876662017.
# PF Error at iteration 150 is 0.00014540859967127062.
#
# Converged in 159 iterations.
# A:  6.084846199128251
# loop:  3
# r:  0.033484753140306585 , A:  6.084846199128251 , diff:  0.012132778261537247
# PF Error at iteration 25 is 0.06561928460192679.
# PF Error at iteration 50 is 0.013356899557742441.
# PF Error at iteration 75 is 0.004044125367561602.
# PF Error at iteration 100 is 0.0013473274900070997.
# PF Error at iteration 125 is 0.00044967594515599174.
# PF Error at iteration 150 is 0.00014516715808055025.
#
# Converged in 159 iterations.
# A:  6.073544871256389
# loop:  4
# r:  0.03346048758378351 , A:  6.073544871256389 , diff:  -0.0011979818002973985
# PF Error at iteration 25 is 0.06561934246839751.
# PF Error at iteration 50 is 0.013356958291649512.
# PF Error at iteration 75 is 0.004044188476241661.
# PF Error at iteration 100 is 0.0013473853792165258.
# PF Error at iteration 125 is 0.0004497175869637715.
# PF Error at iteration 150 is 0.0001451910333898354.
#
# Converged in 159 iterations.
# A:  6.074744139327877
# loop:  5
# r:  0.03346288354738411 , A:  6.074744139327877 , diff:  0.000201720433298469
# PF Error at iteration 25 is 0.06561933272684861.
# PF Error at iteration 50 is 0.013356948404999347.
# PF Error at iteration 75 is 0.004044177852788433.
# PF Error at iteration 100 is 0.0013473756339630327.
# PF Error at iteration 125 is 0.0004497105762797382.
# PF Error at iteration 150 is 0.00014518701374566234.
#
# Converged in 159 iterations.
# A:  6.074542171947568
# loop:  6
# r:  0.03346248010651751 , A:  6.074542171947568 , diff:  -3.399600421793991e-05
# PF Error at iteration 25 is 0.06561933436867395.
# PF Error at iteration 50 is 0.013356950071290008.
# PF Error at iteration 75 is 0.004044179643247325.
# PF Error at iteration 100 is 0.00134737727640033.
# PF Error at iteration 125 is 0.00044971175778485417.
# PF Error at iteration 150 is 0.00014518769119664654.
#
# Converged in 159 iterations.
# A:  6.074576208708442
# loop:  7
# r:  0.033462548098525946 , A:  6.074576208708442 , diff:  5.728516781822179e-06
# TIME: 7.788996934890747(0.0)
# r_star: 0.033462548098525946(0.0)
# K_star: 6.07457048019166(0.0)
# w_star: 1.2253088805095682(0.0)

# %%
# resultに格納されている変数を確認
list(vars(result))

# %%
# 横軸 i 縦軸result.hp.a_gridで2Dプロット
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title("a_grid")
ax.set_xlabel("i")
ax.set_ylabel("a_grid")
plt.plot(np.linspace(0, 49,50), result.hp.a_grid)
plt.show()

# %%
# 定常分布 sd のプロット

# メッシュグリッドを作成
X, Y = np.meshgrid(hp.a_grid, hp.z_grid)
# Z = sd.T  # データの形状を合わせるため転置（必要なら）

# 3Dプロット
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, result.sd.T, cmap='viridis', edgecolor='none')
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=10)

# 軸ラベル
ax.set_xlabel('hp.a_grid (X-axis)')
ax.set_ylabel('hp.z_grid (Y-axis)')
ax.set_zlabel('sd (Z-axis)')
ax.set_title('3D Surface Plot of sd')

plt.show()

# %%
result.hfun_c

# %%
result.hp.hfun_old
