# %%
from olg import *
from setting import Setting
from utils import *
import numpy as np

# %%
result = search_equilibrium(
    Setting(),
    r0 = 0.032,
    lambdaR = 0.001,
    DEBUG_MODE=False
)
# Out:
# Kd:  542.3961993935163 , Ks:  0.0
# w_star:  0.9345903743395974 r_star:  0.032
# Y:  151.87093583018455 , Ld:  65.0 , Ls:  65.0
# tau:  0.2173913043478261 , p:  0.4672951871697987
# gc:  0.011360000000000037
# test -3.4235350809506087
# pf_aprime:  [   0.           -3.42353508   -7.00382356  -10.74641773  -14.65705368
#   -18.74165718  -23.00634986  -27.45745557  -32.10150687  -36.94525181
#   -41.99566091  -47.25993433  -52.74550929  -58.46006777  -64.41154437
#   -70.6081345   -77.05830282  -83.77079187  -90.75463114  -98.01914623
#  -105.57396848 -113.42904483 -121.59464795 -130.08138681 -138.90021749
#  -148.0624544  -157.57978182 -167.4642658  -177.72836652 -188.38495095
#  -199.44730598 -210.92915194 -222.84465657 -235.20844944 -248.03563678
#  -261.34181691 -275.14309601 -289.45610451 -304.29801396 -319.68655443
#  -335.64003251 -352.17734987 -369.31802235 -387.0821998  -405.49068641
#  -424.56496179 -444.32720269 -465.06442879 -486.54460765 -508.79241533
# ...

# %%
print(result.eq)
