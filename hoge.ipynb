       10.44091629, 10.50377387, 10.56663832, 10.62950967, 10.69238792,
       10.7552731 , 10.81816522, 10.8810643 , 10.94397034, 11.00688338,
       11.06980344, 11.13273057, 11.19566479, 11.25860611, 11.32155455,
       11.38451018, 11.44747303, 11.51044315, 11.57342057, 11.63640531,
       11.69939744, 11.76239703, 11.82540414, 11.88841878, 11.951441  ,
       12.01447088, 12.07750851, 12.14055395, 12.2036072 , 12.26666831,
       12.32973738, 12.39281455, 12.45589989, 12.5189934 , 12.58209512,
       12.64520517, 12.70832371, 12.77145086, 12.83458664, 12.89773104,
       12.96088422, 13.02404643, 13.08721777, 13.1503983 , 13.213588  ,
       13.27678702, 13.33999563, 13.40321409, 13.46644222, 13.5296801 ,
       13.59292785, 13.65618595, 13.71945455, 13.78273366, 13.846023  ,
       13.909323  , 13.97263402, 14.03595666, 14.09929051, 14.16263542,
       14.22599172, 14.28936039, 14.35274134, 14.41613507, 14.47954077,
       14.54295896, 14.60639041, 14.66983618, 14.73329497, 14.79676721,
       14.86025278, 14.92375374, 14.9872699 , 15.05080144, 15.11434674])

# %%
len(hfun_a)
# Out:
# 300

# %%
a_grid = np.linspace(-3, 16, 300)
a_grid
# Out:
# array([-3.00000000e+00, -2.93645485e+00, -2.87290970e+00, -2.80936455e+00,
#        -2.74581940e+00, -2.68227425e+00, -2.61872910e+00, -2.55518395e+00,
#        -2.49163880e+00, -2.42809365e+00, -2.36454849e+00, -2.30100334e+00,
#        -2.23745819e+00, -2.17391304e+00, -2.11036789e+00, -2.04682274e+00,
#        -1.98327759e+00, -1.91973244e+00, -1.85618729e+00, -1.79264214e+00,
#        -1.72909699e+00, -1.66555184e+00, -1.60200669e+00, -1.53846154e+00,
#        -1.47491639e+00, -1.41137124e+00, -1.34782609e+00, -1.28428094e+00,
#        -1.22073579e+00, -1.15719064e+00, -1.09364548e+00, -1.03010033e+00,
#        -9.66555184e-01, -9.03010033e-01, -8.39464883e-01, -7.75919732e-01,
#        -7.12374582e-01, -6.48829431e-01, -5.85284281e-01, -5.21739130e-01,
#        -4.58193980e-01, -3.94648829e-01, -3.31103679e-01, -2.67558528e-01,
#        -2.04013378e-01, -1.40468227e-01, -7.69230769e-02, -1.33779264e-02,
# ...

# %%
len(a_grid)
# Out:
# 300

# %%
import numpy as np
from scipy.optimize import minimize

# %%
def fun(sigma, a_grid, hfun_a):
    # return np.max(hfun_a - a_grid**(1-sigma)/(1-sigma))
    return np.max((hfun_a + 3.0) - ((a_grid + 3.0)**(1-sigma))/(1-sigma))

# %%
fun(0.4, a_grid, hfun_a)
# Out:
# np.float64(8.362184669317974)

# %%
sigma_star = minimize(fun, 0.4, (a_grid, hfun_a)).x

# %%
sigma_star
# Out:
# array([-0.07632439])

# %%
import matplotlib.pyplot as plt
plt.plot(a_grid, hfun_a)
plt.plot(a_grid, (a_grid + 3.0)**(1-sigma_star)/(1-sigma_star) - 3.0)
plt.show()

# %%
plt.plot(np.linspace(-3, 100, 300), (np.linspace(-3, 100, 300) + 3.0)**(1-sigma_star)/(1-sigma_star) - 3.0)
plt.show()

# %%
# hfun_a を a_grid に対してプロット
plt.plot(a_grid, hfun_a)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 # hfun_a を a_grid に対してプロット
# ----> 2 plt.plot(a_grid, hfun_a)
#       3 plt.show()
#
# NameError: name 'plt' is not defined
